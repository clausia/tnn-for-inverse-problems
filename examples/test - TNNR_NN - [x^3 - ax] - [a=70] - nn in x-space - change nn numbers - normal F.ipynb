# %% [markdown]
# # normal F

# %%
import sys
sys.path.append("..")

from TwinNeuralNetworkNearestNeighbors import TNNR_NN

import matplotlib.pyplot as plt

import numpy as np

from datetime import datetime

import gc

# %%
def_func = lambda a: lambda x: x**3 - a*x

# %%
n = 2100
seed = 23497

a = 70

# %% [markdown]
# # layers: 64, 64, 1

# %% [markdown]
# # num_nn_train = 5

# %% [markdown]
# ## num_nn_test=10
# ## radius_nn_predict=0.02
# ## radius_sub_nn_predict=0.01

# %%
# %%time

tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                          show_summary=False, show_loss_plot=True, show_rmse=True, 
                          mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                          num_nn_train=5,
                          num_nn_test=10,
                          radius_nn_predict=0.02,
                          radius_sub_nn_predict=0.01)
# Out:
# Test RMSE: 0.028214880098406114
# CPU times: user 20min 35s, sys: 23min 7s, total: 43min 42s
# Wall time: 10min 19s

# %%
plt.scatter(tnnr_nn_test_64.cn_transformer.inverse_transform_x(tnnr_nn_test_64.x_train_single), 
            tnnr_nn_test_64.cn_transformer.inverse_transform_y(tnnr_nn_test_64.y_train_single),
            label='Train data set', s=10, c='#99ffff')
plt.scatter(tnnr_nn_test_64.x_pred_test,
            tnnr_nn_test_64.y_pred_test,
            label='TNNR NN, $2\\times 64$ neurons', s=3)

plt.title('Function: $x^3 - 70x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()

# %% [markdown]
# ## num_nn_test=5
# ## radius_nn_predict=0.02
# ## radius_sub_nn_predict=0.01

# %%
# %%time

tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                          show_summary=False, show_loss_plot=True, show_rmse=True, 
                          mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                          num_nn_train=5,
                          num_nn_test=5,
                          radius_nn_predict=0.02,
                          radius_sub_nn_predict=0.01)
# Out:
# Test RMSE: 0.028904684915089823
# CPU times: user 12min 25s, sys: 13min 23s, total: 25min 48s
# Wall time: 6min 17s

# %%
plt.scatter(tnnr_nn_test_64.cn_transformer.inverse_transform_x(tnnr_nn_test_64.x_train_single), 
            tnnr_nn_test_64.cn_transformer.inverse_transform_y(tnnr_nn_test_64.y_train_single),
            label='Train data set', s=10, c='#99ffff')
plt.scatter(tnnr_nn_test_64.x_pred_test,
            tnnr_nn_test_64.y_pred_test,
            label='TNNR NN, $2\\times 64$ neurons', s=3)

plt.title('Function: $x^3 - 70x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()

# %% [markdown]
# ## num_nn_test=1
# ## radius_nn_predict=0.02
# ## radius_sub_nn_predict=0.01

# %%
# %%time

tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                          show_summary=False, show_loss_plot=True, show_rmse=True, 
                          mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                          num_nn_train=5,
                          num_nn_test=1,
                          radius_nn_predict=0.02,
                          radius_sub_nn_predict=0.01)
# Out:
# Test RMSE: 0.029387163336656728
# CPU times: user 5min 5s, sys: 3min 47s, total: 8min 52s
# Wall time: 3min 6s

# %%
plt.scatter(tnnr_nn_test_64.cn_transformer.inverse_transform_x(tnnr_nn_test_64.x_train_single), 
            tnnr_nn_test_64.cn_transformer.inverse_transform_y(tnnr_nn_test_64.y_train_single),
            label='Train data set', s=10, c='#99ffff')
plt.scatter(tnnr_nn_test_64.x_pred_test,
            tnnr_nn_test_64.y_pred_test,
            label='TNNR NN, $2\\times 64$ neurons', s=3)

plt.title('Function: $x^3 - 70x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()

# %% [markdown]
# ## num_nn_test=15
# ## radius_nn_predict=0.02
# ## radius_sub_nn_predict=0.01

# %%
# %%time

tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                          show_summary=False, show_loss_plot=True, show_rmse=True, 
                          mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                          num_nn_train=5,
                          num_nn_test=15,
                          radius_nn_predict=0.02,
                          radius_sub_nn_predict=0.01)
# Out:
# Test RMSE: 0.028094021123770314
# CPU times: user 29min 57s, sys: 35min 39s, total: 1h 5min 37s
# Wall time: 14min 6s

# %%
plt.scatter(tnnr_nn_test_64.cn_transformer.inverse_transform_x(tnnr_nn_test_64.x_train_single), 
            tnnr_nn_test_64.cn_transformer.inverse_transform_y(tnnr_nn_test_64.y_train_single),
            label='Train data set', s=10, c='#99ffff')
plt.scatter(tnnr_nn_test_64.x_pred_test,
            tnnr_nn_test_64.y_pred_test,
            label='TNNR NN, $2\\times 64$ neurons', s=3)

plt.title('Function: $x^3 - 70x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()

# %% [markdown]
# ## num_nn_test=20
# ## radius_nn_predict=0.02
# ## radius_sub_nn_predict=0.01

# %%
# %%time

tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                          show_summary=False, show_loss_plot=True, show_rmse=True, 
                          mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                          num_nn_train=5,
                          num_nn_test=20,
                          radius_nn_predict=0.02,
                          radius_sub_nn_predict=0.01)
# Out:
# Test RMSE: 0.027663241497279046
# CPU times: user 39min 12s, sys: 47min 42s, total: 1h 26min 54s
# Wall time: 1h 58min 5s

# %%
plt.scatter(tnnr_nn_test_64.cn_transformer.inverse_transform_x(tnnr_nn_test_64.x_train_single), 
            tnnr_nn_test_64.cn_transformer.inverse_transform_y(tnnr_nn_test_64.y_train_single),
            label='Train data set', s=10, c='#99ffff')
plt.scatter(tnnr_nn_test_64.x_pred_test,
            tnnr_nn_test_64.y_pred_test,
            label='TNNR NN, $2\\times 64$ neurons', s=3)

plt.title('Function: $x^3 - 70x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()

# %% [markdown]
# --------------

# %% [markdown]
# ## num_nn_test = 1
# ## radius_nn_predict = 0.005, 0.01, 0.015, 0.025, 0.03
# ## radius_sub_nn_predict = 0.01

# %%
num_nn_test = [1]
radius_nn_predict = [0.005, 0.01, 0.015, 0.025, 0.03]
radius_sub_nn_predict = [0.01]

# %%
# %%time

for nn_test in num_nn_test:
    for nn_predint in radius_nn_predict:
        for sub_nn_predict in radius_sub_nn_predict:

            start_time = datetime.now()

            tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                                      show_summary=False, show_loss_plot=False, show_rmse=True, 
                                      mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                                      num_nn_train=5,
                                      num_nn_test=nn_test,
                                      radius_nn_predict=nn_predint,
                                      radius_sub_nn_predict=sub_nn_predict)

            end_time = datetime.now()
            print('Duration:              {}'.format(end_time - start_time))
            print('num_nn_test:           {}'.format(nn_test))
            print('radius_nn_predict:     {}'.format(nn_predint))
            print('radius_sub_nn_predict: {}'.format(sub_nn_predict))
            print()
# Out:
# Test RMSE: 0.013741694064430385
# Duration:              0:02:14.480603
# num_nn_test:           1
# radius_nn_predict:     0.005
# radius_sub_nn_predict: 0.01
# Test RMSE: 0.0244435882630156
# Duration:              0:02:24.981037
# num_nn_test:           1
# radius_nn_predict:     0.01
# radius_sub_nn_predict: 0.01
# Test RMSE: 0.024625376719898413
# Duration:              0:02:35.265051
# num_nn_test:           1
# radius_nn_predict:     0.015
# radius_sub_nn_predict: 0.01
# Test RMSE: 0.03171904631690183
# Duration:              0:02:51.545451
# num_nn_test:           1
# radius_nn_predict:     0.025
# radius_sub_nn_predict: 0.01
# Test RMSE: 0.03646188371012214
# Duration:              0:02:59.022908
# num_nn_test:           1
# radius_nn_predict:     0.03
# radius_sub_nn_predict: 0.01
# CPU times: user 28min 35s, sys: 19min 7s, total: 47min 42s
# Wall time: 13min 5s

# %% [markdown]
# -----------

# %% [markdown]
# ## num_nn_test = 1
# ## radius_nn_predict = 0.025
# ## radius_sub_nn_predict = 0.001, 0.005, 0.015, 0.02, 0.025

# %%
num_nn_test = [1]
radius_nn_predict = [0.025]
radius_sub_nn_predict = [0.001, 0.005, 0.015, 0.02, 0.025]

# %%
# %%time

for nn_test in num_nn_test:
    for nn_predint in radius_nn_predict:
        for sub_nn_predict in radius_sub_nn_predict:

            start_time = datetime.now()

            tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                                      show_summary=False, show_loss_plot=False, show_rmse=True, 
                                      mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                                      num_nn_train=5,
                                      num_nn_test=nn_test,
                                      radius_nn_predict=nn_predint,
                                      radius_sub_nn_predict=sub_nn_predict)

            end_time = datetime.now()
            print('Duration:              {}'.format(end_time - start_time))
            print('num_nn_test:           {}'.format(nn_test))
            print('radius_nn_predict:     {}'.format(nn_predint))
            print('radius_sub_nn_predict: {}'.format(sub_nn_predict))
            print()
# Out:
# Test RMSE: 0.025519905115279903
# Duration:              0:06:39.582802
# num_nn_test:           1
# radius_nn_predict:     0.025
# radius_sub_nn_predict: 0.001
#
# Test RMSE: 0.026159454350375855
# Duration:              0:03:55.305435
# num_nn_test:           1
# radius_nn_predict:     0.025
# radius_sub_nn_predict: 0.005
#
# Test RMSE: 0.04055723512133106
# Duration:              0:02:56.567477
# num_nn_test:           1
# radius_nn_predict:     0.025
# radius_sub_nn_predict: 0.015
#
# Test RMSE: 0.05113844120478918
# Duration:              0:26:13.819840
# num_nn_test:           1
# radius_nn_predict:     0.025
# radius_sub_nn_predict: 0.02
#
# Test RMSE: 0.06649439907191787
# Duration:              0:02:47.302059
# num_nn_test:           1
# radius_nn_predict:     0.025
# radius_sub_nn_predict: 0.025
#
# CPU times: user 35min 39s, sys: 32min 8s, total: 1h 7min 47s
# Wall time: 42min 32s

# %% [markdown]
# ------------

# %% [markdown]
# ## num_nn_test = 15
# ## radius_nn_predict = 0.005, 0.01, 0.015, 0.025, 0.03
# ## radius_sub_nn_predict = 0.01

# %%
num_nn_test = [15]
radius_nn_predict = [0.005, 0.01, 0.015, 0.025, 0.03]
radius_sub_nn_predict = [0.01]

# %%
# %%time

for nn_test in num_nn_test:
    for nn_predint in radius_nn_predict:
        for sub_nn_predict in radius_sub_nn_predict:

            start_time = datetime.now()

            tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                                      show_summary=False, show_loss_plot=False, show_rmse=True, 
                                      mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                                      num_nn_train=5,
                                      num_nn_test=nn_test,
                                      radius_nn_predict=nn_predint,
                                      radius_sub_nn_predict=sub_nn_predict)

            end_time = datetime.now()
            print('Duration:              {}'.format(end_time - start_time))
            print('num_nn_test:           {}'.format(nn_test))
            print('radius_nn_predict:     {}'.format(nn_predint))
            print('radius_sub_nn_predict: {}'.format(sub_nn_predict))
            print()
# Out:
# Test RMSE: 0.012843133663384736
# Duration:              0:06:02.177576
# num_nn_test:           15
# radius_nn_predict:     0.005
# radius_sub_nn_predict: 0.01
#
# Test RMSE: 0.02499906489600634
# Duration:              0:08:34.699446
# num_nn_test:           15
# radius_nn_predict:     0.01
# radius_sub_nn_predict: 0.01
#
# Test RMSE: 0.024982574436310776
# Duration:              0:11:23.204257
# num_nn_test:           15
# radius_nn_predict:     0.015
# radius_sub_nn_predict: 0.01
#
# Test RMSE: 0.031079543591908218
# Duration:              0:16:07.305207
# num_nn_test:           15
# radius_nn_predict:     0.025
# radius_sub_nn_predict: 0.01
#
# Test RMSE: 0.03363467510544758
# Duration:              0:18:40.763917
# num_nn_test:           15
# radius_nn_predict:     0.03
# radius_sub_nn_predict: 0.01
#
# CPU times: user 2h 12min 25s, sys: 2h 38min 26s, total: 4h 50min 51s
# Wall time: 1h 48s

# %% [markdown]
# ------------

# %% [markdown]
# ## num_nn_test = 15
# ## radius_nn_predict = 0.005
# ## radius_sub_nn_predict = 0.0001, 0.0005, 0.001, 0.005, 0.015

# %%
num_nn_test = [15]
radius_nn_predict = [0.005]
radius_sub_nn_predict = [0.0001, 0.0005, 0.001, 0.005, 0.015]

# %%
# %%time

for nn_test in num_nn_test:
    for nn_predint in radius_nn_predict:
        for sub_nn_predict in radius_sub_nn_predict:

            start_time = datetime.now()

            tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                                      show_summary=False, show_loss_plot=False, show_rmse=True, 
                                      mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                                      num_nn_train=5,
                                      num_nn_test=nn_test,
                                      radius_nn_predict=nn_predint,
                                      radius_sub_nn_predict=sub_nn_predict)

            end_time = datetime.now()
            print('Duration:              {}'.format(end_time - start_time))
            print('num_nn_test:           {}'.format(nn_test))
            print('radius_nn_predict:     {}'.format(nn_predint))
            print('radius_sub_nn_predict: {}'.format(sub_nn_predict))
            print()
# Out:
# Test RMSE: 0.01085506464416101
# Duration:              0:27:13.968088
# num_nn_test:           15
# radius_nn_predict:     0.005
# radius_sub_nn_predict: 0.0001
#
# Test RMSE: 0.010326954769654922
# Duration:              0:22:29.441884
# num_nn_test:           15
# radius_nn_predict:     0.005
# radius_sub_nn_predict: 0.0005
#
# Test RMSE: 0.010360558302096156
# Duration:              0:17:38.522652
# num_nn_test:           15
# radius_nn_predict:     0.005
# radius_sub_nn_predict: 0.001
#
# Test RMSE: 0.01294767864306704
# Duration:              0:08:06.045257
# num_nn_test:           15
# radius_nn_predict:     0.005
# radius_sub_nn_predict: 0.005
#
# Test RMSE: 0.012843133663384736
# Duration:              0:06:07.927388
# num_nn_test:           15
# radius_nn_predict:     0.005
# radius_sub_nn_predict: 0.015
#
# CPU times: user 2h 58min 17s, sys: 3h 38min 41s, total: 6h 36min 58s
# Wall time: 1h 21min 35s

# %% [markdown]
# --------------

# %% [markdown]
# ## num_nn_test = 10
# ## radius_nn_predict = 0.005, 0.01, 0.015, 0.025, 0.03
# ## radius_sub_nn_predict = 0.01

# %%
num_nn_test = [10]
radius_nn_predict = [0.005, 0.01, 0.015, 0.025, 0.03]
radius_sub_nn_predict = [0.01]

# %%
# %%time

for nn_test in num_nn_test:
    for nn_predint in radius_nn_predict:
        for sub_nn_predict in radius_sub_nn_predict:

            start_time = datetime.now()

            tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                                      show_summary=False, show_loss_plot=False, show_rmse=True, 
                                      mdl_wts_file='weights/tnnr_nn_test_64_Fnormal_n' + str(n) + '_inverse_a' + str(a),
                                      num_nn_train=5,
                                      num_nn_test=nn_test,
                                      radius_nn_predict=nn_predint,
                                      radius_sub_nn_predict=sub_nn_predict)

            end_time = datetime.now()
            print('Duration:              {}'.format(end_time - start_time))
            print('num_nn_test:           {}'.format(nn_test))
            print('radius_nn_predict:     {}'.format(nn_predint))
            print('radius_sub_nn_predict: {}'.format(sub_nn_predict))
            print()
# Out:
# Test RMSE: 0.013244968673437094
# Duration:              0:05:02.936991
# num_nn_test:           10
# radius_nn_predict:     0.005
# radius_sub_nn_predict: 0.01
#
# Test RMSE: 0.024821910504246744
# Duration:              0:06:43.552145
# num_nn_test:           10
# radius_nn_predict:     0.01
# radius_sub_nn_predict: 0.01
#
# Test RMSE: 0.024810645487753913
# Duration:              0:08:33.229936
# num_nn_test:           10
# radius_nn_predict:     0.015
# radius_sub_nn_predict: 0.01
#
# Test RMSE: 0.031153257538513234
# Duration:              0:11:14.856951
# num_nn_test:           10
# radius_nn_predict:     0.025
# radius_sub_nn_predict: 0.01
#
# Test RMSE: 0.034022726597348577
# Duration:              0:13:24.293290
# num_nn_test:           10
# radius_nn_predict:     0.03
# radius_sub_nn_predict: 0.01
#
# CPU times: user 2h 31min 3s, sys: 2h 35min 32s, total: 5h 6min 35s
# Wall time: 44min 58s

# %% [markdown]
# --------------

# %% [markdown]
# ## num_nn_test = 10
# ## radius_nn_predict = 0.03
# ## radius_sub_nn_predict = 0.005, 0.015, 0.02, 0.025, 0.03

# %%
num_nn_test = [10]
radius_nn_predict = [0.03]
radius_sub_nn_predict = [0.005, 0.015, 0.02, 0.025, 0.03]

# %%
# %%time

for nn_test in num_nn_test:
    for nn_predint in radius_nn_predict:
        for sub_nn_predict in radius_sub_nn_predict:

            start_time = datetime.now()

            tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                                      show_summary=False, show_loss_plot=False, show_rmse=True, 
                                      mdl_wts_file='weights/tnnr_nn_test_64_Fnormal_n' + str(n) + '_inverse_a' + str(a),
                                      num_nn_train=5,
                                      num_nn_test=nn_test,
                                      radius_nn_predict=nn_predint,
                                      radius_sub_nn_predict=sub_nn_predict)

            end_time = datetime.now()
            print('Duration:              {}'.format(end_time - start_time))
            print('num_nn_test:           {}'.format(nn_test))
            print('radius_nn_predict:     {}'.format(nn_predint))
            print('radius_sub_nn_predict: {}'.format(sub_nn_predict))
            print()
# Out:
# Test RMSE: 0.02754484872422517
# Duration:              0:22:08.575457
# num_nn_test:           10
# radius_nn_predict:     0.03
# radius_sub_nn_predict: 0.005
#
# Test RMSE: 0.04056126598412765
# Duration:              0:10:10.278057
# num_nn_test:           10
# radius_nn_predict:     0.03
# radius_sub_nn_predict: 0.015
#
# Test RMSE: 0.0474408190058455
# Duration:              0:08:30.605657
# num_nn_test:           10
# radius_nn_predict:     0.03
# radius_sub_nn_predict: 0.02
#
# Test RMSE: 0.06037781906486405
# Duration:              0:07:31.264189
# num_nn_test:           10
# radius_nn_predict:     0.03
# radius_sub_nn_predict: 0.025
#
# Test RMSE: 0.08101187959293797
# Duration:              0:06:45.993826
# num_nn_test:           10
# radius_nn_predict:     0.03
# radius_sub_nn_predict: 0.03
#
# CPU times: user 2h 8min 36s, sys: 2h 35min 42s, total: 4h 44min 18s
# Wall time: 55min 6s

# %% [markdown]
# -----------

# %% [markdown]
# ## num_nn_test = 20
# ## radius_nn_predict = (0.005, 0.01, 0.015,) 0.025, 0.03
# ## radius_sub_nn_predict = 0.01

# %%
num_nn_test = [20]
radius_nn_predict = [0.025] #, 0.03]  # results from [0.005, 0.01, 0.015] are in colab nb
radius_sub_nn_predict = [0.01]

# %%
# %%time

for nn_test in num_nn_test:
    for nn_predint in radius_nn_predict:
        for sub_nn_predict in radius_sub_nn_predict:

            start_time = datetime.now()

            tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                                      show_summary=False, show_loss_plot=False, show_rmse=True,
                                      mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                                      num_nn_train=5,
                                      num_nn_test=nn_test,
                                      radius_nn_predict=nn_predint,
                                      radius_sub_nn_predict=sub_nn_predict)

            end_time = datetime.now()
            print('Duration:              {}'.format(end_time - start_time))
            print('num_nn_test:           {}'.format(nn_test))
            print('radius_nn_predict:     {}'.format(nn_predint))
            print('radius_sub_nn_predict: {}'.format(sub_nn_predict))
            print()
# Out:
# Test RMSE: 0.030126820707903765
# Duration:              0:20:43.840079
# num_nn_test:           20
# radius_nn_predict:     0.025
# radius_sub_nn_predict: 0.01
#
# CPU times: user 1h 35min 44s, sys: 1h 36min 57s, total: 3h 12min 41s
# Wall time: 20min 43s

# %%
num_nn_test = [20]
radius_nn_predict = [0.03] #, 0.025]  # results from [0.005, 0.01, 0.015] are in colab nb
radius_sub_nn_predict = [0.01]

# %%
# %%time

for nn_test in num_nn_test:
    for nn_predint in radius_nn_predict:
        for sub_nn_predict in radius_sub_nn_predict:

            start_time = datetime.now()

            tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                                      show_summary=False, show_loss_plot=False, show_rmse=True,
                                      mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                                      num_nn_train=5,
                                      num_nn_test=nn_test,
                                      radius_nn_predict=nn_predint,
                                      radius_sub_nn_predict=sub_nn_predict)

            end_time = datetime.now()
            print('Duration:              {}'.format(end_time - start_time))
            print('num_nn_test:           {}'.format(nn_test))
            print('radius_nn_predict:     {}'.format(nn_predint))
            print('radius_sub_nn_predict: {}'.format(sub_nn_predict))
            print()
# Out:
# Test RMSE: 0.032642890747504746
# Duration:              0:24:28.497982
# num_nn_test:           20
# radius_nn_predict:     0.03
# radius_sub_nn_predict: 0.01
#
# CPU times: user 58min 3s, sys: 1h 14min 38s, total: 2h 12min 41s
# Wall time: 24min 28s

# %% [markdown]
# --------------

# %% [markdown]
# ## num_nn_train = 2, 7, 10, 15, 20
# ## num_nn_test = 10
# ## radius_nn_predict = 0.03
# ## radius_sub_nn_predict = 0.005

# %%
num_nn_train = [2, 7, 10, 15, 20]
num_nn_test = [10]
radius_nn_predict = [0.03]
radius_sub_nn_predict = [0.005]

# %%
# %%time

for nn_train in num_nn_train:
    for nn_test in num_nn_test:
        for nn_predint in radius_nn_predict:
            for sub_nn_predict in radius_sub_nn_predict:

                start_time = datetime.now()

                tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                                          show_summary=False, show_loss_plot=False, show_rmse=True, 
                                          mdl_wts_file='weights/tnnr_nn_test_64_Fnormal_n' + str(n) + '_inverse_a' + str(a),
                                          num_nn_train=nn_train,
                                          num_nn_test=nn_test,
                                          radius_nn_predict=nn_predint,
                                          radius_sub_nn_predict=sub_nn_predict)

                end_time = datetime.now()
                print('Duration:              {}'.format(end_time - start_time))
                print('num_nn_train:          {}'.format(nn_train))
                print('num_nn_test:           {}'.format(nn_test))
                print('radius_nn_predict:     {}'.format(nn_predint))
                print('radius_sub_nn_predict: {}'.format(sub_nn_predict))
                print()
# Out:
# Test RMSE: 0.027430529054342283
# Duration:              0:22:55.519523
# num_nn_train:          2
# num_nn_test:           10
# radius_nn_predict:     0.03
# radius_sub_nn_predict: 0.005
#
# Test RMSE: 0.02786580879906282
# Duration:              0:23:26.689269
# num_nn_train:          7
# num_nn_test:           10
# radius_nn_predict:     0.03
# radius_sub_nn_predict: 0.005
#
# Test RMSE: 0.027685885327731363
# Duration:              0:21:32.629340
# num_nn_train:          10
# num_nn_test:           10
# radius_nn_predict:     0.03
# radius_sub_nn_predict: 0.005
#
# Test RMSE: 0.027799649118054937
# Duration:              0:23:04.861601
# num_nn_train:          15
# num_nn_test:           10
# radius_nn_predict:     0.03
# radius_sub_nn_predict: 0.005
#
# Test RMSE: 0.027790202320619534
# Duration:              0:22:13.430996
# num_nn_train:          20
# num_nn_test:           10
# radius_nn_predict:     0.03
# radius_sub_nn_predict: 0.005
#
# CPU times: user 4h 29min 10s, sys: 5h 25min 16s, total: 9h 54min 26s
# Wall time: 1h 53min 13s

# %% [markdown]
# ---------------

# %%
import sys
sys.path.append("..")

from TwinNeuralNetworkNearestNeighbors import TNNR_NN

import matplotlib.pyplot as plt

import numpy as np

from datetime import datetime

import gc

# %%
def_func = lambda a: lambda x: x**3 - a*x

# %%
n = 2100
seed = 23497

a = 70

# %% [markdown]
# ## num_nn_train = 5
# ## num_nn_test = 20
# ## radius_nn_predict = 0.01
# ## radius_sub_nn_predict = 0.0005, 0.001, 0.005, 0.008, 0.015

# %%
num_nn_train = [5]
num_nn_test = [20]
radius_nn_predict = [0.01]
radius_sub_nn_predict = [0.0005, 0.001, 0.005]#, 0.008, 0.015]

# %%
# %%time

for nn_train in num_nn_train:
    for nn_test in num_nn_test:
        for nn_predint in radius_nn_predict:
            for sub_nn_predict in radius_sub_nn_predict:

                start_time = datetime.now()

                tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                                          show_summary=False, show_loss_plot=False, show_rmse=True, 
                                          mdl_wts_file='weights/tnnr_nn_test_64_Fnormal_n' + str(n) + '_inverse_a' + str(a),
                                          num_nn_train=nn_train,
                                          num_nn_test=nn_test,
                                          radius_nn_predict=nn_predint,
                                          radius_sub_nn_predict=sub_nn_predict)

                end_time = datetime.now()
                print('Duration:              {}'.format(end_time - start_time))
                print('num_nn_train:          {}'.format(nn_train))
                print('num_nn_test:           {}'.format(nn_test))
                print('radius_nn_predict:     {}'.format(nn_predint))
                print('radius_sub_nn_predict: {}'.format(sub_nn_predict))
                print()
                
                del tnnr_nn_test_64
                del start_time
                del end_time
                gc.collect()
# Out:
# Test RMSE: 0.015539686169416788
# Duration:              0:48:31.303876
# num_nn_train:          5
# num_nn_test:           20
# radius_nn_predict:     0.01
# radius_sub_nn_predict: 0.0005
#
# Test RMSE: 0.014923497167639651
# Duration:              0:38:56.836011
# num_nn_train:          5
# num_nn_test:           20
# radius_nn_predict:     0.01
# radius_sub_nn_predict: 0.001
#
# Test RMSE: 0.01590318026618802
# Duration:              0:15:57.836907
# num_nn_train:          5
# num_nn_test:           20
# radius_nn_predict:     0.01
# radius_sub_nn_predict: 0.005

# %%
num_nn_train = [5]
num_nn_test = [20]
radius_nn_predict = [0.01]
radius_sub_nn_predict = [0.008, 0.015] # 0.0005, 0.001, 0.005

# %%
# %%time

for nn_train in num_nn_train:
    for nn_test in num_nn_test:
        for nn_predint in radius_nn_predict:
            for sub_nn_predict in radius_sub_nn_predict:

                start_time = datetime.now()

                tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                                          show_summary=False, show_loss_plot=False, show_rmse=True, 
                                          mdl_wts_file='weights/tnnr_nn_test_64_Fnormal_n' + str(n) + '_inverse_a' + str(a),
                                          num_nn_train=nn_train,
                                          num_nn_test=nn_test,
                                          radius_nn_predict=nn_predint,
                                          radius_sub_nn_predict=sub_nn_predict)

                end_time = datetime.now()
                print('Duration:              {}'.format(end_time - start_time))
                print('num_nn_train:          {}'.format(nn_train))
                print('num_nn_test:           {}'.format(nn_test))
                print('radius_nn_predict:     {}'.format(nn_predint))
                print('radius_sub_nn_predict: {}'.format(sub_nn_predict))
                print()
                
                del tnnr_nn_test_64
                del start_time
                del end_time
                gc.collect()
# Out:
# Test RMSE: 0.023514691645060228
# Duration:              0:11:50.903684
# num_nn_train:          5
# num_nn_test:           20
# radius_nn_predict:     0.01
# radius_sub_nn_predict: 0.008
#
# Test RMSE: 0.024424988624810136
# Duration:              0:08:05.627078
# num_nn_train:          5
# num_nn_test:           20
# radius_nn_predict:     0.01
# radius_sub_nn_predict: 0.015
#
# CPU times: user 1h 25min 39s, sys: 1h 28min 4s, total: 2h 53min 44s
# Wall time: 19min 56s

# %% [markdown]
# ------------

# %% [markdown]
# ## num_nn_train = 12, 13, 14, 16, 17
# ## num_nn_test = 15
# ## radius_nn_predict = 0.005
# ## radius_sub_nn_predict = 0.0005

# %%
num_nn_train = [12, 13]#, 14, 16, 17]
num_nn_test = [15]
radius_nn_predict = [0.005]
radius_sub_nn_predict = [0.0005]

# %%
# %%time

for nn_train in num_nn_train:
    for nn_test in num_nn_test:
        for nn_predint in radius_nn_predict:
            for sub_nn_predict in radius_sub_nn_predict:

                start_time = datetime.now()

                tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                                          show_summary=False, show_loss_plot=False, show_rmse=True, 
                                          mdl_wts_file='weights/tnnr_nn_test_64_Fnormal_n' + str(n) + '_inverse_a' + str(a),
                                          num_nn_train=nn_train,
                                          num_nn_test=nn_test,
                                          radius_nn_predict=nn_predint,
                                          radius_sub_nn_predict=sub_nn_predict)

                end_time = datetime.now()
                print('Duration:              {}'.format(end_time - start_time))
                print('num_nn_train:          {}'.format(nn_train))
                print('num_nn_test:           {}'.format(nn_test))
                print('radius_nn_predict:     {}'.format(nn_predint))
                print('radius_sub_nn_predict: {}'.format(sub_nn_predict))
                print()
# Out:
# Test RMSE: 0.010326063432718307
# Duration:              0:25:40.012427
# num_nn_train:          12
# num_nn_test:           15
# radius_nn_predict:     0.005
# radius_sub_nn_predict: 0.0005
#
# Test RMSE: 0.010317235673056221
# Duration:              0:21:56.636864
# num_nn_train:          13
# num_nn_test:           15
# radius_nn_predict:     0.005
# radius_sub_nn_predict: 0.0005

# %%
num_nn_train = [14, 16, 17] #12, 13
num_nn_test = [15]
radius_nn_predict = [0.005]
radius_sub_nn_predict = [0.0005]

# %%
# %%time

for nn_train in num_nn_train:
    for nn_test in num_nn_test:
        for nn_predint in radius_nn_predict:
            for sub_nn_predict in radius_sub_nn_predict:

                start_time = datetime.now()

                tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                                          show_summary=False, show_loss_plot=False, show_rmse=True, 
                                          mdl_wts_file='weights/tnnr_nn_test_64_Fnormal_n' + str(n) + '_inverse_a' + str(a),
                                          num_nn_train=nn_train,
                                          num_nn_test=nn_test,
                                          radius_nn_predict=nn_predint,
                                          radius_sub_nn_predict=sub_nn_predict)

                end_time = datetime.now()
                print('Duration:              {}'.format(end_time - start_time))
                print('num_nn_train:          {}'.format(nn_train))
                print('num_nn_test:           {}'.format(nn_test))
                print('radius_nn_predict:     {}'.format(nn_predint))
                print('radius_sub_nn_predict: {}'.format(sub_nn_predict))
                print()
                
                del tnnr_nn_test_64
                del start_time
                del end_time
                gc.collect()
# Out:
# Test RMSE: 0.010335486718914651
# Duration:              0:24:24.849254
# num_nn_train:          14
# num_nn_test:           15
# radius_nn_predict:     0.005
# radius_sub_nn_predict: 0.0005
#
# Test RMSE: 0.010331027392289902
# Duration:              0:22:09.103361
# num_nn_train:          16
# num_nn_test:           15
# radius_nn_predict:     0.005
# radius_sub_nn_predict: 0.0005
#
# Test RMSE: 0.010340894574633048
# Duration:              0:21:08.986973
# num_nn_train:          17
# num_nn_test:           15
# radius_nn_predict:     0.005
# radius_sub_nn_predict: 0.0005
#
# CPU times: user 3h 34min 8s, sys: 3h 59min 12s, total: 7h 33min 20s
# Wall time: 1h 7min 43s

# %% [markdown]
# ------------

# %% [markdown]
# ## num_nn_train = 30, 30, 13
# ## num_nn_test = 15
# ## radius_nn_predict = 0.005, 0.1, 0.1
# ## radius_sub_nn_predict = 0.0005, 0.05, 0.05

# %%
import sys
sys.path.append("..")

from TwinNeuralNetworkNearestNeighbors import TNNR_NN

import matplotlib.pyplot as plt

import numpy as np

from datetime import datetime

import gc

# %%
def_func = lambda a: lambda x: x**3 - a*x

# %%
n = 2100
seed = 23497

a = 70

# %%
num_nn_train = [30]
num_nn_test = [15]
radius_nn_predict = [0.005]
radius_sub_nn_predict = [0.0005]

# %%
# %%time

for nn_train in num_nn_train:
    for nn_test in num_nn_test:
        for nn_predint in radius_nn_predict:
            for sub_nn_predict in radius_sub_nn_predict:

                start_time = datetime.now()

                tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                                          show_summary=False, show_loss_plot=False, show_rmse=True, 
                                          mdl_wts_file='weights/tnnr_nn_test_64_Fnormal_n' + str(n) + '_inverse_a' + str(a),
                                          num_nn_train=nn_train,
                                          num_nn_test=nn_test,
                                          radius_nn_predict=nn_predint,
                                          radius_sub_nn_predict=sub_nn_predict)

                end_time = datetime.now()
                print('Duration:              {}'.format(end_time - start_time))
                print('num_nn_train:          {}'.format(nn_train))
                print('num_nn_test:           {}'.format(nn_test))
                print('radius_nn_predict:     {}'.format(nn_predint))
                print('radius_sub_nn_predict: {}'.format(sub_nn_predict))
                print()
                
                del tnnr_nn_test_64
                del start_time
                del end_time
                gc.collect()
# Out:
# Test RMSE: 0.01032922769935053
# Duration:              0:23:40.683731
# num_nn_train:          30
# num_nn_test:           15
# radius_nn_predict:     0.005
# radius_sub_nn_predict: 0.0005
#
# CPU times: user 1h 35min 59s, sys: 1h 46min 19s, total: 3h 22min 19s
# Wall time: 23min 40s

# %%
gc.collect()
# Out:
# 2432

# %%
num_nn_train = [30]
num_nn_test = [15]
radius_nn_predict = [0.1]
radius_sub_nn_predict = [0.05]

# %%
# %%time

for nn_train in num_nn_train:
    for nn_test in num_nn_test:
        for nn_predint in radius_nn_predict:
            for sub_nn_predict in radius_sub_nn_predict:

                start_time = datetime.now()

                tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                                          show_summary=False, show_loss_plot=False, show_rmse=True, 
                                          mdl_wts_file='weights/tnnr_nn_test_64_Fnormal_n' + str(n) + '_inverse_a' + str(a),
                                          num_nn_train=nn_train,
                                          num_nn_test=nn_test,
                                          radius_nn_predict=nn_predint,
                                          radius_sub_nn_predict=sub_nn_predict)

                end_time = datetime.now()
                print('Duration:              {}'.format(end_time - start_time))
                print('num_nn_train:          {}'.format(nn_train))
                print('num_nn_test:           {}'.format(nn_test))
                print('radius_nn_predict:     {}'.format(nn_predint))
                print('radius_sub_nn_predict: {}'.format(sub_nn_predict))
                print()
                
                del tnnr_nn_test_64
                del start_time
                del end_time
                gc.collect()
# Out:
# Test RMSE: 0.1524924073660215
# Duration:              0:16:26.664136
# num_nn_train:          30
# num_nn_test:           15
# radius_nn_predict:     0.1
# radius_sub_nn_predict: 0.05
#
# CPU times: user 43min, sys: 39min 55s, total: 1h 22min 56s
# Wall time: 16min 26s

# %%
gc.collect()
# Out:
# 2432

# %%
num_nn_train = [13]
num_nn_test = [15]
radius_nn_predict = [0.1]
radius_sub_nn_predict = [0.05]

# %%
# %%time

for nn_train in num_nn_train:
    for nn_test in num_nn_test:
        for nn_predint in radius_nn_predict:
            for sub_nn_predict in radius_sub_nn_predict:

                start_time = datetime.now()

                tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                                          show_summary=False, show_loss_plot=False, show_rmse=True, 
                                          mdl_wts_file='weights/tnnr_nn_test_64_Fnormal_n' + str(n) + '_inverse_a' + str(a),
                                          num_nn_train=nn_train,
                                          num_nn_test=nn_test,
                                          radius_nn_predict=nn_predint,
                                          radius_sub_nn_predict=sub_nn_predict)

                end_time = datetime.now()
                print('Duration:              {}'.format(end_time - start_time))
                print('num_nn_train:          {}'.format(nn_train))
                print('num_nn_test:           {}'.format(nn_test))
                print('radius_nn_predict:     {}'.format(nn_predint))
                print('radius_sub_nn_predict: {}'.format(sub_nn_predict))
                print()
                
                del tnnr_nn_test_64
                del start_time
                del end_time
                gc.collect()
# Out:
# Test RMSE: 0.15211683760122818
# Duration:              0:14:36.596887
# num_nn_train:          13
# num_nn_test:           15
# radius_nn_predict:     0.1
# radius_sub_nn_predict: 0.05
#
# CPU times: user 45min 18s, sys: 41min 16s, total: 1h 26min 34s
# Wall time: 14min 36s

# %%
gc.collect()

# %% [markdown]
# ------------

# %%
import sys
sys.path.append("..")

from TwinNeuralNetworkNearestNeighbors import TNNR_NN

import matplotlib.pyplot as plt

import numpy as np

from datetime import datetime

import gc

# %%
def_func = lambda a: lambda x: x**3 - a*x

# %%
n = 2100
seed = 23497

a = 70

# %% [markdown]
# ## layers: 128, 128, 1
# ## num_nn_train = 5
# ## num_nn_test = 10, 5, 1, 15, 20
# ## radius_nn_predict = 0.02
# ## radius_sub_nn_predict = 0.01

# %%
num_nn_train = [5]
num_nn_test = [10, 5, 1, 15, 20]
radius_nn_predict = [0.02]
radius_sub_nn_predict = [0.01]

# %%
# %%time

for nn_train in num_nn_train:
    for nn_test in num_nn_test:
        for nn_predint in radius_nn_predict:
            for sub_nn_predict in radius_sub_nn_predict:

                start_time = datetime.now()

                tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                                          show_summary=False, show_loss_plot=False, show_rmse=True, 
                                          mdl_wts_file='weights/tnnr_nn_test_64_Fnormal_n' + str(n) + '_inverse_a' + str(a),
                                          neurons=128,
                                          num_nn_train=nn_train,
                                          num_nn_test=nn_test,
                                          radius_nn_predict=nn_predint,
                                          radius_sub_nn_predict=sub_nn_predict)

                end_time = datetime.now()
                print('Duration:              {}'.format(end_time - start_time))
                print('num_nn_train:          {}'.format(nn_train))
                print('num_nn_test:           {}'.format(nn_test))
                print('radius_nn_predict:     {}'.format(nn_predint))
                print('radius_sub_nn_predict: {}'.format(sub_nn_predict))
                print()
                
                del tnnr_nn_test_64
                del start_time
                del end_time
                gc.collect()
# Out:
# Test RMSE: 0.028153972879996794
# Duration:              0:09:51.510998
# num_nn_train:          5
# num_nn_test:           10
# radius_nn_predict:     0.02
# radius_sub_nn_predict: 0.01
#
# Test RMSE: 0.02886194969611485
# Duration:              0:06:00.576008
# num_nn_train:          5
# num_nn_test:           5
# radius_nn_predict:     0.02
# radius_sub_nn_predict: 0.01
#
# Test RMSE: 0.029264580688782505
# Duration:              0:02:55.681205
# num_nn_train:          5
# num_nn_test:           1
# radius_nn_predict:     0.02
# radius_sub_nn_predict: 0.01
#
# Test RMSE: 0.0280430436824036
# Duration:              0:13:28.757439
# num_nn_train:          5
# num_nn_test:           15
# radius_nn_predict:     0.02
# radius_sub_nn_predict: 0.01
#
# Test RMSE: 0.027626587741214532
# Duration:              0:16:56.615477
# num_nn_train:          5
# num_nn_test:           20
# radius_nn_predict:     0.02
# radius_sub_nn_predict: 0.01
#
# CPU times: user 3h 19min 23s, sys: 3h 33min, total: 6h 52min 23s
# Wall time: 49min 13s

# %% [markdown]
# ------------

# %%
import sys
sys.path.append("..")

from TwinNeuralNetworkNearestNeighbors import TNNR_NN

import matplotlib.pyplot as plt

import numpy as np

from datetime import datetime

import gc

# %%
def_func = lambda a: lambda x: x**3 - a*x

# %%
n = 2100
seed = 23497

a = 70

# %% [markdown]
# ## layers: 128, 128, 1
# ## num_nn_train = 30, 13, 2
# ## num_nn_test = 15
# ## radius_nn_predict = 0.005
# ## radius_sub_nn_predict = 0.0005

# %%
num_nn_train = [30] #, 13, 2]
num_nn_test = [15]
radius_nn_predict = [0.005]
radius_sub_nn_predict = [0.0005]

# %%
# %%time

for nn_train in num_nn_train:
    for nn_test in num_nn_test:
        for nn_predint in radius_nn_predict:
            for sub_nn_predict in radius_sub_nn_predict:

                start_time = datetime.now()

                tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                                          show_summary=False, show_loss_plot=False, show_rmse=True, 
                                          mdl_wts_file='weights/tnnr_nn_test_64_Fnormal_n' + str(n) + '_inverse_a' + str(a),
                                          neurons=128,
                                          num_nn_train=nn_train,
                                          num_nn_test=nn_test,
                                          radius_nn_predict=nn_predint,
                                          radius_sub_nn_predict=sub_nn_predict)

                end_time = datetime.now()
                print('Duration:              {}'.format(end_time - start_time))
                print('num_nn_train:          {}'.format(nn_train))
                print('num_nn_test:           {}'.format(nn_test))
                print('radius_nn_predict:     {}'.format(nn_predint))
                print('radius_sub_nn_predict: {}'.format(sub_nn_predict))
                print()
                
                del tnnr_nn_test_64
                del start_time
                del end_time
                gc.collect()
# Out:
# Test RMSE: 0.01032840496452422
# Duration:              0:24:29.932360
# num_nn_train:          30
# num_nn_test:           15
# radius_nn_predict:     0.005
# radius_sub_nn_predict: 0.0005

# %%
num_nn_train = [13, 2] #30
num_nn_test = [15]
radius_nn_predict = [0.005]
radius_sub_nn_predict = [0.0005]

# %%
# %%time

for nn_train in num_nn_train:
    for nn_test in num_nn_test:
        for nn_predint in radius_nn_predict:
            for sub_nn_predict in radius_sub_nn_predict:

                start_time = datetime.now()

                tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                                          show_summary=False, show_loss_plot=False, show_rmse=True, 
                                          mdl_wts_file='weights/tnnr_nn_test_64_Fnormal_n' + str(n) + '_inverse_a' + str(a),
                                          neurons=128,
                                          num_nn_train=nn_train,
                                          num_nn_test=nn_test,
                                          radius_nn_predict=nn_predint,
                                          radius_sub_nn_predict=sub_nn_predict)

                end_time = datetime.now()
                print('Duration:              {}'.format(end_time - start_time))
                print('num_nn_train:          {}'.format(nn_train))
                print('num_nn_test:           {}'.format(nn_test))
                print('radius_nn_predict:     {}'.format(nn_predint))
                print('radius_sub_nn_predict: {}'.format(sub_nn_predict))
                print()
                
                del tnnr_nn_test_64
                del start_time
                del end_time
                gc.collect()
# Out:
# Test RMSE: 0.010318233204709471
# Duration:              0:23:32.721295
# num_nn_train:          13
# num_nn_test:           15
# radius_nn_predict:     0.005
# radius_sub_nn_predict: 0.0005
#
# Test RMSE: 0.010334390467818694
# Duration:              0:23:19.520589
# num_nn_train:          2
# num_nn_test:           15
# radius_nn_predict:     0.005
# radius_sub_nn_predict: 0.0005
#
# CPU times: user 1h 55min, sys: 2h 28min 2s, total: 4h 23min 2s
# Wall time: 46min 52s
