# %%
from TwinNeuralNetwork import TNNR, ANNR
import matplotlib.pyplot as plt

# %%
def_func = lambda a: lambda x: x**3 - a*x

# %%
# %%time

seed = 392
a = -80
n = 500

annr_64 = ANNR(def_func(a), n=n, seed=seed, inverse_problem=True,
               show_summary=False, show_loss_plot=False, show_rmse=False, 
               mdl_wts_file='annr64n500inverse')
annr_64.rmse_test
# Out:
# CPU times: user 2min 8s, sys: 23.3 s, total: 2min 31s
# Wall time: 1min 40s
# 58.640805071740765

# %%
plt.scatter(annr_64.cn_transformer.inverse_transform_x(annr_64.x_train_single), 
            annr_64.cn_transformer.inverse_transform_y(annr_64.y_train_single),
            label='Train data set', s=1, c='#99ffff')
plt.scatter(annr_64.x_pred_test,
            annr_64.cn_transformer.inverse_transform_y(annr_64.y_test_single),
            label='ANNR $2\\times 64$ neurons', s=30)
plt.title('Function: $x^3 + 80x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()

# %%
# %%time

seed = 262
a = 80
n = 500

annr_64 = ANNR(def_func(a), n=n, seed=seed, inverse_problem=True,
               show_summary=False, show_loss_plot=False, show_rmse=False, 
               mdl_wts_file='annr64n500inverse')
annr_64.rmse_test
# Out:
# CPU times: user 34.1 s, sys: 6.18 s, total: 40.3 s
# Wall time: 26.5 s
# 35.76155655467645

# %%
plt.scatter(annr_64.cn_transformer.inverse_transform_x(annr_64.x_train_single), 
            annr_64.cn_transformer.inverse_transform_y(annr_64.y_train_single),
            label='Train data set', s=1, c='#99ffff')
plt.scatter(annr_64.x_pred_test,
            annr_64.cn_transformer.inverse_transform_y(annr_64.y_test_single),
            label='ANNR $2\\times 64$ neurons', s=30)
plt.title('Function: $x^3 - 80x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()

# %% [markdown]
# --------------

# %%
# %%time

seed = 392
a = -5
n = 500

annr_64 = ANNR(def_func(a), n=n, seed=seed, inverse_problem=True,
               show_summary=False, show_loss_plot=False, show_rmse=False, 
               mdl_wts_file='annr64n500inverse')
annr_64.rmse_test
# Out:
# CPU times: user 1min 24s, sys: 14.5 s, total: 1min 39s
# Wall time: 1min 4s
# 58.55920041470864

# %%
plt.scatter(annr_64.cn_transformer.inverse_transform_x(annr_64.x_train_single), 
            annr_64.cn_transformer.inverse_transform_y(annr_64.y_train_single),
            label='Train data set', s=1, c='#99ffff')
plt.scatter(annr_64.x_pred_test,
            annr_64.cn_transformer.inverse_transform_y(annr_64.y_test_single),
            label='ANNR $2\\times 64$ neurons', s=30)
plt.title('Function: $x^3 + 5x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()

# %%
# %%time

seed = 262
a = 5
n = 500

annr_64 = ANNR(def_func(a), n=n, seed=seed, inverse_problem=True,
               show_summary=False, show_loss_plot=False, show_rmse=False, 
               mdl_wts_file='annr64n500inverse')
annr_64.rmse_test
# Out:
# CPU times: user 1min 1s, sys: 11.1 s, total: 1min 12s
# Wall time: 47.9 s
# 55.744171349479586

# %%
plt.scatter(annr_64.cn_transformer.inverse_transform_x(annr_64.x_train_single), 
            annr_64.cn_transformer.inverse_transform_y(annr_64.y_train_single),
            label='Train data set', s=1, c='#99ffff')
plt.scatter(annr_64.x_pred_test,
            annr_64.cn_transformer.inverse_transform_y(annr_64.y_test_single),
            label='ANNR $2\\times 64$ neurons', s=30)
plt.title('Function: $x^3 - 5x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()

# %% [markdown]
# -------------

# %%
# %%time

seed = 392
a = -30
n = 500

annr_64 = ANNR(def_func(a), n=n, seed=seed, inverse_problem=True,
               show_summary=False, show_loss_plot=False, show_rmse=False, 
               mdl_wts_file='annr64n500inverse')
annr_64.rmse_test
# Out:
# CPU times: user 1min 28s, sys: 15.9 s, total: 1min 44s
# Wall time: 1min 9s
# 58.59948814205806

# %%
plt.scatter(annr_64.cn_transformer.inverse_transform_x(annr_64.x_train_single), 
            annr_64.cn_transformer.inverse_transform_y(annr_64.y_train_single),
            label='Train data set', s=1, c='#99ffff')
plt.scatter(annr_64.x_pred_test,
            annr_64.cn_transformer.inverse_transform_y(annr_64.y_test_single),
            label='ANNR $2\\times 64$ neurons', s=30)
plt.title('Function: $x^3 + 30x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()

# %%
# %%time

seed = 262
a = 30
n = 500

annr_64 = ANNR(def_func(a), n=n, seed=seed, inverse_problem=True,
               show_summary=False, show_loss_plot=False, show_rmse=False, 
               mdl_wts_file='annr64n500inverse')
annr_64.rmse_test
# Out:
# CPU times: user 1min 38s, sys: 17.5 s, total: 1min 56s
# Wall time: 1min 18s
# 51.221170467207216

# %%
plt.scatter(annr_64.cn_transformer.inverse_transform_x(annr_64.x_train_single), 
            annr_64.cn_transformer.inverse_transform_y(annr_64.y_train_single),
            label='Train data set', s=1, c='#99ffff')
plt.scatter(annr_64.x_pred_test,
            annr_64.cn_transformer.inverse_transform_y(annr_64.y_test_single),
            label='ANNR $2\\times 64$ neurons', s=30)
plt.title('Function: $x^3 - 30x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()
