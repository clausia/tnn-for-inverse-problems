# %%
import sys
sys.path.append("..")

from TwinNeuralNetworkNearestNeighbors import TNNR_NN

import matplotlib.pyplot as plt

import numpy as np

# %%
def_func = lambda a: lambda x: x**3 - a*x

# %%
n = 2100
seed = 9876

a = 70

# %%
# %%time

tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                          show_summary=False, show_loss_plot=True, show_rmse=True, 
                          mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                          num_nn_train=5,
                          num_nn_test=10,
                          radius_nn_predict=0.02,
                          radius_sub_nn_predict=0.01)
# Out:
# Test RMSE: 0.026787581868834554
# CPU times: user 35min 25s, sys: 43min 37s, total: 1h 19min 3s
# Wall time: 10min 28s

# %%
plt.scatter(tnnr_nn_test_64.cn_transformer.inverse_transform_x(tnnr_nn_test_64.x_train_single), 
            tnnr_nn_test_64.cn_transformer.inverse_transform_y(tnnr_nn_test_64.y_train_single),
            label='Train data set', s=1, c='#99ffff')
plt.scatter(tnnr_nn_test_64.x_pred_test,
            tnnr_nn_test_64.y_pred_test,
            label='TNNR NN, $2\\times 64$ neurons', s=15)

plt.title('Function: $x^3 - 70x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()

# %%
len(tnnr_nn_test_64.x_pred_test)
# Out:
# 4200

# %%
# %%time

# como antes, sin usar los circulos naranjas

tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                          show_summary=False, show_loss_plot=True, show_rmse=True, 
                          mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                          num_nn_train=5,
                          no_use_nn=True)
# Out:
# Test RMSE: 6.851771447678038
# CPU times: user 3min 56s, sys: 41.2 s, total: 4min 38s
# Wall time: 3min 11s

# %%
plt.scatter(tnnr_nn_test_64.cn_transformer.inverse_transform_x(tnnr_nn_test_64.x_train_single), 
            tnnr_nn_test_64.cn_transformer.inverse_transform_y(tnnr_nn_test_64.y_train_single),
            label='Train data set', s=1, c='#99ffff')
plt.scatter(tnnr_nn_test_64.x_pred_test,
            tnnr_nn_test_64.cn_transformer.inverse_transform_y(tnnr_nn_test_64.y_test_single),
            label='TNNR NN, $2\\times 64$ neurons', s=15)

plt.title('Function: $x^3 - 70x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()

# %%
# %%time

# pocos vecinos en la predicción

tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                          show_summary=False, show_loss_plot=True, show_rmse=True, 
                          mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                          num_nn_train=5,
                          num_nn_test=2,
                          radius_nn_predict=0.02,
                          radius_sub_nn_predict=0.01)
# Out:
# Test RMSE: 0.026938296925172786
# CPU times: user 10min 23s, sys: 9min 4s, total: 19min 27s
# Wall time: 4min 34s

# %%
plt.scatter(tnnr_nn_test_64.cn_transformer.inverse_transform_x(tnnr_nn_test_64.x_train_single), 
            tnnr_nn_test_64.cn_transformer.inverse_transform_y(tnnr_nn_test_64.y_train_single),
            label='Train data set', s=1, c='#99ffff')
plt.scatter(tnnr_nn_test_64.x_pred_test,
            tnnr_nn_test_64.y_pred_test,
            label='TNNR NN, $2\\times 64$ neurons', s=15)

plt.title('Function: $x^3 - 70x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()

# %%
len(tnnr_nn_test_64.x_pred_test)
# Out:
# 840

# %%
# %%time

# muchos vecinos para la preducción

tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                          show_summary=False, show_loss_plot=True, show_rmse=True, 
                          mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                          num_nn_train=5,
                          num_nn_test=20,
                          radius_nn_predict=0.02,
                          radius_sub_nn_predict=0.01)
# Out:
# Test RMSE: 0.026708880940344914
# CPU times: user 1h 8min 38s, sys: 1h 25min 8s, total: 2h 33min 46s
# Wall time: 18min 13s

# %%
plt.scatter(tnnr_nn_test_64.cn_transformer.inverse_transform_x(tnnr_nn_test_64.x_train_single), 
            tnnr_nn_test_64.cn_transformer.inverse_transform_y(tnnr_nn_test_64.y_train_single),
            label='Train data set', s=1, c='#99ffff')
plt.scatter(tnnr_nn_test_64.x_pred_test,
            tnnr_nn_test_64.y_pred_test,
            label='TNNR NN, $2\\times 64$ neurons', s=15)

plt.title('Function: $x^3 - 70x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()

# %%
# %%time

# con ruido en rango uniforme en los puntos

tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                          show_summary=False, show_loss_plot=True, show_rmse=True, 
                          mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                          num_nn_train=5,
                          num_nn_test=10,
                          radius_nn_predict=0.02,
                          radius_sub_nn_predict=0.01,
                          noise_range_x=(-0.5, 0.5),
                          noise_range_y=(-1, 1))
# Out:
# Test RMSE: 0.027159232085256786
# CPU times: user 34min 6s, sys: 42min 15s, total: 1h 16min 22s
# Wall time: 10min 16s

# %%
plt.scatter(tnnr_nn_test_64.cn_transformer.inverse_transform_x(tnnr_nn_test_64.x_train_single), 
            tnnr_nn_test_64.cn_transformer.inverse_transform_y(tnnr_nn_test_64.y_train_single),
            label='Train data set', s=10, c='#99ffff')
plt.scatter(tnnr_nn_test_64.x_pred_test,
            tnnr_nn_test_64.y_pred_test,
            label='TNNR NN, $2\\times 64$ neurons', s=3)

plt.title('Function: $x^3 - 70x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()

# %%
plt.scatter(tnnr_nn_test_64.cn_transformer.inverse_transform_x(tnnr_nn_test_64.x_train_single), 
            tnnr_nn_test_64.cn_transformer.inverse_transform_y(tnnr_nn_test_64.y_train_single),
            label='Train data set', s=3, c='#99ffff')

plt.title('Function: $x^3 - 70x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()

# %%
len(tnnr_nn_test_64.x_pred_test)
# Out:
# 4200

# %%
len(tnnr_nn_test_64.x_train_single)
# Out:
# 1260

# %%
# %%time

# con ruido gaussiano en los puntos

tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                          show_summary=False, show_loss_plot=True, show_rmse=True, 
                          mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                          num_nn_train=5,
                          num_nn_test=10,
                          radius_nn_predict=0.02,
                          radius_sub_nn_predict=0.01,
                          noise_normal_x=(0, 0.1),
                          noise_normal_y=(0, 1))
# Out:
# Test RMSE: 0.02656686207618051
# CPU times: user 34min, sys: 42min 56s, total: 1h 16min 57s
# Wall time: 9min 30s

# %%
plt.scatter(tnnr_nn_test_64.cn_transformer.inverse_transform_x(tnnr_nn_test_64.x_train_single), 
            tnnr_nn_test_64.cn_transformer.inverse_transform_y(tnnr_nn_test_64.y_train_single),
            label='Train data set', s=10, c='#99ffff')
plt.scatter(tnnr_nn_test_64.x_pred_test,
            tnnr_nn_test_64.y_pred_test,
            label='TNNR NN, $2\\times 64$ neurons', s=3)

plt.title('Function: $x^3 - 70x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()

# %%
plt.scatter(tnnr_nn_test_64.cn_transformer.inverse_transform_x(tnnr_nn_test_64.x_train_single), 
            tnnr_nn_test_64.cn_transformer.inverse_transform_y(tnnr_nn_test_64.y_train_single),
            label='Train data set', s=3, c='#99ffff')

plt.title('Function: $x^3 - 70x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()

# %%
# %%time

# con mucho ruido gaussiano en los puntos

tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                          show_summary=False, show_loss_plot=True, show_rmse=True, 
                          mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                          num_nn_train=5,
                          num_nn_test=10,
                          radius_nn_predict=0.02,
                          radius_sub_nn_predict=0.01,
                          noise_normal_x=(0, 0.5),
                          noise_normal_y=(0, 5))
# Out:
# Test RMSE: 0.028179945525242684
# CPU times: user 34min 1s, sys: 42min, total: 1h 16min 2s
# Wall time: 11min 19s

# %%
plt.scatter(tnnr_nn_test_64.cn_transformer.inverse_transform_x(tnnr_nn_test_64.x_train_single), 
            tnnr_nn_test_64.cn_transformer.inverse_transform_y(tnnr_nn_test_64.y_train_single),
            label='Train data set', s=10, c='#99ffff')
plt.scatter(tnnr_nn_test_64.x_pred_test,
            tnnr_nn_test_64.y_pred_test,
            label='TNNR NN, $2\\times 64$ neurons', s=3)

plt.title('Function: $x^3 - 70x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()

# %%
plt.scatter(tnnr_nn_test_64.cn_transformer.inverse_transform_x(tnnr_nn_test_64.x_train_single), 
            tnnr_nn_test_64.cn_transformer.inverse_transform_y(tnnr_nn_test_64.y_train_single),
            label='Train data set', s=3, c='#99ffff')

plt.title('Function: $x^3 - 70x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()

# %%
# %%time

# con mucho ruido gaussiano en los puntos

tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                          show_summary=False, show_loss_plot=True, show_rmse=True, 
                          mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                          num_nn_train=5,
                          num_nn_test=5,
                          radius_nn_predict=0.02,
                          radius_sub_nn_predict=0.01,
                          noise_normal_x=(0, 0.5),
                          noise_normal_y=(0, 5))
# Out:
# Test RMSE: 0.027872170059231496
# CPU times: user 20min 14s, sys: 22min 4s, total: 42min 19s
# Wall time: 7min 3s

# %%
plt.scatter(tnnr_nn_test_64.cn_transformer.inverse_transform_x(tnnr_nn_test_64.x_train_single), 
            tnnr_nn_test_64.cn_transformer.inverse_transform_y(tnnr_nn_test_64.y_train_single),
            label='Train data set', s=10, c='#99ffff')
plt.scatter(tnnr_nn_test_64.x_pred_test,
            tnnr_nn_test_64.y_pred_test,
            label='TNNR NN, $2\\times 64$ neurons', s=3)

plt.title('Function: $x^3 - 70x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()

# %%
plt.scatter(tnnr_nn_test_64.cn_transformer.inverse_transform_x(tnnr_nn_test_64.x_train_single), 
            tnnr_nn_test_64.cn_transformer.inverse_transform_y(tnnr_nn_test_64.y_train_single),
            label='Train data set', s=3, c='#99ffff')

plt.title('Function: $x^3 - 70x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()

# %%
# %%time

# setting F=0 when predicting

tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                          show_summary=False, show_loss_plot=True, show_rmse=True, 
                          mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                          num_nn_train=5,
                          num_nn_test=10,
                          radius_nn_predict=0.02,
                          radius_sub_nn_predict=0.01,
                          zero_F_training=True)
# Out:
# Test RMSE: 0.026821735178188158
# CPU times: user 35min 11s, sys: 42min 33s, total: 1h 17min 44s
# Wall time: 10min 32s

# %%
plt.scatter(tnnr_nn_test_64.cn_transformer.inverse_transform_x(tnnr_nn_test_64.x_train_single), 
            tnnr_nn_test_64.cn_transformer.inverse_transform_y(tnnr_nn_test_64.y_train_single),
            label='Train data set', s=10, c='#99ffff')
plt.scatter(tnnr_nn_test_64.x_pred_test,
            tnnr_nn_test_64.y_pred_test,
            label='TNNR NN, $2\\times 64$ neurons', s=3)

plt.title('Function: $x^3 - 70x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()

# %%
# %%time

# setting F=0 when predicting

tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                          show_summary=False, show_loss_plot=True, show_rmse=True, 
                          mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                          num_nn_train=5,
                          num_nn_test=10,
                          radius_nn_predict=0.02,
                          radius_sub_nn_predict=0.01,
                          zero_F_training=False,
                          zero_F_testing=True)
# Out:
# Test RMSE: 0.026821735178188172
# CPU times: user 34min 12s, sys: 40min 58s, total: 1h 15min 10s
# Wall time: 10min 23s

# %%
plt.scatter(tnnr_nn_test_64.cn_transformer.inverse_transform_x(tnnr_nn_test_64.x_train_single), 
            tnnr_nn_test_64.cn_transformer.inverse_transform_y(tnnr_nn_test_64.y_train_single),
            label='Train data set', s=10, c='#99ffff')
plt.scatter(tnnr_nn_test_64.x_pred_test,
            tnnr_nn_test_64.y_pred_test,
            label='TNNR NN, $2\\times 64$ neurons', s=3)

plt.title('Function: $x^3 - 70x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()

# %%
# different function

def_func2 = lambda a: lambda x: a*x**2

# %%
# %%time

tnnr_nn_test_64 = TNNR_NN(def_func2(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                          show_summary=False, show_loss_plot=True, show_rmse=True, 
                          mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                          num_nn_train=5,
                          num_nn_test=10,
                          radius_nn_predict=0.02,
                          radius_sub_nn_predict=0.01)
# Out:
# Test RMSE: 0.02721383907623308
# CPU times: user 34min 43s, sys: 41min 47s, total: 1h 16min 30s
# Wall time: 10min 15s

# %%
plt.scatter(tnnr_nn_test_64.cn_transformer.inverse_transform_x(tnnr_nn_test_64.x_train_single), 
            tnnr_nn_test_64.cn_transformer.inverse_transform_y(tnnr_nn_test_64.y_train_single),
            label='Train data set', s=1, c='#99ffff')
plt.scatter(tnnr_nn_test_64.x_pred_test,
            tnnr_nn_test_64.y_pred_test,
            label='TNNR NN, $2\\times 64$ neurons', s=15)

plt.title('Function: $70x^2$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()

# %%
# different function

def_func3 = lambda a: lambda x: a*np.sin(x)

# %%
# %%time

tnnr_nn_test_64 = TNNR_NN(def_func3(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                          show_summary=False, show_loss_plot=True, show_rmse=True, 
                          mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                          num_nn_train=5,
                          num_nn_test=10,
                          radius_nn_predict=0.02,
                          radius_sub_nn_predict=0.01)
# Out:
# Test RMSE: 0.026938874556944686
# CPU times: user 22min 22s, sys: 25min 52s, total: 48min 15s
# Wall time: 11min 11s

# %%
plt.scatter(tnnr_nn_test_64.cn_transformer.inverse_transform_x(tnnr_nn_test_64.x_train_single), 
            tnnr_nn_test_64.cn_transformer.inverse_transform_y(tnnr_nn_test_64.y_train_single),
            label='Train data set', s=1, c='#99ffff')
plt.scatter(tnnr_nn_test_64.x_pred_test,
            tnnr_nn_test_64.y_pred_test,
            label='TNNR NN, $2\\times 64$ neurons', s=15)

plt.title('Function: $70\; \sin(x)$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()

# %%
# %%time

# con F=0 en training

tnnr_nn_test_64 = TNNR_NN(def_func3(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                          show_summary=False, show_loss_plot=True, show_rmse=True, 
                          mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                          num_nn_train=5,
                          num_nn_test=10,
                          radius_nn_predict=0.02,
                          radius_sub_nn_predict=0.01,
                          zero_F_training=True)
# Out:
# Test RMSE: 0.026800725994253136
# CPU times: user 21min 49s, sys: 24min 54s, total: 46min 44s
# Wall time: 10min 58s

# %%
plt.scatter(tnnr_nn_test_64.cn_transformer.inverse_transform_x(tnnr_nn_test_64.x_train_single), 
            tnnr_nn_test_64.cn_transformer.inverse_transform_y(tnnr_nn_test_64.y_train_single),
            label='Train data set', s=1, c='#99ffff')
plt.scatter(tnnr_nn_test_64.x_pred_test,
            tnnr_nn_test_64.y_pred_test,
            label='TNNR NN, $2\\times 64$ neurons', s=15)

plt.title('Function: $70\; \sin(x)$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()

# %%
# different function

def_func4 = lambda a: lambda x: np.cos(x*4)

# %%
# %%time

tnnr_nn_test_64 = TNNR_NN(def_func4(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                          show_summary=False, show_loss_plot=True, show_rmse=True, 
                          mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                          num_nn_train=5,
                          num_nn_test=10,
                          radius_nn_predict=0.02,
                          radius_sub_nn_predict=0.01)
# Out:
# Test RMSE: 0.027171057574222807
# CPU times: user 43min 24s, sys: 41min 26s, total: 1h 24min 51s
# Wall time: 10min 36s

# %%
plt.plot(np.arange(-10, 10, 0.01), 
         def_func4(a)(np.arange(-10, 10, 0.01)),
         label='Continuos function', c='#ebd234', linewidth=0.4)
plt.scatter(tnnr_nn_test_64.cn_transformer.inverse_transform_x(tnnr_nn_test_64.x_train_single), 
            tnnr_nn_test_64.cn_transformer.inverse_transform_y(tnnr_nn_test_64.y_train_single),
            label='Train data set', s=1, c='#99ffff')
plt.scatter(tnnr_nn_test_64.x_pred_test,
            tnnr_nn_test_64.y_pred_test,
            label='TNNR NN, $2\\times 64$ neurons', s=15)

plt.title('Function: $\cos(4x)$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()

# %%
# %%time

# con F=0 en training

tnnr_nn_test_64 = TNNR_NN(def_func4(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                          show_summary=False, show_loss_plot=True, show_rmse=True, 
                          mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                          num_nn_train=5,
                          num_nn_test=10,
                          radius_nn_predict=0.02,
                          radius_sub_nn_predict=0.01,
                          zero_F_training=True)
# Out:
# Test RMSE: 0.026986744339976027
# CPU times: user 21min 30s, sys: 24min 44s, total: 46min 14s
# Wall time: 10min 46s

# %%
plt.plot(np.arange(-10, 10, 0.01), 
         def_func4(a)(np.arange(-10, 10, 0.01)),
         label='Continuos function', c='#ebd234', linewidth=0.4)
plt.scatter(tnnr_nn_test_64.cn_transformer.inverse_transform_x(tnnr_nn_test_64.x_train_single), 
            tnnr_nn_test_64.cn_transformer.inverse_transform_y(tnnr_nn_test_64.y_train_single),
            label='Train data set', s=1, c='#99ffff')
plt.scatter(tnnr_nn_test_64.x_pred_test,
            tnnr_nn_test_64.y_pred_test,
            label='TNNR NN, $2\\times 64$ neurons', s=15)

plt.title('Function: $\cos(4x)$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()

# %%
# different function

def_func5 = lambda a: lambda x: np.sin(x)/(a*x)

# %%
# %%time

tnnr_nn_test_64 = TNNR_NN(def_func5(0.1), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                          show_summary=False, show_loss_plot=True, show_rmse=True, 
                          mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                          num_nn_train=5,
                          num_nn_test=10,
                          radius_nn_predict=0.02,
                          radius_sub_nn_predict=0.01)
# Out:
# Test RMSE: 0.027642762512869606
# CPU times: user 40min 26s, sys: 39min 52s, total: 1h 20min 18s
# Wall time: 10min 48s

# %%
plt.plot(np.arange(-10, 10, 0.01), 
         def_func5(0.1)(np.arange(-10, 10, 0.01)),
         label='Continuos function', c='#ebd234', linewidth=0.4)
plt.scatter(tnnr_nn_test_64.cn_transformer.inverse_transform_x(tnnr_nn_test_64.x_train_single), 
            tnnr_nn_test_64.cn_transformer.inverse_transform_y(tnnr_nn_test_64.y_train_single),
            label='Train data set', s=35, c='#99ffff')
plt.scatter(tnnr_nn_test_64.x_pred_test,
            tnnr_nn_test_64.y_pred_test,
            label='TNNR NN, $2\\times 64$ neurons', s=15)

plt.title('Function: $\cos(4x)$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()

# %% [markdown]
# ------------

# %% [markdown]
# ------------

# %%
import sys
sys.path.append("..")

from TwinNeuralNetworkNearestNeighbors import TNNR_NN

import matplotlib.pyplot as plt

import numpy as np

from datetime import datetime

import gc

# %%
def_func = lambda a: lambda x: x**3 - a*x

# %%
n = 2100
seed = 23497

a = 70

# %%
# %%time

tnnr_nn_test_64_fnorm = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                                show_summary=False, show_loss_plot=True, show_rmse=True, 
                                mdl_wts_file='weights/tnnr_nn_test_64_fnorm_n' + str(n) + '_inverse_a' + str(a),
                                num_nn_train=13,
                                num_nn_test=15,
                                radius_nn_predict=0.005,
                                radius_sub_nn_predict=0.0005)
# Out:
# Test RMSE: 0.010317235673056221
# CPU times: user 1h 42min 25s, sys: 1h 43min 32s, total: 3h 25min 58s
# Wall time: 22min 4s

# %%
gc.collect()
# Out:
# 74602

# %%
# %%time

tnnr_nn_test_64_fzero = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                                show_summary=False, show_loss_plot=True, show_rmse=True, 
                                mdl_wts_file='weights/tnnr_nn_test_64_fzero_n' + str(n) + '_inverse_a' + str(a),
                                num_nn_train=13,
                                num_nn_test=15,
                                radius_nn_predict=0.005,
                                radius_sub_nn_predict=0.0005,
                                zero_F_training=True)
# Out:
# Test RMSE: 0.010317383310882654
# CPU times: user 1h 43min 15s, sys: 1h 42min 31s, total: 3h 25min 46s
# Wall time: 22min 1s

# %%
plt.plot(tnnr_nn_test_64_fnorm.train_history.history['loss'], label='Train (normal F)')
plt.plot(tnnr_nn_test_64_fnorm.train_history.history['val_loss'], label='Val (normal F)')

plt.plot(tnnr_nn_test_64_fzero.train_history.history['loss'], label='Train (F = 0)')
plt.plot(tnnr_nn_test_64_fzero.train_history.history['val_loss'], label='Val (F = 0)')

plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')

# %%
plt.scatter(tnnr_nn_test_64_fnorm.cn_transformer.inverse_transform_x(tnnr_nn_test_64_fnorm.x_train_single), 
            tnnr_nn_test_64_fnorm.cn_transformer.inverse_transform_y(tnnr_nn_test_64_fnorm.y_train_single),
            label='Train data set', s=40, c='#99ffff')
plt.scatter(tnnr_nn_test_64_fnorm.x_pred_test,
            tnnr_nn_test_64_fnorm.y_pred_test,
            label='TNNR NN, Normal F, $2\\times 64$ neurons', s=15)
plt.scatter(tnnr_nn_test_64_fnorm.x_pred_test,
            tnnr_nn_test_64_fnorm.y_pred_test,
            label='TNNR NN, F = 0, $2\\times 64$ neurons', s=3)

plt.title('Function: $x^3 - 70x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()

# %% [markdown]
# ------------

# %%
import sys
sys.path.append("..")

from TwinNeuralNetworkNearestNeighbors import TNNR_NN

import matplotlib.pyplot as plt

import numpy as np

from datetime import datetime

import gc

# %%
def_func = lambda a: lambda x: x**3 - a*x

# %%
n = 2100
seed = 2349

a = -70

# %%
# %%time

tnnr_nn_test_64_fnorm = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                                show_summary=False, show_loss_plot=True, show_rmse=True, 
                                mdl_wts_file='weights/tnnr_nn_test_64_fnorm_n' + str(n) + '_inverse_a' + str(a),
                                num_nn_train=13,
                                num_nn_test=15,
                                radius_nn_predict=0.005,
                                radius_sub_nn_predict=0.0005)
# Out:
# Test RMSE: 0.01020671309403946
# CPU times: user 1h 41min 41s, sys: 1h 41min 1s, total: 3h 22min 42s
# Wall time: 23min 25s

# %%
gc.collect()
# Out:
# 62947

# %%
# %%time

tnnr_nn_test_64_fzero = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                                show_summary=False, show_loss_plot=True, show_rmse=True, 
                                mdl_wts_file='weights/tnnr_nn_test_64_fzero_n' + str(n) + '_inverse_a' + str(a),
                                num_nn_train=13,
                                num_nn_test=15,
                                radius_nn_predict=0.005,
                                radius_sub_nn_predict=0.0005,
                                zero_F_training=True)
# Out:
# Test RMSE: 0.010183002287883682
# CPU times: user 1h 39min 26s, sys: 1h 40min 13s, total: 3h 19min 40s
# Wall time: 22min 3s

# %%
plt.plot(tnnr_nn_test_64_fnorm.train_history.history['loss'], label='Train (normal F)')
plt.plot(tnnr_nn_test_64_fnorm.train_history.history['val_loss'], label='Val (normal F)')

plt.plot(tnnr_nn_test_64_fzero.train_history.history['loss'], label='Train (F = 0)')
plt.plot(tnnr_nn_test_64_fzero.train_history.history['val_loss'], label='Val (F = 0)')

plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')

# %%
plt.scatter(tnnr_nn_test_64_fnorm.cn_transformer.inverse_transform_x(tnnr_nn_test_64_fnorm.x_train_single), 
            tnnr_nn_test_64_fnorm.cn_transformer.inverse_transform_y(tnnr_nn_test_64_fnorm.y_train_single),
            label='Train data set', s=40, c='#99ffff')
plt.scatter(tnnr_nn_test_64_fnorm.x_pred_test,
            tnnr_nn_test_64_fnorm.y_pred_test,
            label='TNNR NN, Normal F, $2\\times 64$ neurons', s=15)
plt.scatter(tnnr_nn_test_64_fnorm.x_pred_test,
            tnnr_nn_test_64_fnorm.y_pred_test,
            label='TNNR NN, F = 0, $2\\times 64$ neurons', s=3)

plt.title('Function: $x^3 + 70x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()

# %%
0.01020671309403946-0.010183002287883682
# Out:
# 2.3710806155777253e-05
