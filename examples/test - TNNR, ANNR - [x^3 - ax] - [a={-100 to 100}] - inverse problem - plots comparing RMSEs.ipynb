# %%
from TwinNeuralNetwork import TNNR, ANNR
import matplotlib.pyplot as plt
import numpy as np

# %%
def_func = lambda a: lambda x: x**3 - a*x

# %%
# %%time

n = 1000
seed = 25389
rmses = []
nns = []

for a in np.arange(-100, 101, 10):
    
    tnnr_64 = TNNR(def_func(a), n=n, seed=seed, inverse_problem=True,
                   show_summary=False, show_loss_plot=False, show_rmse=False, 
               mdl_wts_file='weights/tnnr64_n' + str(n) + '_inverse_a' + str(a))
    annr_64 = ANNR(def_func(a), n=n, seed=seed, inverse_problem=True,
                   show_summary=False, show_loss_plot=False, show_rmse=False, 
               mdl_wts_file='weights/annr64_n' + str(n) + '_inverse_a' + str(a))
    
    tnnr_128 = TNNR(def_func(a), n=n, seed=seed, neurons=128, inverse_problem=True,
                    show_summary=False, show_loss_plot=False, show_rmse=False, 
               mdl_wts_file='weights/tnnr128_n' + str(n) + '_inverse_a' + str(a))
    annr_128 = ANNR(def_func(a), n=n, seed=seed, neurons=128, inverse_problem=True,
                    show_summary=False, show_loss_plot=False, show_rmse=False, 
               mdl_wts_file='weights/annr128_n' + str(n) + '_inverse_a' + str(a))
    
    rmses.append([tnnr_64.rmse_test, annr_64.rmse_test, tnnr_128.rmse_test, annr_128.rmse_test])
    nns.append([tnnr_64, annr_64, tnnr_128, annr_128])
    
    seed += 73
# Out:
# CPU times: user 3h 35min 35s, sys: 1h 1min 42s, total: 4h 37min 18s
# Wall time: 2h 35min 15s

# %%
plt.plot(np.arange(-100, 101, 10), np.array(rmses)[:,0], label='TNNR $2\\times 64$ neurons')
plt.plot(np.arange(-x100, 101, 10), np.array(rmses)[:,1], label='ANNR $2\\times 64$ neurons')
plt.plot(np.arange(-100, 101, 10), np.array(rmses)[:,2], label='TNNR $2\\times 128$ neurons')
plt.plot(np.arange(-100, 101, 10), np.array(rmses)[:,3], label='ANNR $2\\times 128$ neurons')

plt.title('Function: $x^3 - ax$')
plt.xlabel('a')
plt.ylabel('RMSE')
plt.legend()

# %%
# %%time

n = 1000
seed = 239
rmses = []
nns = []

for a in np.arange(-100, 101, 10):
    
    tnnr_64 = TNNR(def_func(a), n=n, seed=seed, inverse_problem=True,
                   show_summary=False, show_loss_plot=False, show_rmse=False, 
               mdl_wts_file='weights/tnnr64_n' + str(n) + '_inverse_a' + str(a))
    annr_64 = ANNR(def_func(a), n=n, seed=seed, inverse_problem=True,
                   show_summary=False, show_loss_plot=False, show_rmse=False, 
               mdl_wts_file='weights/annr64_n' + str(n) + '_inverse_a' + str(a))
    
    tnnr_128 = TNNR(def_func(a), n=n, seed=seed, neurons=128, inverse_problem=True,
                    show_summary=False, show_loss_plot=False, show_rmse=False, 
               mdl_wts_file='weights/tnnr128_n' + str(n) + '_inverse_a' + str(a))
    annr_128 = ANNR(def_func(a), n=n, seed=seed, neurons=128, inverse_problem=True,
                    show_summary=False, show_loss_plot=False, show_rmse=False, 
               mdl_wts_file='weights/annr128_n' + str(n) + '_inverse_a' + str(a))
    
    rmses.append([tnnr_64.rmse_test, annr_64.rmse_test, tnnr_128.rmse_test, annr_128.rmse_test])
    nns.append([tnnr_64, annr_64, tnnr_128, annr_128])
    
    seed += 23
# Out:
# CPU times: user 3h 28min 33s, sys: 57min 14s, total: 4h 25min 47s
# Wall time: 2h 28min 39s

# %%
plt.plot(np.arange(-100, 101, 10), np.array(rmses)[:,0], label='TNNR $2\\times 64$ neurons')
plt.plot(np.arange(-100, 101, 10), np.array(rmses)[:,1], label='ANNR $2\\times 64$ neurons')
plt.plot(np.arange(-100, 101, 10), np.array(rmses)[:,2], label='TNNR $2\\times 128$ neurons')
plt.plot(np.arange(-100, 101, 10), np.array(rmses)[:,3], label='ANNR $2\\times 128$ neurons')

plt.title('Function: $x^3 - ax$')
plt.xlabel('a')
plt.ylabel('RMSE')
plt.legend()

# %%
# %%time

n = 1000
seed = 232349
rmses = []
nns = []

for a in np.arange(-100, 101, 10):
    
    tnnr_64 = TNNR(def_func(a), n=n, seed=seed, inverse_problem=True,
                   show_summary=False, show_loss_plot=False, show_rmse=False, 
               mdl_wts_file='weights/tnnr64_n' + str(n) + '_inverse_a' + str(a))
    annr_64 = ANNR(def_func(a), n=n, seed=seed, inverse_problem=True,
                   show_summary=False, show_loss_plot=False, show_rmse=False, 
               mdl_wts_file='weights/annr64_n' + str(n) + '_inverse_a' + str(a))
    
    tnnr_128 = TNNR(def_func(a), n=n, seed=seed, neurons=128, inverse_problem=True,
                    show_summary=False, show_loss_plot=False, show_rmse=False, 
               mdl_wts_file='weights/tnnr128_n' + str(n) + '_inverse_a' + str(a))
    annr_128 = ANNR(def_func(a), n=n, seed=seed, neurons=128, inverse_problem=True,
                    show_summary=False, show_loss_plot=False, show_rmse=False, 
               mdl_wts_file='weights/annr128_n' + str(n) + '_inverse_a' + str(a))
    
    rmses.append([tnnr_64.rmse_test, annr_64.rmse_test, tnnr_128.rmse_test, annr_128.rmse_test])
    #nns.append([tnnr_64, annr_64, tnnr_128, annr_128])
    
    seed += 783
# Out:
# CPU times: user 3h 33min 6s, sys: 57min 30s, total: 4h 30min 36s
# Wall time: 2h 31min 56s

# %%
plt.plot(np.arange(-100, 101, 10), np.array(rmses)[:,0], label='TNNR $2\\times 64$ neurons')
plt.plot(np.arange(-100, 101, 10), np.array(rmses)[:,1], label='ANNR $2\\times 64$ neurons')
plt.plot(np.arange(-100, 101, 10), np.array(rmses)[:,2], label='TNNR $2\\times 128$ neurons')
plt.plot(np.arange(-100, 101, 10), np.array(rmses)[:,3], label='ANNR $2\\times 128$ neurons')

plt.title('Function: $x^3 - ax$')
plt.xlabel('a')
plt.ylabel('RMSE')
plt.legend()

# %% [markdown]
# ----------

# %%
with open("sample2.txt", "w") as file:
    file.write(str(d))

# %%
with open("sample2.txt", "r") as file:
    a = eval(file.readline())

# %%
a
# Out:
# [1, 2, 3, 4, 5]

# %%
# %%time

n = 500
seed = 9876

for experiment in range(10):
    
    rmses = []
    
    for a in np.arange(-100, 101, 10):

        tnnr_64 = TNNR(def_func(a), n=n, seed=seed, inverse_problem=True,
                       show_summary=False, show_loss_plot=False, show_rmse=False, 
                   mdl_wts_file='weights/tnnr64_n' + str(n) + '_inverse_a' + str(a))
        annr_64 = ANNR(def_func(a), n=n, seed=seed, inverse_problem=True,
                       show_summary=False, show_loss_plot=False, show_rmse=False, 
                   mdl_wts_file='weights/annr64_n' + str(n) + '_inverse_a' + str(a))

        tnnr_128 = TNNR(def_func(a), n=n, seed=seed, neurons=128, inverse_problem=True,
                        show_summary=False, show_loss_plot=False, show_rmse=False, 
                   mdl_wts_file='weights/tnnr128_n' + str(n) + '_inverse_a' + str(a))
        annr_128 = ANNR(def_func(a), n=n, seed=seed, neurons=128, inverse_problem=True,
                        show_summary=False, show_loss_plot=False, show_rmse=False, 
                   mdl_wts_file='weights/annr128_n' + str(n) + '_inverse_a' + str(a))

        rmses.append([tnnr_64.rmse_test, annr_64.rmse_test, tnnr_128.rmse_test, annr_128.rmse_test])
        
        seed += 59
        
    with open("rmses_" + str(experiment) + ".txt", "w") as file:
        file.write(str(rmses))
        
    seed += 2439

# %%
start 19:30 domingo
end   12:39 lunes

# %%
# %%time

n = 500
seed = 9876 + (2439*7) + (59*7*21)

for experiment in range(7, 10):
    
    rmses = []
    
    for a in np.arange(-100, 101, 10):

        tnnr_64 = TNNR(def_func(a), n=n, seed=seed, inverse_problem=True,
                       show_summary=False, show_loss_plot=False, show_rmse=False, 
                   mdl_wts_file='weights/tnnr64_n' + str(n) + '_inverse_a' + str(a))
        annr_64 = ANNR(def_func(a), n=n, seed=seed, inverse_problem=True,
                       show_summary=False, show_loss_plot=False, show_rmse=False, 
                   mdl_wts_file='weights/annr64_n' + str(n) + '_inverse_a' + str(a))

        tnnr_128 = TNNR(def_func(a), n=n, seed=seed, neurons=128, inverse_problem=True,
                        show_summary=False, show_loss_plot=False, show_rmse=False, 
                   mdl_wts_file='weights/tnnr128_n' + str(n) + '_inverse_a' + str(a))
        annr_128 = ANNR(def_func(a), n=n, seed=seed, neurons=128, inverse_problem=True,
                        show_summary=False, show_loss_plot=False, show_rmse=False, 
                   mdl_wts_file='weights/annr128_n' + str(n) + '_inverse_a' + str(a))

        rmses.append([tnnr_64.rmse_test, annr_64.rmse_test, tnnr_128.rmse_test, annr_128.rmse_test])
        
        seed += 59
        
    with open("rmses_" + str(experiment) + ".txt", "w") as file:
        file.write(str(rmses))
        
    seed += 2439

# %%
start 14:55 lunes
end   16:53 lunes

# %%
# %%time

n = 500
seed = 9876 + (2439*8) + (59*8*21)

for experiment in range(8, 10):
    
    rmses = []
    
    for a in np.arange(-100, 101, 10):

        tnnr_64 = TNNR(def_func(a), n=n, seed=seed, inverse_problem=True,
                       show_summary=False, show_loss_plot=False, show_rmse=False, 
                   mdl_wts_file='weights/tnnr64_n' + str(n) + '_inverse_a' + str(a))
        annr_64 = ANNR(def_func(a), n=n, seed=seed, inverse_problem=True,
                       show_summary=False, show_loss_plot=False, show_rmse=False, 
                   mdl_wts_file='weights/annr64_n' + str(n) + '_inverse_a' + str(a))

        tnnr_128 = TNNR(def_func(a), n=n, seed=seed, neurons=128, inverse_problem=True,
                        show_summary=False, show_loss_plot=False, show_rmse=False, 
                   mdl_wts_file='weights/tnnr128_n' + str(n) + '_inverse_a' + str(a))
        annr_128 = ANNR(def_func(a), n=n, seed=seed, neurons=128, inverse_problem=True,
                        show_summary=False, show_loss_plot=False, show_rmse=False, 
                   mdl_wts_file='weights/annr128_n' + str(n) + '_inverse_a' + str(a))

        rmses.append([tnnr_64.rmse_test, annr_64.rmse_test, tnnr_128.rmse_test, annr_128.rmse_test])
        
        seed += 59
        
    with open("rmses_" + str(experiment) + ".txt", "w") as file:
        file.write(str(rmses))
        
    seed += 2439
# Out:
# CPU times: user 4h 55min 48s, sys: 1h 18min 39s, total: 6h 14min 27s
# Wall time: 3h 34min 40s

# %%
start 18:46 lunes
end   22:20 lunes

# %%
rmses_tnnr_64 = []
rmses_annr_64 = []
rmses_tnnr_128 = []
rmses_annr_128 = []

for experiment in range(10):
    
    with open("rmses_" + str(experiment) + ".txt", "r") as file:
        rmses = eval(file.readline())

    rmses_tnnr_64.append(np.array(rmses)[:,0])
    rmses_annr_64.append(np.array(rmses)[:,1])
    rmses_tnnr_128.append(np.array(rmses)[:,2])
    rmses_annr_128.append(np.array(rmses)[:,3])
    
means_tnnr_64 = np.mean(rmses_tnnr_64, axis=0)
means_annr_64 = np.mean(rmses_annr_64, axis=0)
means_tnnr_128 = np.mean(rmses_tnnr_128, axis=0)
means_annr_128 = np.mean(rmses_annr_128, axis=0)

stds_tnnr_64 = np.std(rmses_tnnr_64, axis=0)/np.sqrt(10 - 1)
stds_annr_64 = np.std(rmses_annr_64, axis=0)/np.sqrt(10 - 1)
stds_tnnr_128 = np.std(rmses_tnnr_128, axis=0)/np.sqrt(10 - 1)
stds_annr_128 = np.std(rmses_annr_128, axis=0)/np.sqrt(10 - 1)


plt.errorbar(np.arange(-100, 101, 10), means_tnnr_64, yerr=stds_tnnr_64, label='TNNR $2\\times 64$ neurons',
             marker='o', ms=2, ls='-', lw=1, elinewidth=0.7, capsize=2, capthick=0.7)
plt.errorbar(np.arange(-100, 101, 10), means_annr_64, yerr=stds_annr_64, label='ANNR $2\\times 64$ neurons',
             marker='o', ms=2, ls='-', lw=1, elinewidth=0.7, capsize=2, capthick=0.7)
plt.errorbar(np.arange(-100, 101, 10), means_tnnr_128, yerr=stds_tnnr_128, label='TNNR $2\\times 128$ neurons',
             marker='o', ms=2, ls='-', lw=1, elinewidth=0.7, capsize=2, capthick=0.7)
plt.errorbar(np.arange(-100, 101, 10), means_annr_128, yerr=stds_annr_128, label='ANNR $2\\times 128$ neurons',
             marker='o', ms=2, ls='-', lw=1, elinewidth=0.7, capsize=2, capthick=0.7)
plt.title('Function: $x^3 - ax$')
plt.xlabel('a')
plt.ylabel('RMSE')
plt.legend()
plt.show()

# %%
plt.errorbar(np.arange(-100, 101, 10), means_tnnr_64, yerr=stds_tnnr_64, label='TNNR $2\\times 64$ neurons',
             marker='o', ms=2, ls='-', lw=1, elinewidth=0.7, capsize=2, capthick=0.7)
plt.errorbar(np.arange(-100, 101, 10), means_tnnr_128, yerr=stds_tnnr_128, label='TNNR $2\\times 128$ neurons',
             marker='o', ms=2, ls='-', lw=1, elinewidth=0.7, capsize=2, capthick=0.7)
plt.title('Function: $x^3 - ax$')
plt.xlabel('a')
plt.ylabel('RMSE')
plt.legend()
plt.show()

# %%
plt.errorbar(np.arange(-100, 101, 10), means_annr_64, yerr=stds_annr_64, label='ANNR $2\\times 64$ neurons',
             marker='o', ms=2, ls='-', lw=1, elinewidth=0.7, capsize=2, capthick=0.7)
plt.errorbar(np.arange(-100, 101, 10), means_annr_128, yerr=stds_annr_128, label='ANNR $2\\times 128$ neurons',
             marker='o', ms=2, ls='-', lw=1, elinewidth=0.7, capsize=2, capthick=0.7)
plt.title('Function: $x^3 - ax$')
plt.xlabel('a')
plt.ylabel('RMSE')
plt.legend()
plt.show()

# %% [markdown]
# ------------

# %% [markdown]
# ## check when $a=70$

# %%
# %%time

n = 1000
seed = 9876

a = 70


tnnr_64 = TNNR(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.5,
               show_summary=False, show_loss_plot=False, show_rmse=False, 
           mdl_wts_file='weights/tnnr64_n' + str(n) + '_inverse_a' + str(a))
annr_64 = ANNR(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.5,
               show_summary=False, show_loss_plot=False, show_rmse=False, 
           mdl_wts_file='weights/annr64_n' + str(n) + '_inverse_a' + str(a))

tnnr_128 = TNNR(def_func(a), n=n, seed=seed, neurons=128, inverse_problem=True, test_pct=0.5,
                show_summary=False, show_loss_plot=False, show_rmse=False, 
           mdl_wts_file='weights/tnnr128_n' + str(n) + '_inverse_a' + str(a))
annr_128 = ANNR(def_func(a), n=n, seed=seed, neurons=128, inverse_problem=True, test_pct=0.5,
                show_summary=False, show_loss_plot=False, show_rmse=False, 
           mdl_wts_file='weights/annr128_n' + str(n) + '_inverse_a' + str(a))


print("RMSE of TNNR 64:", tnnr_64.rmse_test)
print("RMSE of ANNR 64:", annr_64.rmse_test)
print("RMSE of TNNR 128:", tnnr_128.rmse_test)
print("RMSE of ANNR 128:", annr_128.rmse_test)
# Out:
# RMSE of TNNR 64: 5.5669227245866075
# RMSE of ANNR 64: 20.008424078642385
# RMSE of TNNR 128: 5.34775733880324
# RMSE of ANNR 128: 20.27830989322358
# CPU times: user 3min 35s, sys: 50.3 s, total: 4min 25s
# Wall time: 2min 48s

# %%
plt.scatter(tnnr_64.cn_transformer.inverse_transform_x(tnnr_64.x_train_single), 
            tnnr_64.cn_transformer.inverse_transform_y(tnnr_64.y_train_single),
            label='Train data set', s=1, c='#99ffff')
plt.scatter(tnnr_64.x_pred_test,
            tnnr_64.cn_transformer.inverse_transform_y(tnnr_64.y_test_single),
            label='TNNR $2\\times 64$ neurons', s=30)
plt.scatter(tnnr_128.x_pred_test,
            tnnr_128.cn_transformer.inverse_transform_y(tnnr_128.y_test_single),
            label='TNNR $2\\times 128$ neurons', s=30)

plt.title('Function: $x^3 - 70x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()

# %%
plt.scatter(annr_64.cn_transformer.inverse_transform_x(annr_64.x_train_single), 
            annr_64.cn_transformer.inverse_transform_y(annr_64.y_train_single),
            label='Train data set', s=1, c='#99ffff')
plt.scatter(annr_64.x_pred_test,
            annr_64.cn_transformer.inverse_transform_y(annr_64.y_test_single),
            label='ANNR $2\\times 64$ neurons', s=30)
plt.scatter(annr_128.x_pred_test,
            annr_128.cn_transformer.inverse_transform_y(annr_128.y_test_single),
            label='ANNR $2\\times 128$ neurons', s=30)

plt.title('Function: $x^3 - 70x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()

# %% [markdown]
# -----------

# %% [markdown]
# ## $a=-70$

# %%
# %%time

n = 1000
seed = 235

a = -70


tnnr_64 = TNNR(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.5,
               show_summary=False, show_loss_plot=False, show_rmse=False, 
           mdl_wts_file='weights/tnnr64_n' + str(n) + '_inverse_a' + str(a))
annr_64 = ANNR(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.5,
               show_summary=False, show_loss_plot=False, show_rmse=False, 
           mdl_wts_file='weights/annr64_n' + str(n) + '_inverse_a' + str(a))

tnnr_128 = TNNR(def_func(a), n=n, seed=seed, neurons=128, inverse_problem=True, test_pct=0.5,
                show_summary=False, show_loss_plot=False, show_rmse=False, 
           mdl_wts_file='weights/tnnr128_n' + str(n) + '_inverse_a' + str(a))
annr_128 = ANNR(def_func(a), n=n, seed=seed, neurons=128, inverse_problem=True, test_pct=0.5,
                show_summary=False, show_loss_plot=False, show_rmse=False, 
           mdl_wts_file='weights/annr128_n' + str(n) + '_inverse_a' + str(a))


print("RMSE of TNNR 64:", tnnr_64.rmse_test)
print("RMSE of ANNR 64:", annr_64.rmse_test)
print("RMSE of TNNR 128:", tnnr_128.rmse_test)
print("RMSE of ANNR 128:", annr_128.rmse_test)
# Out:
# RMSE of TNNR 64: 0.018538357839859274
# RMSE of ANNR 64: 55.73956782548314
# RMSE of TNNR 128: 0.02785460742166351
# RMSE of ANNR 128: 55.72722014079944
# CPU times: user 10min 49s, sys: 2min 27s, total: 13min 16s
# Wall time: 8min 12s

# %%
plt.scatter(tnnr_64.cn_transformer.inverse_transform_x(tnnr_64.x_train_single), 
            tnnr_64.cn_transformer.inverse_transform_y(tnnr_64.y_train_single),
            label='Train data set', s=1, c='#99ffff')
plt.scatter(tnnr_64.x_pred_test,
            tnnr_64.cn_transformer.inverse_transform_y(tnnr_64.y_test_single),
            label='TNNR $2\\times 64$ neurons', s=30)
plt.scatter(tnnr_128.x_pred_test,
            tnnr_128.cn_transformer.inverse_transform_y(tnnr_128.y_test_single),
            label='TNNR $2\\times 128$ neurons', s=30)

plt.title('Function: $x^3 + 70x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()

# %%
plt.scatter(annr_64.cn_transformer.inverse_transform_x(annr_64.x_train_single), 
            annr_64.cn_transformer.inverse_transform_y(annr_64.y_train_single),
            label='Train data set', s=1, c='#99ffff')
plt.scatter(annr_64.x_pred_test,
            annr_64.cn_transformer.inverse_transform_y(annr_64.y_test_single),
            label='ANNR $2\\times 64$ neurons', s=30)
plt.scatter(annr_128.x_pred_test,
            annr_128.cn_transformer.inverse_transform_y(annr_128.y_test_single),
            label='ANNR $2\\times 128$ neurons', s=30)

plt.title('Function: $x^3 + 70x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()

# %% [markdown]
# ----------

# %% [markdown]
# ## $a=10$

# %%
# %%time

n = 1000
seed = 93

a = 10


tnnr_64 = TNNR(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.5,
               show_summary=False, show_loss_plot=False, show_rmse=False, 
           mdl_wts_file='weights/tnnr64_n' + str(n) + '_inverse_a' + str(a))
annr_64 = ANNR(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.5,
               show_summary=False, show_loss_plot=False, show_rmse=False, 
           mdl_wts_file='weights/annr64_n' + str(n) + '_inverse_a' + str(a))

tnnr_128 = TNNR(def_func(a), n=n, seed=seed, neurons=128, inverse_problem=True, test_pct=0.5,
                show_summary=False, show_loss_plot=False, show_rmse=False, 
           mdl_wts_file='weights/tnnr128_n' + str(n) + '_inverse_a' + str(a))
annr_128 = ANNR(def_func(a), n=n, seed=seed, neurons=128, inverse_problem=True, test_pct=0.5,
                show_summary=False, show_loss_plot=False, show_rmse=False, 
           mdl_wts_file='weights/annr128_n' + str(n) + '_inverse_a' + str(a))


print("RMSE of TNNR 64:", tnnr_64.rmse_test)
print("RMSE of ANNR 64:", annr_64.rmse_test)
print("RMSE of TNNR 128:", tnnr_128.rmse_test)
print("RMSE of ANNR 128:", annr_128.rmse_test)
# Out:
# RMSE of TNNR 64: 1.1068230005085213
# RMSE of ANNR 64: 60.62027683403622
# RMSE of TNNR 128: 1.1292439038950317
# RMSE of ANNR 128: 59.81190844247616
# CPU times: user 7min 45s, sys: 1min 44s, total: 9min 29s
# Wall time: 5min 51s

# %%
plt.scatter(tnnr_64.cn_transformer.inverse_transform_x(tnnr_64.x_train_single), 
            tnnr_64.cn_transformer.inverse_transform_y(tnnr_64.y_train_single),
            label='Train data set', s=1, c='#99ffff')
plt.scatter(tnnr_64.x_pred_test,
            tnnr_64.cn_transformer.inverse_transform_y(tnnr_64.y_test_single),
            label='TNNR $2\\times 64$ neurons', s=30)
plt.scatter(tnnr_128.x_pred_test,
            tnnr_128.cn_transformer.inverse_transform_y(tnnr_128.y_test_single),
            label='TNNR $2\\times 128$ neurons', s=30)

plt.title('Function: $x^3 - 10x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()

# %%
plt.scatter(annr_64.cn_transformer.inverse_transform_x(annr_64.x_train_single), 
            annr_64.cn_transformer.inverse_transform_y(annr_64.y_train_single),
            label='Train data set', s=1, c='#99ffff')
plt.scatter(annr_64.x_pred_test,
            annr_64.cn_transformer.inverse_transform_y(annr_64.y_test_single),
            label='ANNR $2\\times 64$ neurons', s=30)
plt.scatter(annr_128.x_pred_test,
            annr_128.cn_transformer.inverse_transform_y(annr_128.y_test_single),
            label='ANNR $2\\times 128$ neurons', s=30)

plt.title('Function: $x^3 - 10x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()

# %% [markdown]
# -------------

# %% [markdown]
# ## $a=40$

# %%
# %%time

n = 1000
seed = 29474

a = 40


tnnr_64 = TNNR(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.5,
               show_summary=False, show_loss_plot=False, show_rmse=False, 
           mdl_wts_file='weights/tnnr64_n' + str(n) + '_inverse_a' + str(a))
annr_64 = ANNR(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.5,
               show_summary=False, show_loss_plot=False, show_rmse=False, 
           mdl_wts_file='weights/annr64_n' + str(n) + '_inverse_a' + str(a))

tnnr_128 = TNNR(def_func(a), n=n, seed=seed, neurons=128, inverse_problem=True, test_pct=0.5,
                show_summary=False, show_loss_plot=False, show_rmse=False, 
           mdl_wts_file='weights/tnnr128_n' + str(n) + '_inverse_a' + str(a))
annr_128 = ANNR(def_func(a), n=n, seed=seed, neurons=128, inverse_problem=True, test_pct=0.5,
                show_summary=False, show_loss_plot=False, show_rmse=False, 
           mdl_wts_file='weights/annr128_n' + str(n) + '_inverse_a' + str(a))


print("RMSE of TNNR 64:", tnnr_64.rmse_test)
print("RMSE of ANNR 64:", annr_64.rmse_test)
print("RMSE of TNNR 128:", tnnr_128.rmse_test)
print("RMSE of ANNR 128:", annr_128.rmse_test)
# Out:
# RMSE of TNNR 64: 3.1656558446171505
# RMSE of ANNR 64: 48.659599390519894
# RMSE of TNNR 128: 3.1765580170264984
# RMSE of ANNR 128: 48.809447201805845
# CPU times: user 6min 58s, sys: 1min 29s, total: 8min 28s
# Wall time: 5min 21s

# %%
plt.scatter(tnnr_64.cn_transformer.inverse_transform_x(tnnr_64.x_train_single), 
            tnnr_64.cn_transformer.inverse_transform_y(tnnr_64.y_train_single),
            label='Train data set', s=1, c='#99ffff')
plt.scatter(tnnr_64.x_pred_test,
            tnnr_64.cn_transformer.inverse_transform_y(tnnr_64.y_test_single),
            label='TNNR $2\\times 64$ neurons', s=30)
plt.scatter(tnnr_128.x_pred_test,
            tnnr_128.cn_transformer.inverse_transform_y(tnnr_128.y_test_single),
            label='TNNR $2\\times 128$ neurons', s=30)

plt.title('Function: $x^3 - 40x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()

# %%
plt.scatter(annr_64.cn_transformer.inverse_transform_x(annr_64.x_train_single), 
            annr_64.cn_transformer.inverse_transform_y(annr_64.y_train_single),
            label='Train data set', s=1, c='#99ffff')
plt.scatter(annr_64.x_pred_test,
            annr_64.cn_transformer.inverse_transform_y(annr_64.y_test_single),
            label='ANNR $2\\times 64$ neurons', s=30)
plt.scatter(annr_128.x_pred_test,
            annr_128.cn_transformer.inverse_transform_y(annr_128.y_test_single),
            label='ANNR $2\\times 128$ neurons', s=30)

plt.title('Function: $x^3 - 40x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()

# %% [markdown]
# ----------

# %% [markdown]
# ## $a=100$

# %%
# %%time

n = 1000
seed = 94923

a = 100


tnnr_64 = TNNR(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.5,
               show_summary=False, show_loss_plot=False, show_rmse=False, 
           mdl_wts_file='weights/tnnr64_n' + str(n) + '_inverse_a' + str(a))
annr_64 = ANNR(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.5,
               show_summary=False, show_loss_plot=False, show_rmse=False, 
           mdl_wts_file='weights/annr64_n' + str(n) + '_inverse_a' + str(a))

tnnr_128 = TNNR(def_func(a), n=n, seed=seed, neurons=128, inverse_problem=True, test_pct=0.5,
                show_summary=False, show_loss_plot=False, show_rmse=False, 
           mdl_wts_file='weights/tnnr128_n' + str(n) + '_inverse_a' + str(a))
annr_128 = ANNR(def_func(a), n=n, seed=seed, neurons=128, inverse_problem=True, test_pct=0.5,
                show_summary=False, show_loss_plot=False, show_rmse=False, 
           mdl_wts_file='weights/annr128_n' + str(n) + '_inverse_a' + str(a))


print("RMSE of TNNR 64:", tnnr_64.rmse_test)
print("RMSE of ANNR 64:", annr_64.rmse_test)
print("RMSE of TNNR 128:", tnnr_128.rmse_test)
print("RMSE of ANNR 128:", annr_128.rmse_test)
# Out:
# RMSE of TNNR 64: 2.8724353745291795
# RMSE of ANNR 64: 53.05019675728627
# RMSE of TNNR 128: 2.8836300126648373
# RMSE of ANNR 128: 51.53955749725205
# CPU times: user 5min 1s, sys: 1min 8s, total: 6min 9s
# Wall time: 3min 50s

# %%
plt.scatter(tnnr_64.cn_transformer.inverse_transform_x(tnnr_64.x_train_single), 
            tnnr_64.cn_transformer.inverse_transform_y(tnnr_64.y_train_single),
            label='Train data set', s=1, c='#99ffff')
plt.scatter(tnnr_64.x_pred_test,
            tnnr_64.cn_transformer.inverse_transform_y(tnnr_64.y_test_single),
            label='TNNR $2\\times 64$ neurons', s=30)
plt.scatter(tnnr_128.x_pred_test,
            tnnr_128.cn_transformer.inverse_transform_y(tnnr_128.y_test_single),
            label='TNNR $2\\times 128$ neurons', s=30)

plt.title('Function: $x^3 - 100x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()

# %%
plt.scatter(annr_64.cn_transformer.inverse_transform_x(annr_64.x_train_single), 
            annr_64.cn_transformer.inverse_transform_y(annr_64.y_train_single),
            label='Train data set', s=1, c='#99ffff')
plt.scatter(annr_64.x_pred_test,
            annr_64.cn_transformer.inverse_transform_y(annr_64.y_test_single),
            label='ANNR $2\\times 64$ neurons', s=30)
plt.scatter(annr_128.x_pred_test,
            annr_128.cn_transformer.inverse_transform_y(annr_128.y_test_single),
            label='ANNR $2\\times 128$ neurons', s=30)

plt.title('Function: $x^3 - 100x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()
