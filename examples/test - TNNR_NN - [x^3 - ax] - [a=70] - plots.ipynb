# %%
import sys
sys.path.append("..")

from TwinNeuralNetworkNearestNeighbors import TNNR_NN

import matplotlib.pyplot as plt

import numpy as np

# %%
def_func = lambda a: lambda x: x**3 - a*x

# %%
n = 200
seed = 9876

a = 70

# %%
# %%time

tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.5,
                          show_summary=False, show_loss_plot=False, show_rmse=False, 
                          mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                          num_nn_train=5)
# Out:
# CPU times: user 34.1 s, sys: 6.36 s, total: 40.5 s
# Wall time: 27.9 s

# %%
# %%time

tnnr_nn_test_128 = TNNR_NN(def_func(a), n=n, seed=seed, neurons=128, inverse_problem=True, test_pct=0.5,
                           show_summary=False, show_loss_plot=False, show_rmse=False, 
                           mdl_wts_file='weights/tnnr_nn_test_128_n' + str(n) + '_inverse_a' + str(a),
                           num_nn_train=5)
# Out:
# CPU times: user 23.5 s, sys: 6.73 s, total: 30.2 s
# Wall time: 18 s

# %%
print("RMSE of TNNR_NN 64:", tnnr_nn_test_64.rmse_test)
print("RMSE of TNNR_NN 128:", tnnr_nn_test_128.rmse_test)
# Out:
# RMSE of TNNR_NN 64: 7.0929972821411065
# RMSE of TNNR_NN 128: 7.043373281833797

# %%
plt.scatter(tnnr_nn_test_64.cn_transformer.inverse_transform_x(tnnr_nn_test_64.x_train_single), 
            tnnr_nn_test_64.cn_transformer.inverse_transform_y(tnnr_nn_test_64.y_train_single),
            label='Train data set', s=1, c='#99ffff')
plt.scatter(tnnr_nn_test_64.x_pred_test,
            tnnr_nn_test_64.cn_transformer.inverse_transform_y(tnnr_nn_test_128.y_test_single),
            label='TNNR NN, $2\\times 64$ neurons', s=30)
plt.scatter(tnnr_nn_test_128.x_pred_test,
            tnnr_nn_test_128.cn_transformer.inverse_transform_y(tnnr_nn_test_128.y_test_single),
            label='TNNR NN, $2\\times 128$ neurons', s=5)

plt.title('Function: $x^3 - 70x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()

# %% [markdown]
# -------------

# %%
# %%time

tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.5,
                          show_summary=False, show_loss_plot=False, show_rmse=False, 
                          mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                          num_nn_train=5,
                          num_nn_test=3)

tnnr_nn_test_128 = TNNR_NN(def_func(a), n=n, seed=seed, neurons=128, inverse_problem=True, test_pct=0.5,
                           show_summary=False, show_loss_plot=False, show_rmse=False, 
                           mdl_wts_file='weights/tnnr_nn_test_128_n' + str(n) + '_inverse_a' + str(a),
                           num_nn_train=5,
                           num_nn_test=3)
# Out:
# CPU times: user 55 s, sys: 13 s, total: 1min 8s
# Wall time: 42.6 s

# %%
print("RMSE of TNNR_NN 64:", tnnr_nn_test_64.rmse_test)
print("RMSE of TNNR_NN 128:", tnnr_nn_test_128.rmse_test)
# Out:
# RMSE of TNNR_NN 64: 6.262987931963511
# RMSE of TNNR_NN 128: 6.217829416676984

# %%
plt.scatter(tnnr_nn_test_64.cn_transformer.inverse_transform_x(tnnr_nn_test_64.x_train_single), 
            tnnr_nn_test_64.cn_transformer.inverse_transform_y(tnnr_nn_test_64.y_train_single),
            label='Train data set', s=1, c='#99ffff')
plt.scatter(tnnr_nn_test_64.x_pred_test,
            tnnr_nn_test_64.cn_transformer.inverse_transform_y(tnnr_nn_test_128.y_test_single),
            label='TNNR NN, $2\\times 64$ neurons', s=30)
plt.scatter(tnnr_nn_test_128.x_pred_test,
            tnnr_nn_test_128.cn_transformer.inverse_transform_y(tnnr_nn_test_128.y_test_single),
            label='TNNR NN, $2\\times 128$ neurons', s=30)

plt.title('Function: $x^3 - 70x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()

# %% [markdown]
# ---------

# %%
# %%time

seed = 4567

tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.5,
                          show_summary=False, show_loss_plot=False, show_rmse=False, 
                          mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                          num_nn_train=5,
                          num_nn_test=2)

tnnr_nn_test_128 = TNNR_NN(def_func(a), n=n, seed=seed, neurons=128, inverse_problem=True, test_pct=0.5,
                           show_summary=False, show_loss_plot=False, show_rmse=False, 
                           mdl_wts_file='weights/tnnr_nn_test_128_n' + str(n) + '_inverse_a' + str(a),
                           num_nn_train=5,
                           num_nn_test=2)
# Out:
# CPU times: user 57.5 s, sys: 15.2 s, total: 1min 12s
# Wall time: 43.6 s

# %%
print("RMSE of TNNR_NN 64:", tnnr_nn_test_64.rmse_test)
print("RMSE of TNNR_NN 128:", tnnr_nn_test_128.rmse_test)
# Out:
# RMSE of TNNR_NN 64: 6.939070724707092
# RMSE of TNNR_NN 128: 6.941834986353917

# %%
plt.scatter(tnnr_nn_test_64.cn_transformer.inverse_transform_x(tnnr_nn_test_64.x_train_single), 
            tnnr_nn_test_64.cn_transformer.inverse_transform_y(tnnr_nn_test_64.y_train_single),
            label='Train data set', s=1, c='#99ffff')
plt.scatter(tnnr_nn_test_64.x_pred_test,
            tnnr_nn_test_64.cn_transformer.inverse_transform_y(tnnr_nn_test_128.y_test_single),
            label='TNNR NN, $2\\times 64$ neurons', s=30)
plt.scatter(tnnr_nn_test_128.x_pred_test,
            tnnr_nn_test_128.cn_transformer.inverse_transform_y(tnnr_nn_test_128.y_test_single),
            label='TNNR NN, $2\\times 128$ neurons', s=30)

plt.title('Function: $x^3 - 70x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()

# %% [markdown]
# -----------

# %%
# %%time

seed = 8934

tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.5,
                          show_summary=False, show_loss_plot=False, show_rmse=False, 
                          mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                          num_nn_train=5,
                          num_nn_test=5)

tnnr_nn_test_128 = TNNR_NN(def_func(a), n=n, seed=seed, neurons=128, inverse_problem=True, test_pct=0.5,
                           show_summary=False, show_loss_plot=False, show_rmse=False, 
                           mdl_wts_file='weights/tnnr_nn_test_128_n' + str(n) + '_inverse_a' + str(a),
                           num_nn_train=5,
                           num_nn_test=5)
# Out:
# CPU times: user 1min 10s, sys: 17.2 s, total: 1min 27s
# Wall time: 54.1 s

# %%
print("RMSE of TNNR_NN 64:", tnnr_nn_test_64.rmse_test)
print("RMSE of TNNR_NN 128:", tnnr_nn_test_128.rmse_test)
# Out:
# RMSE of TNNR_NN 64: 6.013641359714862
# RMSE of TNNR_NN 128: 6.015202521153752

# %%
plt.scatter(tnnr_nn_test_64.cn_transformer.inverse_transform_x(tnnr_nn_test_64.x_train_single), 
            tnnr_nn_test_64.cn_transformer.inverse_transform_y(tnnr_nn_test_64.y_train_single),
            label='Train data set', s=1, c='#99ffff')
plt.scatter(tnnr_nn_test_64.x_pred_test,
            tnnr_nn_test_64.cn_transformer.inverse_transform_y(tnnr_nn_test_128.y_test_single),
            label='TNNR NN, $2\\times 64$ neurons', s=30)
plt.scatter(tnnr_nn_test_128.x_pred_test,
            tnnr_nn_test_128.cn_transformer.inverse_transform_y(tnnr_nn_test_128.y_test_single),
            label='TNNR NN, $2\\times 128$ neurons', s=30)

plt.title('Function: $x^3 - 70x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()

# %% [markdown]
# -----------

# %%
# %%time

seed = 234598

tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.5,
                          show_summary=False, show_loss_plot=False, show_rmse=False, 
                          mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                          num_nn_train=2,
                          num_nn_test=1)

tnnr_nn_test_128 = TNNR_NN(def_func(a), n=n, seed=seed, neurons=128, inverse_problem=True, test_pct=0.5,
                           show_summary=False, show_loss_plot=False, show_rmse=False, 
                           mdl_wts_file='weights/tnnr_nn_test_128_n' + str(n) + '_inverse_a' + str(a),
                           num_nn_train=2,
                           num_nn_test=1)
# Out:
# CPU times: user 1min 9s, sys: 16.2 s, total: 1min 25s
# Wall time: 54.2 s

# %%
print("RMSE of TNNR_NN 64:", tnnr_nn_test_64.rmse_test)
print("RMSE of TNNR_NN 128:", tnnr_nn_test_128.rmse_test)
# Out:
# RMSE of TNNR_NN 64: 7.925037978797268
# RMSE of TNNR_NN 128: 7.925225549903294

# %%
plt.scatter(tnnr_nn_test_64.cn_transformer.inverse_transform_x(tnnr_nn_test_64.x_train_single), 
            tnnr_nn_test_64.cn_transformer.inverse_transform_y(tnnr_nn_test_64.y_train_single),
            label='Train data set', s=1, c='#99ffff')
plt.scatter(tnnr_nn_test_64.x_pred_test,
            tnnr_nn_test_64.cn_transformer.inverse_transform_y(tnnr_nn_test_128.y_test_single),
            label='TNNR NN, $2\\times 64$ neurons', s=30)
plt.scatter(tnnr_nn_test_128.x_pred_test,
            tnnr_nn_test_128.cn_transformer.inverse_transform_y(tnnr_nn_test_128.y_test_single),
            label='TNNR NN, $2\\times 128$ neurons', s=30)

plt.title('Function: $x^3 - 70x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()

# %% [markdown]
# ------------

# %%
# %%time

seed = 234598

tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.5,
                          show_summary=False, show_loss_plot=False, show_rmse=False, 
                          mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                          num_nn_train=10,
                          num_nn_test=1)

tnnr_nn_test_128 = TNNR_NN(def_func(a), n=n, seed=seed, neurons=128, inverse_problem=True, test_pct=0.5,
                           show_summary=False, show_loss_plot=False, show_rmse=False, 
                           mdl_wts_file='weights/tnnr_nn_test_128_n' + str(n) + '_inverse_a' + str(a),
                           num_nn_train=10,
                           num_nn_test=1)
# Out:
# CPU times: user 57.2 s, sys: 15.3 s, total: 1min 12s
# Wall time: 43.6 s

# %%
print("RMSE of TNNR_NN 64:", tnnr_nn_test_64.rmse_test)
print("RMSE of TNNR_NN 128:", tnnr_nn_test_128.rmse_test)
# Out:
# RMSE of TNNR_NN 64: 7.942620120599146
# RMSE of TNNR_NN 128: 7.94286986735143

# %%
plt.scatter(tnnr_nn_test_64.cn_transformer.inverse_transform_x(tnnr_nn_test_64.x_train_single), 
            tnnr_nn_test_64.cn_transformer.inverse_transform_y(tnnr_nn_test_64.y_train_single),
            label='Train data set', s=1, c='#99ffff')
plt.scatter(tnnr_nn_test_64.x_pred_test,
            tnnr_nn_test_64.cn_transformer.inverse_transform_y(tnnr_nn_test_128.y_test_single),
            label='TNNR NN, $2\\times 64$ neurons', s=30)
plt.scatter(tnnr_nn_test_128.x_pred_test,
            tnnr_nn_test_128.cn_transformer.inverse_transform_y(tnnr_nn_test_128.y_test_single),
            label='TNNR NN, $2\\times 128$ neurons', s=30)

plt.title('Function: $x^3 - 70x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()

# %% [markdown]
# ----------

# %% [markdown]
# # n = 1000

# %%
n = 1000
seed = 9876

a = 70

# %%
# %%time

tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.5,
                          show_summary=False, show_loss_plot=False, show_rmse=False, 
                          mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                          num_nn_train=5)

tnnr_nn_test_128 = TNNR_NN(def_func(a), n=n, seed=seed, neurons=128, inverse_problem=True, test_pct=0.5,
                           show_summary=False, show_loss_plot=False, show_rmse=False, 
                           mdl_wts_file='weights/tnnr_nn_test_128_n' + str(n) + '_inverse_a' + str(a),
                           num_nn_train=5)
# Out:
# CPU times: user 1min 48s, sys: 21.5 s, total: 2min 9s
# Wall time: 1min 27s

# %%
print("RMSE of TNNR_NN 64:", tnnr_nn_test_64.rmse_test)
print("RMSE of TNNR_NN 128:", tnnr_nn_test_128.rmse_test)
# Out:
# RMSE of TNNR_NN 64: 6.902770340671583
# RMSE of TNNR_NN 128: 6.902773974921905

# %%
plt.scatter(tnnr_nn_test_64.cn_transformer.inverse_transform_x(tnnr_nn_test_64.x_train_single), 
            tnnr_nn_test_64.cn_transformer.inverse_transform_y(tnnr_nn_test_64.y_train_single),
            label='Train data set', s=1, c='#99ffff')
plt.scatter(tnnr_nn_test_64.x_pred_test,
            tnnr_nn_test_64.cn_transformer.inverse_transform_y(tnnr_nn_test_128.y_test_single),
            label='TNNR NN, $2\\times 64$ neurons', s=30)
plt.scatter(tnnr_nn_test_128.x_pred_test,
            tnnr_nn_test_128.cn_transformer.inverse_transform_y(tnnr_nn_test_128.y_test_single),
            label='TNNR NN, $2\\times 128$ neurons', s=5)

plt.title('Function: $x^3 - 70x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()

# %% [markdown]
# ----------

# %%
# %%time

tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.5,
                          show_summary=False, show_loss_plot=False, show_rmse=False, 
                          mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                          num_nn_train=5,
                          num_nn_test=3)

tnnr_nn_test_128 = TNNR_NN(def_func(a), n=n, seed=seed, neurons=128, inverse_problem=True, test_pct=0.5,
                           show_summary=False, show_loss_plot=False, show_rmse=False, 
                           mdl_wts_file='weights/tnnr_nn_test_128_n' + str(n) + '_inverse_a' + str(a),
                           num_nn_train=5,
                           num_nn_test=3)
# Out:
# CPU times: user 1min 50s, sys: 21.5 s, total: 2min 11s
# Wall time: 1min 29s

# %%
print("RMSE of TNNR_NN 64:", tnnr_nn_test_64.rmse_test)
print("RMSE of TNNR_NN 128:", tnnr_nn_test_128.rmse_test)
# Out:
# RMSE of TNNR_NN 64: 5.401974525999629
# RMSE of TNNR_NN 128: 5.401921426304376

# %%
plt.scatter(tnnr_nn_test_64.cn_transformer.inverse_transform_x(tnnr_nn_test_64.x_train_single), 
            tnnr_nn_test_64.cn_transformer.inverse_transform_y(tnnr_nn_test_64.y_train_single),
            label='Train data set', s=1, c='#99ffff')
plt.scatter(tnnr_nn_test_64.x_pred_test,
            tnnr_nn_test_64.cn_transformer.inverse_transform_y(tnnr_nn_test_128.y_test_single),
            label='TNNR NN, $2\\times 64$ neurons', s=30)
plt.scatter(tnnr_nn_test_128.x_pred_test,
            tnnr_nn_test_128.cn_transformer.inverse_transform_y(tnnr_nn_test_128.y_test_single),
            label='TNNR NN, $2\\times 128$ neurons', s=5)

plt.title('Function: $x^3 - 70x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()

# %% [markdown]
# ------------

# %%
# %%time

tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.5,
                          show_summary=False, show_loss_plot=False, show_rmse=False, 
                          mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                          num_nn_train=10,
                          num_nn_test=1)

tnnr_nn_test_128 = TNNR_NN(def_func(a), n=n, seed=seed, neurons=128, inverse_problem=True, test_pct=0.5,
                           show_summary=False, show_loss_plot=False, show_rmse=False, 
                           mdl_wts_file='weights/tnnr_nn_test_128_n' + str(n) + '_inverse_a' + str(a),
                           num_nn_train=10,
                           num_nn_test=1)
# Out:
# CPU times: user 2min 7s, sys: 27.2 s, total: 2min 35s
# Wall time: 1min 40s

# %%
print("RMSE of TNNR_NN 64:", tnnr_nn_test_64.rmse_test)
print("RMSE of TNNR_NN 128:", tnnr_nn_test_128.rmse_test)
# Out:
# RMSE of TNNR_NN 64: 6.902584688294572
# RMSE of TNNR_NN 128: 6.902468238463174

# %%
plt.scatter(tnnr_nn_test_64.cn_transformer.inverse_transform_x(tnnr_nn_test_64.x_train_single), 
            tnnr_nn_test_64.cn_transformer.inverse_transform_y(tnnr_nn_test_64.y_train_single),
            label='Train data set', s=1, c='#99ffff')
plt.scatter(tnnr_nn_test_64.x_pred_test,
            tnnr_nn_test_64.cn_transformer.inverse_transform_y(tnnr_nn_test_128.y_test_single),
            label='TNNR NN, $2\\times 64$ neurons', s=30)
plt.scatter(tnnr_nn_test_128.x_pred_test,
            tnnr_nn_test_128.cn_transformer.inverse_transform_y(tnnr_nn_test_128.y_test_single),
            label='TNNR NN, $2\\times 128$ neurons', s=5)

plt.title('Function: $x^3 - 70x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()

# %% [markdown]
# ------------

# %%
# %%time

tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.5,
                          show_summary=False, show_loss_plot=False, show_rmse=False, 
                          mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                          num_nn_train=1,
                          num_nn_test=1)

tnnr_nn_test_128 = TNNR_NN(def_func(a), n=n, seed=seed, neurons=128, inverse_problem=True, test_pct=0.5,
                           show_summary=False, show_loss_plot=False, show_rmse=False, 
                           mdl_wts_file='weights/tnnr_nn_test_128_n' + str(n) + '_inverse_a' + str(a),
                           num_nn_train=1,
                           num_nn_test=1)
# Out:
# CPU times: user 2min 8s, sys: 26.2 s, total: 2min 34s
# Wall time: 1min 42s

# %%
print("RMSE of TNNR_NN 64:", tnnr_nn_test_64.rmse_test)
print("RMSE of TNNR_NN 128:", tnnr_nn_test_128.rmse_test)
# Out:
# RMSE of TNNR_NN 64: 6.904400598275503
# RMSE of TNNR_NN 128: 6.905148110296385

# %%
plt.scatter(tnnr_nn_test_64.cn_transformer.inverse_transform_x(tnnr_nn_test_64.x_train_single), 
            tnnr_nn_test_64.cn_transformer.inverse_transform_y(tnnr_nn_test_64.y_train_single),
            label='Train data set', s=1, c='#99ffff')
plt.scatter(tnnr_nn_test_64.x_pred_test,
            tnnr_nn_test_64.cn_transformer.inverse_transform_y(tnnr_nn_test_128.y_test_single),
            label='TNNR NN, $2\\times 64$ neurons', s=30)
plt.scatter(tnnr_nn_test_128.x_pred_test,
            tnnr_nn_test_128.cn_transformer.inverse_transform_y(tnnr_nn_test_128.y_test_single),
            label='TNNR NN, $2\\times 128$ neurons', s=5)

plt.title('Function: $x^3 - 70x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()

# %% [markdown]
# # F = 0

# %%
n = 200
seed = 9876

a = 70

# %%
# %%time

tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.5,
                          show_summary=False, show_loss_plot=False, show_rmse=False, 
                          mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                          num_nn_train=5)

tnnr_nn_test_128 = TNNR_NN(def_func(a), n=n, seed=seed, neurons=128, inverse_problem=True, test_pct=0.5,
                           show_summary=False, show_loss_plot=False, show_rmse=False, 
                           mdl_wts_file='weights/tnnr_nn_test_128_n' + str(n) + '_inverse_a' + str(a),
                           num_nn_train=5)
# Out:
# CPU times: user 59.5 s, sys: 13.5 s, total: 1min 12s
# Wall time: 47.5 s

# %%
print("RMSE of TNNR_NN 64:", tnnr_nn_test_64.rmse_test)
print("RMSE of TNNR_NN 128:", tnnr_nn_test_128.rmse_test)
# Out:
# RMSE of TNNR_NN 64: 7.088039026226768
# RMSE of TNNR_NN 128: 7.088039026226768

# %%
plt.scatter(tnnr_nn_test_64.cn_transformer.inverse_transform_x(tnnr_nn_test_64.x_train_single), 
            tnnr_nn_test_64.cn_transformer.inverse_transform_y(tnnr_nn_test_64.y_train_single),
            label='Train data set', s=1, c='#99ffff')
plt.scatter(tnnr_nn_test_64.x_pred_test,
            tnnr_nn_test_64.cn_transformer.inverse_transform_y(tnnr_nn_test_64.y_test_single),
            label='TNNR NN, $2\\times 64$ neurons', s=30)
plt.scatter(tnnr_nn_test_128.x_pred_test,
            tnnr_nn_test_128.cn_transformer.inverse_transform_y(tnnr_nn_test_128.y_test_single),
            label='TNNR NN, $2\\times 128$ neurons', s=5)

plt.title('Function: $x^3 - 70x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()

# %%
n = 1000

# %%
# %%time

tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.5,
                          show_summary=False, show_loss_plot=False, show_rmse=False, 
                          mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                          num_nn_train=5)

tnnr_nn_test_128 = TNNR_NN(def_func(a), n=n, seed=seed, neurons=128, inverse_problem=True, test_pct=0.5,
                           show_summary=False, show_loss_plot=False, show_rmse=False, 
                           mdl_wts_file='weights/tnnr_nn_test_128_n' + str(n) + '_inverse_a' + str(a),
                           num_nn_train=5)
# Out:
# CPU times: user 1min 57s, sys: 21.8 s, total: 2min 19s
# Wall time: 1min 35s

# %%
print("RMSE of TNNR_NN 64:", tnnr_nn_test_64.rmse_test)
print("RMSE of TNNR_NN 128:", tnnr_nn_test_128.rmse_test)
# Out:
# RMSE of TNNR_NN 64: 6.902568625613587
# RMSE of TNNR_NN 128: 6.902568625613587

# %%
plt.scatter(tnnr_nn_test_64.cn_transformer.inverse_transform_x(tnnr_nn_test_64.x_train_single), 
            tnnr_nn_test_64.cn_transformer.inverse_transform_y(tnnr_nn_test_64.y_train_single),
            label='Train data set', s=1, c='#99ffff')
plt.scatter(tnnr_nn_test_64.x_pred_test,
            tnnr_nn_test_64.cn_transformer.inverse_transform_y(tnnr_nn_test_64.y_test_single),
            label='TNNR NN, $2\\times 64$ neurons', s=30)
plt.scatter(tnnr_nn_test_128.x_pred_test,
            tnnr_nn_test_128.cn_transformer.inverse_transform_y(tnnr_nn_test_128.y_test_single),
            label='TNNR NN, $2\\times 128$ neurons', s=5)

plt.title('Function: $x^3 - 70x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()

# %% [markdown]
# # With training curves

# %%
n = 1000
seed = 9876

a = 70

# %%
# %%time

tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.5,
                          show_summary=False, show_loss_plot=True, show_rmse=False, 
                          mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                          num_nn_train=5)

tnnr_nn_test_128 = TNNR_NN(def_func(a), n=n, seed=seed, neurons=128, inverse_problem=True, test_pct=0.5,
                           show_summary=False, show_loss_plot=True, show_rmse=False, 
                           mdl_wts_file='weights/tnnr_nn_test_128_n' + str(n) + '_inverse_a' + str(a),
                           num_nn_train=5)
# Out:
# CPU times: user 1min 52s, sys: 21.8 s, total: 2min 14s
# Wall time: 1min 31s

# %%
print("RMSE of TNNR_NN 64:", tnnr_nn_test_64.rmse_test)
print("RMSE of TNNR_NN 128:", tnnr_nn_test_128.rmse_test)
# Out:
# RMSE of TNNR_NN 64: 6.902770340671583
# RMSE of TNNR_NN 128: 6.902773974921905

# %%
plt.scatter(tnnr_nn_test_64.cn_transformer.inverse_transform_x(tnnr_nn_test_64.x_train_single), 
            tnnr_nn_test_64.cn_transformer.inverse_transform_y(tnnr_nn_test_64.y_train_single),
            label='Train data set', s=1, c='#99ffff')
plt.scatter(tnnr_nn_test_64.x_pred_test,
            tnnr_nn_test_64.cn_transformer.inverse_transform_y(tnnr_nn_test_64.y_test_single),
            label='TNNR NN, $2\\times 64$ neurons', s=30)
plt.scatter(tnnr_nn_test_128.x_pred_test,
            tnnr_nn_test_128.cn_transformer.inverse_transform_y(tnnr_nn_test_128.y_test_single),
            label='TNNR NN, $2\\times 128$ neurons', s=5)

plt.title('Function: $x^3 - 70x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()

# %%
plt.plot(tnnr_nn_test_64.train_history.history['loss'], label='Train')
plt.plot(tnnr_nn_test_64.train_history.history['val_loss'], label='Val')
plt.ylim([0, 0.0005])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')

# %% [markdown]
# ## F = 0

# %%
n = 1000
seed = 9876

a = 70

# %%
# %%time

tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.5,
                          show_summary=False, show_loss_plot=True, show_rmse=False, 
                          mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                          num_nn_train=5)

tnnr_nn_test_128 = TNNR_NN(def_func(a), n=n, seed=seed, neurons=128, inverse_problem=True, test_pct=0.5,
                           show_summary=False, show_loss_plot=True, show_rmse=False, 
                           mdl_wts_file='weights/tnnr_nn_test_128_n' + str(n) + '_inverse_a' + str(a),
                           num_nn_train=5)
# Out:
# CPU times: user 1min 58s, sys: 22.4 s, total: 2min 20s
# Wall time: 1min 36s

# %%
plt.scatter(tnnr_nn_test_64.cn_transformer.inverse_transform_x(tnnr_nn_test_64.x_train_single), 
            tnnr_nn_test_64.cn_transformer.inverse_transform_y(tnnr_nn_test_64.y_train_single),
            label='Train data set', s=1, c='#99ffff')
plt.scatter(tnnr_nn_test_64.x_pred_test,
            tnnr_nn_test_64.cn_transformer.inverse_transform_y(tnnr_nn_test_64.y_test_single),
            label='TNNR NN, $2\\times 64$ neurons', s=30)
plt.scatter(tnnr_nn_test_128.x_pred_test,
            tnnr_nn_test_128.cn_transformer.inverse_transform_y(tnnr_nn_test_128.y_test_single),
            label='TNNR NN, $2\\times 128$ neurons', s=5)

plt.title('Function: $x^3 - 70x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()

# %%
print("RMSE of TNNR_NN 64:", tnnr_nn_test_64.rmse_test)
print("RMSE of TNNR_NN 128:", tnnr_nn_test_128.rmse_test)
# Out:
# RMSE of TNNR_NN 64: 6.902568625613587
# RMSE of TNNR_NN 128: 6.902568625613587

# %%
#plt.plot(tnnr_nn_test_64.mse_test_data[:,0][:,0], label='F = 0', linewidth=0.5)
#plt.scatter(tnnr_nn_test_64.x_pred_test[:,0][:,0],tnnr_nn_test_64.y_test_single, label='F = 0', s=0.2)
plt.plot(tnnr_nn_test_64.train_history.history['loss'], label='Train')
plt.plot(tnnr_nn_test_64.train_history.history['val_loss'], label='Val')
#plt.plot(pred_zero_test, label='F = 0')
#plt.scatter(pred_zero_test, tnnr_nn_test_64.y_test_single, label='F = 0')

#plt.ylim([0, 0.5])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')

# %%
x_mse_zero_test = []
for i in (range(len(tnnr_nn_test_64.x_test_single))):
    x_mse_zero_test.append((0 - tnnr_nn_test_64.x_test_single[i]) ** 2)

# %%
len(x_mse_zero_test)
# Out:
# 500

# %%
x_mse_zero_test = np.array(x_mse_zero_test) * tnnr_nn_test_64.cn_transformer.x_max ** 2

# %%
rmse_zero_test = np.average(x_mse_zero_test) ** 0.5

# %%
rmse_zero_test
# Out:
# 5.815129662246262

# %%
#plt.plot(tnnr_nn_test_64.mse_test_data[:,0][:,0], label='F = 0', linewidth=0.5)
#plt.scatter(tnnr_nn_test_64.x_pred_test[:,0][:,0],tnnr_nn_test_64.y_test_single, label='F = 0', s=0.2)
plt.plot(tnnr_nn_test_64.train_history.history['loss'], label='Train')
plt.plot(tnnr_nn_test_64.train_history.history['val_loss'], label='Val')
#plt.plot(x_mse_zero_test, label='F = 0')
#plt.scatter(x_mse_zero_test, tnnr_nn_test_64.y_test_single, label='F = 0')
plt.axhline(y = rmse_zero_test, color = 'r', linestyle = '-')

#plt.ylim([0, 0.5])
#plt.xlim([0, 10])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')

# %% [markdown]
# -------

# %% [markdown]
# ## con model malo

# %%
# %%time

tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.5,
                          show_summary=False, show_loss_plot=True, show_rmse=False, 
                          mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                          num_nn_train=5)

tnnr_nn_test_128 = TNNR_NN(def_func(a), n=n, seed=seed, neurons=128, inverse_problem=True, test_pct=0.5,
                           show_summary=False, show_loss_plot=True, show_rmse=False, 
                           mdl_wts_file='weights/tnnr_nn_test_128_n' + str(n) + '_inverse_a' + str(a),
                           num_nn_train=5)
# Out:
# CPU times: user 1min 53s, sys: 22.1 s, total: 2min 15s
# Wall time: 1min 32s

# %%
print("RMSE of TNNR_NN 64:", tnnr_nn_test_64.rmse_test)
print("RMSE of TNNR_NN 128:", tnnr_nn_test_128.rmse_test)
# Out:
# RMSE of TNNR_NN 64: 6.902568625613587
# RMSE of TNNR_NN 128: 6.902568625613587

# %%
plt.plot(tnnr_nn_test_64.train_history.history['loss'], label='Train')
plt.plot(tnnr_nn_test_64.train_history.history['val_loss'], label='Val')
#plt.axhline(y = tnnr_nn_test_64.rmse_test, color = 'r', linestyle = '-')

plt.ylim([0, 0.0001])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')

# %%
tnnr_nn_test_64.x_val_single.shape
# Out:
# (50, 1)

# %% [markdown]
# ## con model bueno

# %%
# %%time

tnnr_nn_test_64_b = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.5,
                          show_summary=False, show_loss_plot=True, show_rmse=False, 
                          mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                          num_nn_train=5)

tnnr_nn_test_128_b = TNNR_NN(def_func(a), n=n, seed=seed, neurons=128, inverse_problem=True, test_pct=0.5,
                           show_summary=False, show_loss_plot=True, show_rmse=False, 
                           mdl_wts_file='weights/tnnr_nn_test_128_n' + str(n) + '_inverse_a' + str(a),
                           num_nn_train=5)
# Out:
# CPU times: user 1min 54s, sys: 21.9 s, total: 2min 16s
# Wall time: 1min 33s

# %%
print("RMSE of TNNR_NN 64:", tnnr_nn_test_64_b.rmse_test)
print("RMSE of TNNR_NN 128:", tnnr_nn_test_128_b.rmse_test)
# Out:
# RMSE of TNNR_NN 64: 6.902568625613587
# RMSE of TNNR_NN 128: 6.902568625613587

# %%
plt.plot(tnnr_nn_test_64_b.train_history.history['loss'], label='Train')
plt.plot(tnnr_nn_test_64_b.train_history.history['val_loss'], label='Val')
plt.axhline(y = 6.9, color = 'r', linestyle = '-')

#plt.ylim([0, 0.5])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')

# %% [markdown]
# ---------

# %% [markdown]
# ## modelo malo (Lambda layer to 0) same size for val

# %%
import sys
sys.path.append("..")

from TwinNeuralNetworkNearestNeighbors import TNNR_NN

import matplotlib.pyplot as plt

import numpy as np

# %%
def_func = lambda a: lambda x: x**3 - a*x

# %%
n = 2100
seed = 9876

a = 70

# %%
# %%time

tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.3, val_pct=0.35,
                          show_summary=False, show_loss_plot=True, show_rmse=False, 
                          mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                          num_nn_train=5)
# Out:
# CPU times: user 3min 39s, sys: 39 s, total: 4min 18s
# Wall time: 3min

# %%
print("RMSE of TNNR_NN 64:", tnnr_nn_test_64.rmse_test)
# Out:
# RMSE of TNNR_NN 64: 6.863949722941514

# %%
tnnr_nn_test_64.x_val_single.shape
# Out:
# (735, 1)

# %%
tnnr_nn_test_64.x_train_single.shape
# Out:
# (735, 1)

# %% [markdown]
# ## modelo malo (Lambda layer to 0) num neighbors for val set like val pct from train set

# %%
import sys
sys.path.append("..")

from TwinNeuralNetworkNearestNeighbors import TNNR_NN

import matplotlib.pyplot as plt

import numpy as np

# %%
def_func = lambda a: lambda x: x**3 - a*x

# %%
n = 2100
seed = 9876

a = 70

# %%
# %%time

tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                          show_summary=False, show_loss_plot=True, show_rmse=False, 
                          mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                          num_nn_train=5)
# Out:
# num_neighbors = 5
# num_neighbors = 1
# CPU times: user 1min 43s, sys: 17.5 s, total: 2min
# Wall time: 1min 25s

# %%
plt.plot(tnnr_nn_test_64.train_history.history['loss'], label='Train')
plt.plot(tnnr_nn_test_64.train_history.history['val_loss'], label='Val')

plt.ylim([0, 1e-10])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')

# %%
# %%time

tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                          show_summary=False, show_loss_plot=True, show_rmse=False, 
                          mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                          num_nn_train=20)
# Out:
# num_neighbors = 20
# num_neighbors = 6
# CPU times: user 1min 53s, sys: 18.7 s, total: 2min 11s
# Wall time: 1min 31s

# %%
# %%time

tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.3, val_pct=0.4,
                          show_summary=False, show_loss_plot=True, show_rmse=False, 
                          mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                          num_nn_train=20)
# Out:
# num_neighbors = 20
# num_neighbors = 26
# CPU times: user 4min 32s, sys: 47.5 s, total: 5min 20s
# Wall time: 3min 44s

# %% [markdown]
# ### using at least 2 neighbors for val set

# %%
import sys
sys.path.append("..")

from TwinNeuralNetworkNearestNeighbors import TNNR_NN

import matplotlib.pyplot as plt

import numpy as np

# %%
n = 2100
seed = 9876

a = 70

# %%
def_func = lambda a: lambda x: x**3 - a*x

# %%
# %%time

tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                          show_summary=False, show_loss_plot=True, show_rmse=False, 
                          mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                          num_nn_train=5)
# Out:
# num_neighbors = 5
# num_neighbors = 1
# CPU times: user 3min 51s, sys: 39.2 s, total: 4min 31s
# Wall time: 3min 5s

# %% [markdown]
# ## modelo bueno (no extra layer) num neighbors for val set like val pct from train set

# %% [markdown]
# ### using at least 2 neighbors for val set

# %%
import sys
sys.path.append("..")

from TwinNeuralNetworkNearestNeighbors import TNNR_NN

import matplotlib.pyplot as plt

import numpy as np

# %%
def_func = lambda a: lambda x: x**3 - a*x

# %%
n = 2100
seed = 9876

a = 70

# %%
# %%time

tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                          show_summary=False, show_loss_plot=True, show_rmse=False, 
                          mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                          num_nn_train=5)
# Out:
# num_neighbors = 5
# num_neighbors = 1
# CPU times: user 3min 53s, sys: 40.6 s, total: 4min 33s
# Wall time: 3min 7s

# %%
plt.plot(tnnr_nn_test_64.train_history.history['loss'], label='Train')
plt.plot(tnnr_nn_test_64.train_history.history['val_loss'], label='Val')

plt.ylim([0, 0.00001])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')

# %% [markdown]
# -----------

# %% [markdown]
# # $F\neq 0$ when predicting (no extra layer en el modelo)

# %%
import sys
sys.path.append("..")

from TwinNeuralNetworkNearestNeighbors import TNNR_NN

import matplotlib.pyplot as plt

import numpy as np

# %%
def_func = lambda a: lambda x: x**3 - a*x

# %%
n = 2100
seed = 9876

a = 70

# %%
# %%time

tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                          show_summary=False, show_loss_plot=True, show_rmse=False, 
                          mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                          num_nn_train=5)
# Out:
# num_neighbors = 5
# num_neighbors = 1
# CPU times: user 3min 50s, sys: 39.4 s, total: 4min 30s
# Wall time: 3min 6s

# %%
plt.scatter(tnnr_nn_test_64.cn_transformer.inverse_transform_x(tnnr_nn_test_64.x_train_single), 
            tnnr_nn_test_64.cn_transformer.inverse_transform_y(tnnr_nn_test_64.y_train_single),
            label='Train data set', s=1, c='#99ffff')
plt.scatter(tnnr_nn_test_64.x_pred_test,
            tnnr_nn_test_64.cn_transformer.inverse_transform_y(tnnr_nn_test_64.y_test_single),
            label='TNNR NN, $2\\times 64$ neurons', s=30)

plt.title('Function: $x^3 - 70x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()

# %% [markdown]
# # $F = 0$ when predicting (no extra layer en el modelo)

# %%
# %%time

tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                          show_summary=False, show_loss_plot=True, show_rmse=False, 
                          mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                          num_nn_train=5,
                          zero_F_testing=True)
# Out:
# num_neighbors = 5
# num_neighbors = 1
# CPU times: user 3min 48s, sys: 40.1 s, total: 4min 28s
# Wall time: 3min 2s

# %%
plt.scatter(tnnr_nn_test_64.cn_transformer.inverse_transform_x(tnnr_nn_test_64.x_train_single), 
            tnnr_nn_test_64.cn_transformer.inverse_transform_y(tnnr_nn_test_64.y_train_single),
            label='Train data set', s=1, c='#99ffff')
plt.scatter(tnnr_nn_test_64.x_pred_test,
            tnnr_nn_test_64.cn_transformer.inverse_transform_y(tnnr_nn_test_64.y_test_single),
            label='TNNR NN, $2\\times 64$ neurons', s=30)

plt.title('Function: $x^3 - 70x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()

# %% [markdown]
# # $F = 0$ when training and $F = 0$ when predicting

# %%
# %%time

tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                          show_summary=False, show_loss_plot=True, show_rmse=False, 
                          mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                          num_nn_train=5,
                          zero_F_training=True,
                          zero_F_testing=True)
# Out:
# num_neighbors = 5
# num_neighbors = 1
# CPU times: user 3min 49s, sys: 38.2 s, total: 4min 27s
# Wall time: 3min 3s

# %%
plt.scatter(tnnr_nn_test_64.cn_transformer.inverse_transform_x(tnnr_nn_test_64.x_train_single), 
            tnnr_nn_test_64.cn_transformer.inverse_transform_y(tnnr_nn_test_64.y_train_single),
            label='Train data set', s=1, c='#99ffff')
plt.scatter(tnnr_nn_test_64.x_pred_test,
            tnnr_nn_test_64.cn_transformer.inverse_transform_y(tnnr_nn_test_64.y_test_single),
            label='TNNR NN, $2\\times 64$ neurons', s=30)

plt.title('Function: $x^3 - 70x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()
