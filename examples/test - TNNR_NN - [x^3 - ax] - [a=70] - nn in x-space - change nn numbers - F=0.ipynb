# %% [markdown]
# # F = 0

# %%
import sys
sys.path.append("..")

from TwinNeuralNetworkNearestNeighbors import TNNR_NN

import matplotlib.pyplot as plt

import numpy as np

from datetime import datetime

import gc

# %%
def_func = lambda a: lambda x: x**3 - a*x

# %%
n = 2100
seed = 23497

a = 70

# %% [markdown]
# ## num_nn_test=10
# ## radius_nn_predict=0.02
# ## radius_sub_nn_predict=0.01

# %%
# %%time

tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                          show_summary=False, show_loss_plot=True, show_rmse=True, 
                          mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                          num_nn_train=5,
                          num_nn_test=10,
                          radius_nn_predict=0.02,
                          radius_sub_nn_predict=0.01,
                          zero_F_training=True)
# Out:
# Test RMSE: 0.028127400539366503
# CPU times: user 20min 51s, sys: 23min 14s, total: 44min 5s
# Wall time: 10min 19s

# %%
plt.scatter(tnnr_nn_test_64.cn_transformer.inverse_transform_x(tnnr_nn_test_64.x_train_single), 
            tnnr_nn_test_64.cn_transformer.inverse_transform_y(tnnr_nn_test_64.y_train_single),
            label='Train data set', s=10, c='#99ffff')
plt.scatter(tnnr_nn_test_64.x_pred_test,
            tnnr_nn_test_64.y_pred_test,
            label='TNNR NN, $2\\times 64$ neurons', s=3)

plt.title('Function: $x^3 - 70x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()

# %% [markdown]
# ## num_nn_test=5
# ## radius_nn_predict=0.02
# ## radius_sub_nn_predict=0.01

# %%
# %%time

tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                          show_summary=False, show_loss_plot=True, show_rmse=True, 
                          mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                          num_nn_train=5,
                          num_nn_test=5,
                          radius_nn_predict=0.02,
                          radius_sub_nn_predict=0.01,
                          zero_F_training=True)
# Out:
# Test RMSE: 0.02883748313808436
# CPU times: user 12min 22s, sys: 13min 11s, total: 25min 34s
# Wall time: 6min 17s

# %%
plt.scatter(tnnr_nn_test_64.cn_transformer.inverse_transform_x(tnnr_nn_test_64.x_train_single), 
            tnnr_nn_test_64.cn_transformer.inverse_transform_y(tnnr_nn_test_64.y_train_single),
            label='Train data set', s=10, c='#99ffff')
plt.scatter(tnnr_nn_test_64.x_pred_test,
            tnnr_nn_test_64.y_pred_test,
            label='TNNR NN, $2\\times 64$ neurons', s=3)

plt.title('Function: $x^3 - 70x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()

# %% [markdown]
# ## num_nn_test=1
# ## radius_nn_predict=0.02
# ## radius_sub_nn_predict=0.01

# %%
# %%time

tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                          show_summary=False, show_loss_plot=True, show_rmse=True, 
                          mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                          num_nn_train=5,
                          num_nn_test=1,
                          radius_nn_predict=0.02,
                          radius_sub_nn_predict=0.01,
                          zero_F_training=True)
# Out:
# Test RMSE: 0.02878717372005931
# CPU times: user 5min 5s, sys: 3min 44s, total: 8min 49s
# Wall time: 3min 5s

# %%
plt.scatter(tnnr_nn_test_64.cn_transformer.inverse_transform_x(tnnr_nn_test_64.x_train_single), 
            tnnr_nn_test_64.cn_transformer.inverse_transform_y(tnnr_nn_test_64.y_train_single),
            label='Train data set', s=10, c='#99ffff')
plt.scatter(tnnr_nn_test_64.x_pred_test,
            tnnr_nn_test_64.y_pred_test,
            label='TNNR NN, $2\\times 64$ neurons', s=3)

plt.title('Function: $x^3 - 70x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()

# %% [markdown]
# ## num_nn_test=15
# ## radius_nn_predict=0.02
# ## radius_sub_nn_predict=0.01

# %%
# %%time

tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                          show_summary=False, show_loss_plot=True, show_rmse=True, 
                          mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                          num_nn_train=5,
                          num_nn_test=15,
                          radius_nn_predict=0.02,
                          radius_sub_nn_predict=0.01,
                          zero_F_training=True)
# Out:
# Test RMSE: 0.028043268782680413
# CPU times: user 29min 42s, sys: 35min 21s, total: 1h 5min 3s
# Wall time: 13min 50s

# %%
plt.scatter(tnnr_nn_test_64.cn_transformer.inverse_transform_x(tnnr_nn_test_64.x_train_single), 
            tnnr_nn_test_64.cn_transformer.inverse_transform_y(tnnr_nn_test_64.y_train_single),
            label='Train data set', s=10, c='#99ffff')
plt.scatter(tnnr_nn_test_64.x_pred_test,
            tnnr_nn_test_64.y_pred_test,
            label='TNNR NN, $2\\times 64$ neurons', s=3)

plt.title('Function: $x^3 - 70x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()

# %% [markdown]
# ## num_nn_test=20
# ## radius_nn_predict=0.02
# ## radius_sub_nn_predict=0.01

# %%
# %%time

tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                          show_summary=False, show_loss_plot=True, show_rmse=True, 
                          mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                          num_nn_train=5,
                          num_nn_test=20,
                          radius_nn_predict=0.02,
                          radius_sub_nn_predict=0.01,
                          zero_F_training=True)
# Out:
# Test RMSE: 0.02771195139381227
# CPU times: user 38min 30s, sys: 47min 53s, total: 1h 26min 24s
# Wall time: 1h 58min 8s

# %%
plt.scatter(tnnr_nn_test_64.cn_transformer.inverse_transform_x(tnnr_nn_test_64.x_train_single), 
            tnnr_nn_test_64.cn_transformer.inverse_transform_y(tnnr_nn_test_64.y_train_single),
            label='Train data set', s=10, c='#99ffff')
plt.scatter(tnnr_nn_test_64.x_pred_test,
            tnnr_nn_test_64.y_pred_test,
            label='TNNR NN, $2\\times 64$ neurons', s=3)

plt.title('Function: $x^3 - 70x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()

# %% [markdown]
# -----------

# %% [markdown]
# ## num_nn_test = 1
# ## radius_nn_predict = 0.005, 0.01, 0.015, 0.025, 0.03
# ## radius_sub_nn_predict = 0.01

# %%
num_nn_test = [1]
radius_nn_predict = [0.005, 0.01, 0.015, 0.025, 0.03]
radius_sub_nn_predict = [0.01]

# %%
# %%time

for nn_test in num_nn_test:
    for nn_predint in radius_nn_predict:
        for sub_nn_predict in radius_sub_nn_predict:

            start_time = datetime.now()

            tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                                      show_summary=False, show_loss_plot=False, show_rmse=True, 
                                      mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                                      num_nn_train=5,
                                      num_nn_test=nn_test,
                                      radius_nn_predict=nn_predint,
                                      radius_sub_nn_predict=sub_nn_predict,
                                      zero_F_training=True)

            end_time = datetime.now()
            print('Duration:              {}'.format(end_time - start_time))
            print('num_nn_test:           {}'.format(nn_test))
            print('radius_nn_predict:     {}'.format(nn_predint))
            print('radius_sub_nn_predict: {}'.format(sub_nn_predict))
            print()
# Out:
# Test RMSE: 0.011918425428210313
# Duration:              0:02:41.693381
# num_nn_test:           1
# radius_nn_predict:     0.005
# radius_sub_nn_predict: 0.01
# Test RMSE: 0.024524221162712724
# Duration:              0:02:48.733519
# num_nn_test:           1
# radius_nn_predict:     0.01
# radius_sub_nn_predict: 0.01
# Test RMSE: 0.024944369081893434
# Duration:              0:02:54.783397
# num_nn_test:           1
# radius_nn_predict:     0.015
# radius_sub_nn_predict: 0.01
# Test RMSE: 0.031260480083889416
# Duration:              0:02:55.100998
# num_nn_test:           1
# radius_nn_predict:     0.025
# radius_sub_nn_predict: 0.01
# Test RMSE: 0.03616578905577721
# Duration:              0:03:05.235151
# num_nn_test:           1
# radius_nn_predict:     0.03
# radius_sub_nn_predict: 0.01
# CPU times: user 29min 6s, sys: 20min 34s, total: 49min 40s
# Wall time: 14min 25s

# %% [markdown]
# -----------

# %% [markdown]
# ## num_nn_test = 1
# ## radius_nn_predict = 0.025
# ## radius_sub_nn_predict = 0.001, 0.005, 0.015, 0.02, 0.025

# %%
num_nn_test = [1]
radius_nn_predict = [0.025]
radius_sub_nn_predict = [0.001, 0.005, 0.015, 0.02, 0.025]

# %%
# %%time

for nn_test in num_nn_test:
    for nn_predint in radius_nn_predict:
        for sub_nn_predict in radius_sub_nn_predict:

            start_time = datetime.now()

            tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                                      show_summary=False, show_loss_plot=False, show_rmse=True, 
                                      mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                                      num_nn_train=5,
                                      num_nn_test=nn_test,
                                      radius_nn_predict=nn_predint,
                                      radius_sub_nn_predict=sub_nn_predict,
                                      zero_F_training=True)

            end_time = datetime.now()
            print('Duration:              {}'.format(end_time - start_time))
            print('num_nn_test:           {}'.format(nn_test))
            print('radius_nn_predict:     {}'.format(nn_predint))
            print('radius_sub_nn_predict: {}'.format(sub_nn_predict))
            print()
# Out:
# Test RMSE: 0.025521936100277833
# Duration:              0:06:51.661840
# num_nn_test:           1
# radius_nn_predict:     0.025
# radius_sub_nn_predict: 0.001
#
# Test RMSE: 0.026133867581794076
# Duration:              0:03:59.169826
# num_nn_test:           1
# radius_nn_predict:     0.025
# radius_sub_nn_predict: 0.005
#
# Test RMSE: 0.04084326931696085
# Duration:              0:03:02.468454
# num_nn_test:           1
# radius_nn_predict:     0.025
# radius_sub_nn_predict: 0.015
#
# Test RMSE: 0.05113036988803468
# Duration:              0:26:19.633135
# num_nn_test:           1
# radius_nn_predict:     0.025
# radius_sub_nn_predict: 0.02
#
# Test RMSE: 0.06727561912398979
# Duration:              0:02:38.785123
# num_nn_test:           1
# radius_nn_predict:     0.025
# radius_sub_nn_predict: 0.025
#
# CPU times: user 36min 50s, sys: 32min 12s, total: 1h 9min 2s
# Wall time: 42min 51s

# %% [markdown]
# -----------

# %% [markdown]
# ## num_nn_test = 15
# ## radius_nn_predict = 0.005, 0.01, 0.015, 0.025, 0.03
# ## radius_sub_nn_predict = 0.01

# %%
num_nn_test = [15]
radius_nn_predict = [0.005, 0.01, 0.015, 0.025, 0.03]
radius_sub_nn_predict = [0.01]

# %%
# %%time

for nn_test in num_nn_test:
    for nn_predint in radius_nn_predict:
        for sub_nn_predict in radius_sub_nn_predict:

            start_time = datetime.now()

            tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                                      show_summary=False, show_loss_plot=False, show_rmse=True, 
                                      mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                                      num_nn_train=5,
                                      num_nn_test=nn_test,
                                      radius_nn_predict=nn_predint,
                                      radius_sub_nn_predict=sub_nn_predict,
                                      zero_F_training=True)

            end_time = datetime.now()
            print('Duration:              {}'.format(end_time - start_time))
            print('num_nn_test:           {}'.format(nn_test))
            print('radius_nn_predict:     {}'.format(nn_predint))
            print('radius_sub_nn_predict: {}'.format(sub_nn_predict))
            print()
# Out:
# Test RMSE: 0.010968750807033346
# Duration:              0:06:02.706124
# num_nn_test:           15
# radius_nn_predict:     0.005
# radius_sub_nn_predict: 0.01
#
# Test RMSE: 0.02507028865143177
# Duration:              0:08:27.870377
# num_nn_test:           15
# radius_nn_predict:     0.01
# radius_sub_nn_predict: 0.01
#
# Test RMSE: 0.02501026982654567
# Duration:              0:11:17.195651
# num_nn_test:           15
# radius_nn_predict:     0.015
# radius_sub_nn_predict: 0.01
#
# Test RMSE: 0.03109021659865472
# Duration:              0:15:56.257323
# num_nn_test:           15
# radius_nn_predict:     0.025
# radius_sub_nn_predict: 0.01
#
# Test RMSE: 0.03360706954298592
# Duration:              0:18:26.523993
# num_nn_test:           15
# radius_nn_predict:     0.03
# radius_sub_nn_predict: 0.01
#
# CPU times: user 2h 8min 44s, sys: 2h 33min 57s, total: 4h 42min 41s
# Wall time: 1h 10s

# %% [markdown]
# ------------

# %% [markdown]
# ## num_nn_test = 15
# ## radius_nn_predict = 0.005
# ## radius_sub_nn_predict = 0.0001, 0.0005, 0.001, 0.005, 0.015

# %%
num_nn_test = [15]
radius_nn_predict = [0.005]
radius_sub_nn_predict = [0.0001, 0.0005, 0.001, 0.005, 0.015]

# %%
# %%time

for nn_test in num_nn_test:
    for nn_predint in radius_nn_predict:
        for sub_nn_predict in radius_sub_nn_predict:

            start_time = datetime.now()

            tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                                      show_summary=False, show_loss_plot=False, show_rmse=True, 
                                      mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                                      num_nn_train=5,
                                      num_nn_test=nn_test,
                                      radius_nn_predict=nn_predint,
                                      radius_sub_nn_predict=sub_nn_predict,
                                      zero_F_training=True)

            end_time = datetime.now()
            print('Duration:              {}'.format(end_time - start_time))
            print('num_nn_test:           {}'.format(nn_test))
            print('radius_nn_predict:     {}'.format(nn_predint))
            print('radius_sub_nn_predict: {}'.format(sub_nn_predict))
            print()
# Out:
# Test RMSE: 0.010854842258983985
# Duration:              0:27:22.200864
# num_nn_test:           15
# radius_nn_predict:     0.005
# radius_sub_nn_predict: 0.0001
#
# Test RMSE: 0.01032705546606929
# Duration:              0:22:04.754001
# num_nn_test:           15
# radius_nn_predict:     0.005
# radius_sub_nn_predict: 0.0005
#
# Test RMSE: 0.010350458187227586
# Duration:              0:17:29.437175
# num_nn_test:           15
# radius_nn_predict:     0.005
# radius_sub_nn_predict: 0.001
#
# Test RMSE: 0.012828519581805094
# Duration:              0:08:03.597136
# num_nn_test:           15
# radius_nn_predict:     0.005
# radius_sub_nn_predict: 0.005
#
# Test RMSE: 0.010968750807033346
# Duration:              0:06:06.362816
# num_nn_test:           15
# radius_nn_predict:     0.005
# radius_sub_nn_predict: 0.015
#
# CPU times: user 3h 34s, sys: 3h 42min 1s, total: 6h 42min 36s
# Wall time: 1h 21min 6s

# %% [markdown]
# --------------

# %% [markdown]
# ## num_nn_test = 10
# ## radius_nn_predict = 0.005, 0.01, 0.015, 0.025, 0.03
# ## radius_sub_nn_predict = 0.01

# %%
num_nn_test = [10]
radius_nn_predict = [0.005, 0.01, 0.015, 0.025, 0.03]
radius_sub_nn_predict = [0.01]

# %%
# %%time

for nn_test in num_nn_test:
    for nn_predint in radius_nn_predict:
        for sub_nn_predict in radius_sub_nn_predict:

            start_time = datetime.now()

            tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                                      show_summary=False, show_loss_plot=False, show_rmse=True, 
                                      mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                                      num_nn_train=5,
                                      num_nn_test=nn_test,
                                      radius_nn_predict=nn_predint,
                                      radius_sub_nn_predict=sub_nn_predict,
                                      zero_F_training=True)

            end_time = datetime.now()
            print('Duration:              {}'.format(end_time - start_time))
            print('num_nn_test:           {}'.format(nn_test))
            print('radius_nn_predict:     {}'.format(nn_predint))
            print('radius_sub_nn_predict: {}'.format(sub_nn_predict))
            print()
# Out:
# Test RMSE: 0.011056077295888082
# Duration:              0:04:59.834451
# num_nn_test:           10
# radius_nn_predict:     0.005
# radius_sub_nn_predict: 0.01
#
# Test RMSE: 0.024803072285351255
# Duration:              0:06:33.681825
# num_nn_test:           10
# radius_nn_predict:     0.01
# radius_sub_nn_predict: 0.01
#
# Test RMSE: 0.02486464881767897
# Duration:              0:08:04.644473
# num_nn_test:           10
# radius_nn_predict:     0.015
# radius_sub_nn_predict: 0.01
#
# Test RMSE: 0.031226462795884497
# Duration:              0:11:44.780126
# num_nn_test:           10
# radius_nn_predict:     0.025
# radius_sub_nn_predict: 0.01

# %%
# Out:
# Test RMSE: 0.03411728090558845
# Duration:              0:12:46.874197
# num_nn_test:           10
# radius_nn_predict:     0.03
# radius_sub_nn_predict: 0.01
#
# CPU times: user 59min, sys: 57min 21s, total: 1h 56min 21s
# Wall time: 12min 46s

# %% [markdown]
# --------------

# %% [markdown]
# ## num_nn_test = 10
# ## radius_nn_predict = 0.03
# ## radius_sub_nn_predict = 0.005, 0.015, 0.02, 0.025, 0.03

# %%
num_nn_test = [10]
radius_nn_predict = [0.03]
radius_sub_nn_predict = [0.005, 0.015, 0.02, 0.025, 0.03]

# %%
# %%time

for nn_test in num_nn_test:
    for nn_predint in radius_nn_predict:
        for sub_nn_predict in radius_sub_nn_predict:

            start_time = datetime.now()

            tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                                      show_summary=False, show_loss_plot=False, show_rmse=True, 
                                      mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                                      num_nn_train=5,
                                      num_nn_test=nn_test,
                                      radius_nn_predict=nn_predint,
                                      radius_sub_nn_predict=sub_nn_predict,
                                      zero_F_training=True)

            end_time = datetime.now()
            print('Duration:              {}'.format(end_time - start_time))
            print('num_nn_test:           {}'.format(nn_test))
            print('radius_nn_predict:     {}'.format(nn_predint))
            print('radius_sub_nn_predict: {}'.format(sub_nn_predict))
            print()
# Out:
# Test RMSE: 0.027492638025680374
# Duration:              0:21:26.649292
# num_nn_test:           10
# radius_nn_predict:     0.03
# radius_sub_nn_predict: 0.005
#
# Test RMSE: 0.040303818972446885
# Duration:              0:09:57.651974
# num_nn_test:           10
# radius_nn_predict:     0.03
# radius_sub_nn_predict: 0.015
#
# Test RMSE: 0.047403557414038344
# Duration:              0:08:22.023991
# num_nn_test:           10
# radius_nn_predict:     0.03
# radius_sub_nn_predict: 0.02
#
# Test RMSE: 0.06060302234582758
# Duration:              0:07:24.993983
# num_nn_test:           10
# radius_nn_predict:     0.03
# radius_sub_nn_predict: 0.025
#
# Test RMSE: 0.08117452713410192
# Duration:              0:06:45.216807
# num_nn_test:           10
# radius_nn_predict:     0.03
# radius_sub_nn_predict: 0.03
#
# CPU times: user 2h 2min 25s, sys: 2h 32min 19s, total: 4h 34min 45s
# Wall time: 53min 56s

# %% [markdown]
# -----------

# %% [markdown]
# ## num_nn_test = 20
# ## radius_nn_predict = (0.005, 0.01, 0.015,) 0.025, 0.03
# ## radius_sub_nn_predict = 0.01

# %%
num_nn_test = [20]
radius_nn_predict = [0.025, 0.03]  # results from [0.005, 0.01, 0.015] are in colab nb
radius_sub_nn_predict = [0.01]

# %%
# %%time

for nn_test in num_nn_test:
    for nn_predint in radius_nn_predict:
        for sub_nn_predict in radius_sub_nn_predict:

            start_time = datetime.now()

            tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                                      show_summary=False, show_loss_plot=False, show_rmse=True, 
                                      mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                                      num_nn_train=5,
                                      num_nn_test=nn_test,
                                      radius_nn_predict=nn_predint,
                                      radius_sub_nn_predict=sub_nn_predict,
                                      zero_F_training=True)

            end_time = datetime.now()
            print('Duration:              {}'.format(end_time - start_time))
            print('num_nn_test:           {}'.format(nn_test))
            print('radius_nn_predict:     {}'.format(nn_predint))
            print('radius_sub_nn_predict: {}'.format(sub_nn_predict))
            print()
# Out:
# Test RMSE: 0.030136421836476843
# Duration:              0:21:16.457796
# num_nn_test:           20
# radius_nn_predict:     0.025
# radius_sub_nn_predict: 0.01
#
# Test RMSE: 0.03266949806815732
# Duration:              0:23:37.427804
# num_nn_test:           20
# radius_nn_predict:     0.03
# radius_sub_nn_predict: 0.01
#
# CPU times: user 2h 32min, sys: 2h 50min 1s, total: 5h 22min 2s
# Wall time: 44min 53s

# %% [markdown]
# --------------

# %% [markdown]
# ## num_nn_train = 2, 7, 10, 15, 20
# ## num_nn_test = 10
# ## radius_nn_predict = 0.03
# ## radius_sub_nn_predict = 0.005

# %%
num_nn_train = [2, 7, 10, 15, 20]
num_nn_test = [10]
radius_nn_predict = [0.03]
radius_sub_nn_predict = [0.005]

# %%
# %%time

for nn_train in num_nn_train:
    for nn_test in num_nn_test:
        for nn_predint in radius_nn_predict:
            for sub_nn_predict in radius_sub_nn_predict:

                start_time = datetime.now()

                tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                                          show_summary=False, show_loss_plot=False, show_rmse=True, 
                                          mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                                          num_nn_train=nn_train,
                                          num_nn_test=nn_test,
                                          radius_nn_predict=nn_predint,
                                          radius_sub_nn_predict=sub_nn_predict,
                                          zero_F_training=True)

                end_time = datetime.now()
                print('Duration:              {}'.format(end_time - start_time))
                print('num_nn_train:          {}'.format(nn_train))
                print('num_nn_test:           {}'.format(nn_test))
                print('radius_nn_predict:     {}'.format(nn_predint))
                print('radius_sub_nn_predict: {}'.format(sub_nn_predict))
                print()
# Out:
# Test RMSE: 0.02745430516846103
# Duration:              0:22:32.137334
# num_nn_train:          2
# num_nn_test:           10
# radius_nn_predict:     0.03
# radius_sub_nn_predict: 0.005
#
# Test RMSE: 0.02757483907402568
# Duration:              0:22:19.485740
# num_nn_train:          7
# num_nn_test:           10
# radius_nn_predict:     0.03
# radius_sub_nn_predict: 0.005
#
# Test RMSE: 0.027621221305587623
# Duration:              0:21:42.665689
# num_nn_train:          10
# num_nn_test:           10
# radius_nn_predict:     0.03
# radius_sub_nn_predict: 0.005
#
# Test RMSE: 0.027580139413125628
# Duration:              0:21:01.284566
# num_nn_train:          15
# num_nn_test:           10
# radius_nn_predict:     0.03
# radius_sub_nn_predict: 0.005
#
# Test RMSE: 0.02773620476215976
# Duration:              0:20:35.553416
# num_nn_train:          20
# num_nn_test:           10
# radius_nn_predict:     0.03
# radius_sub_nn_predict: 0.005
#
# CPU times: user 4h 13min 26s, sys: 5h 25min 36s, total: 9h 39min 3s
# Wall time: 1h 48min 11s

# %% [markdown]
# ---------

# %% [markdown]
# ## num_nn_train = 2, 7, 10, 15, 20
# ## num_nn_test = 15
# ## radius_nn_predict = 0.005
# ## radius_sub_nn_predict = 0.0005

# %%
num_nn_train = [2, 7, 10] #, 15, 20]
num_nn_test = [15]
radius_nn_predict = [0.005]
radius_sub_nn_predict = [0.0005]

# %%
# %%time

for nn_train in num_nn_train:
    for nn_test in num_nn_test:
        for nn_predint in radius_nn_predict:
            for sub_nn_predict in radius_sub_nn_predict:

                start_time = datetime.now()

                tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                                          show_summary=False, show_loss_plot=False, show_rmse=True, 
                                          mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                                          num_nn_train=nn_train,
                                          num_nn_test=nn_test,
                                          radius_nn_predict=nn_predint,
                                          radius_sub_nn_predict=sub_nn_predict,
                                          zero_F_training=True)

                end_time = datetime.now()
                print('Duration:              {}'.format(end_time - start_time))
                print('num_nn_train:          {}'.format(nn_train))
                print('num_nn_test:           {}'.format(nn_test))
                print('radius_nn_predict:     {}'.format(nn_predint))
                print('radius_sub_nn_predict: {}'.format(sub_nn_predict))
                print()
# Out:
# Test RMSE: 0.010334345122585076
# Duration:              0:21:37.016941
# num_nn_train:          2
# num_nn_test:           15
# radius_nn_predict:     0.005
# radius_sub_nn_predict: 0.0005
#
# Test RMSE: 0.01033553044947351
# Duration:              0:21:09.777682
# num_nn_train:          7
# num_nn_test:           15
# radius_nn_predict:     0.005
# radius_sub_nn_predict: 0.0005
#
# Test RMSE: 0.010327643851247145
# Duration:              0:21:03.614192
# num_nn_train:          10
# num_nn_test:           15
# radius_nn_predict:     0.005
# radius_sub_nn_predict: 0.0005

# %%
num_nn_train = [15, 20]  # results for 2, 7, 10, in previous cell
num_nn_test = [15]
radius_nn_predict = [0.005]
radius_sub_nn_predict = [0.0005]

# %%
# %%time

for nn_train in num_nn_train:
    for nn_test in num_nn_test:
        for nn_predint in radius_nn_predict:
            for sub_nn_predict in radius_sub_nn_predict:

                start_time = datetime.now()

                tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                                          show_summary=False, show_loss_plot=False, show_rmse=True, 
                                          mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                                          num_nn_train=nn_train,
                                          num_nn_test=nn_test,
                                          radius_nn_predict=nn_predint,
                                          radius_sub_nn_predict=sub_nn_predict,
                                          zero_F_training=True)

                end_time = datetime.now()
                print('Duration:              {}'.format(end_time - start_time))
                print('num_nn_train:          {}'.format(nn_train))
                print('num_nn_test:           {}'.format(nn_test))
                print('radius_nn_predict:     {}'.format(nn_predint))
                print('radius_sub_nn_predict: {}'.format(sub_nn_predict))
                print()
# Out:
# Test RMSE: 0.010319780747754921
# Duration:              0:20:42.699290
# num_nn_train:          15
# num_nn_test:           15
# radius_nn_predict:     0.005
# radius_sub_nn_predict: 0.0005
#
# Test RMSE: 0.010323387616632533
# Duration:              0:20:20.501221
# num_nn_train:          20
# num_nn_test:           15
# radius_nn_predict:     0.005
# radius_sub_nn_predict: 0.0005
#
# CPU times: user 2h 50min 58s, sys: 3h 7min 55s, total: 5h 58min 53s
# Wall time: 41min 3s

# %%
# %%time

# test for RAM and time, the TNNR has no layers but the one with F=0

num_nn_train = [20]
num_nn_test = [15]
radius_nn_predict = [0.005]
radius_sub_nn_predict = [0.0005]

for nn_train in num_nn_train:
    for nn_test in num_nn_test:
        for nn_predint in radius_nn_predict:
            for sub_nn_predict in radius_sub_nn_predict:

                start_time = datetime.now()

                tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                                          show_summary=False, show_loss_plot=False, show_rmse=True, 
                                          mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                                          num_nn_train=nn_train,
                                          num_nn_test=nn_test,
                                          radius_nn_predict=nn_predint,
                                          radius_sub_nn_predict=sub_nn_predict,
                                          zero_F_training=True,
                                          zero_F_testing=True)

                end_time = datetime.now()
                print('Duration:              {}'.format(end_time - start_time))
                print('num_nn_train:          {}'.format(nn_train))
                print('num_nn_test:           {}'.format(nn_test))
                print('radius_nn_predict:     {}'.format(nn_predint))
                print('radius_sub_nn_predict: {}'.format(sub_nn_predict))
                print()
# Out:
# Test RMSE: 0.010323387616632537
# Duration:              0:20:23.846585
# num_nn_train:          20
# num_nn_test:           15
# radius_nn_predict:     0.005
# radius_sub_nn_predict: 0.0005
#
# CPU times: user 1h 32min 28s, sys: 1h 44min 50s, total: 3h 17min 19s
# Wall time: 20min 23s

# %%
# no hubo ganancia ^
# poner las capas de la TNNR o no (salvo la de F=0), da lo mismo en tiempo y parece que en RAM también

# %% [markdown]
# ---------------

# %%
import sys
sys.path.append("..")

from TwinNeuralNetworkNearestNeighbors import TNNR_NN

import matplotlib.pyplot as plt

import numpy as np

from datetime import datetime

import gc

# %%
def_func = lambda a: lambda x: x**3 - a*x

# %%
n = 2100
seed = 23497

a = 70

# %% [markdown]
# ## num_nn_train = 5
# ## num_nn_test = 20
# ## radius_nn_predict = 0.01
# ## radius_sub_nn_predict = 0.0005, 0.001, 0.005, 0.008, 0.015

# %%
num_nn_train = [5]
num_nn_test = [20]
radius_nn_predict = [0.01]
radius_sub_nn_predict = [0.0005, 0.001, 0.005]#, 0.008, 0.015]

# %%
# %%time

for nn_train in num_nn_train:
    for nn_test in num_nn_test:
        for nn_predint in radius_nn_predict:
            for sub_nn_predict in radius_sub_nn_predict:

                start_time = datetime.now()

                tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                                          show_summary=False, show_loss_plot=False, show_rmse=True, 
                                          mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                                          num_nn_train=nn_train,
                                          num_nn_test=nn_test,
                                          radius_nn_predict=nn_predint,
                                          radius_sub_nn_predict=sub_nn_predict,
                                          zero_F_training=True)

                end_time = datetime.now()
                print('Duration:              {}'.format(end_time - start_time))
                print('num_nn_train:          {}'.format(nn_train))
                print('num_nn_test:           {}'.format(nn_test))
                print('radius_nn_predict:     {}'.format(nn_predint))
                print('radius_sub_nn_predict: {}'.format(sub_nn_predict))
                print()
                
                del tnnr_nn_test_64
                del start_time
                del end_time
                gc.collect()
# Out:
# Test RMSE: 0.015539308654644356
# Duration:              0:49:01.384323
# num_nn_train:          5
# num_nn_test:           20
# radius_nn_predict:     0.01
# radius_sub_nn_predict: 0.0005
#
# Test RMSE: 0.014922465363015183
# Duration:              0:38:38.526805
# num_nn_train:          5
# num_nn_test:           20
# radius_nn_predict:     0.01
# radius_sub_nn_predict: 0.001
#
# Test RMSE: 0.015881167156294607
# Duration:              0:15:48.320767
# num_nn_train:          5
# num_nn_test:           20
# radius_nn_predict:     0.01
# radius_sub_nn_predict: 0.005
#
# CPU times: user 8h 19min 6s, sys: 8h 53min 57s, total: 17h 13min 3s
# Wall time: 1h 43min 28s

# %%
num_nn_train = [5]
num_nn_test = [20]
radius_nn_predict = [0.01]
radius_sub_nn_predict = [0.008, 0.015] # 0.0005, 0.001, 0.005

# %%
# %%time

for nn_train in num_nn_train:
    for nn_test in num_nn_test:
        for nn_predint in radius_nn_predict:
            for sub_nn_predict in radius_sub_nn_predict:

                start_time = datetime.now()

                tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                                          show_summary=False, show_loss_plot=False, show_rmse=True, 
                                          mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                                          num_nn_train=nn_train,
                                          num_nn_test=nn_test,
                                          radius_nn_predict=nn_predint,
                                          radius_sub_nn_predict=sub_nn_predict,
                                          zero_F_training=True)

                end_time = datetime.now()
                print('Duration:              {}'.format(end_time - start_time))
                print('num_nn_train:          {}'.format(nn_train))
                print('num_nn_test:           {}'.format(nn_test))
                print('radius_nn_predict:     {}'.format(nn_predint))
                print('radius_sub_nn_predict: {}'.format(sub_nn_predict))
                print()
                
                del tnnr_nn_test_64
                del start_time
                del end_time
                gc.collect()
# Out:
# Test RMSE: 0.023491489379145913
# Duration:              0:12:25.429647
# num_nn_train:          5
# num_nn_test:           20
# radius_nn_predict:     0.01
# radius_sub_nn_predict: 0.008
#
# Test RMSE: 0.023220330855601837
# Duration:              0:07:58.071944
# num_nn_train:          5
# num_nn_test:           20
# radius_nn_predict:     0.01
# radius_sub_nn_predict: 0.015
#
# CPU times: user 1h 23min 42s, sys: 1h 29min 25s, total: 2h 53min 7s
# Wall time: 20min 23s

# %% [markdown]
# ------------

# %% [markdown]
# ## num_nn_train = 12, 13, 14, 16, 17
# ## num_nn_test = 15
# ## radius_nn_predict = 0.005
# ## radius_sub_nn_predict = 0.0005

# %%
num_nn_train = [12] #, 13, 14, 16, 17]
num_nn_test = [15]
radius_nn_predict = [0.005]
radius_sub_nn_predict = [0.0005]

# %%
# %%time

for nn_train in num_nn_train:
    for nn_test in num_nn_test:
        for nn_predint in radius_nn_predict:
            for sub_nn_predict in radius_sub_nn_predict:

                start_time = datetime.now()

                tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                                          show_summary=False, show_loss_plot=False, show_rmse=True, 
                                          mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                                          num_nn_train=nn_train,
                                          num_nn_test=nn_test,
                                          radius_nn_predict=nn_predint,
                                          radius_sub_nn_predict=sub_nn_predict,
                                          zero_F_training=True)

                end_time = datetime.now()
                print('Duration:              {}'.format(end_time - start_time))
                print('num_nn_train:          {}'.format(nn_train))
                print('num_nn_test:           {}'.format(nn_test))
                print('radius_nn_predict:     {}'.format(nn_predint))
                print('radius_sub_nn_predict: {}'.format(sub_nn_predict))
                print()
# Out:
# Test RMSE: 0.010318509219284037
# Duration:              0:21:49.183930
# num_nn_train:          12
# num_nn_test:           15
# radius_nn_predict:     0.005
# radius_sub_nn_predict: 0.0005

# %%
num_nn_train = [13]#, 14, 16, 17] # 12
num_nn_test = [15]
radius_nn_predict = [0.005]
radius_sub_nn_predict = [0.0005]

# %%
# %%time

for nn_train in num_nn_train:
    for nn_test in num_nn_test:
        for nn_predint in radius_nn_predict:
            for sub_nn_predict in radius_sub_nn_predict:

                start_time = datetime.now()

                tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                                          show_summary=False, show_loss_plot=False, show_rmse=True, 
                                          mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                                          num_nn_train=nn_train,
                                          num_nn_test=nn_test,
                                          radius_nn_predict=nn_predint,
                                          radius_sub_nn_predict=sub_nn_predict,
                                          zero_F_training=True)

                end_time = datetime.now()
                print('Duration:              {}'.format(end_time - start_time))
                print('num_nn_train:          {}'.format(nn_train))
                print('num_nn_test:           {}'.format(nn_test))
                print('radius_nn_predict:     {}'.format(nn_predint))
                print('radius_sub_nn_predict: {}'.format(sub_nn_predict))
                print()
                
                del tnnr_nn_test_64
                del start_time
                del end_time
                gc.collect()
# Out:
# Test RMSE: 0.010317383310882654
# Duration:              0:23:30.183320
# num_nn_train:          13
# num_nn_test:           15
# radius_nn_predict:     0.005
# radius_sub_nn_predict: 0.0005

# %%
num_nn_train = [14, 16, 17] # 12, 13
num_nn_test = [15]
radius_nn_predict = [0.005]
radius_sub_nn_predict = [0.0005]

# %%
# %%time

for nn_train in num_nn_train:
    for nn_test in num_nn_test:
        for nn_predint in radius_nn_predict:
            for sub_nn_predict in radius_sub_nn_predict:

                start_time = datetime.now()

                tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                                          show_summary=False, show_loss_plot=False, show_rmse=True, 
                                          mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                                          num_nn_train=nn_train,
                                          num_nn_test=nn_test,
                                          radius_nn_predict=nn_predint,
                                          radius_sub_nn_predict=sub_nn_predict,
                                          zero_F_training=True)

                end_time = datetime.now()
                print('Duration:              {}'.format(end_time - start_time))
                print('num_nn_train:          {}'.format(nn_train))
                print('num_nn_test:           {}'.format(nn_test))
                print('radius_nn_predict:     {}'.format(nn_predint))
                print('radius_sub_nn_predict: {}'.format(sub_nn_predict))
                print()
                
                del tnnr_nn_test_64
                del start_time
                del end_time
                gc.collect()
# Out:
# Test RMSE: 0.010319746584343903
# Duration:              0:21:10.625307
# num_nn_train:          14
# num_nn_test:           15
# radius_nn_predict:     0.005
# radius_sub_nn_predict: 0.0005
#
# Test RMSE: 0.010338255416607437
# Duration:              0:21:15.133168
# num_nn_train:          16
# num_nn_test:           15
# radius_nn_predict:     0.005
# radius_sub_nn_predict: 0.0005
#
# Test RMSE: 0.010330554819475595
# Duration:              0:20:04.089189
# num_nn_train:          17
# num_nn_test:           15
# radius_nn_predict:     0.005
# radius_sub_nn_predict: 0.0005
#
# CPU times: user 4h 39min 12s, sys: 5h 11min 4s, total: 9h 50min 16s
# Wall time: 1h 2min 30s

# %% [markdown]
# ------------

# %% [markdown]
# ## num_nn_train = 30, 30, 13
# ## num_nn_test = 15
# ## radius_nn_predict = 0.005, 0.1, 0.1
# ## radius_sub_nn_predict = 0.0005, 0.05, 0.05

# %%
import sys
sys.path.append("..")

from TwinNeuralNetworkNearestNeighbors import TNNR_NN

import matplotlib.pyplot as plt

import numpy as np

from datetime import datetime

import gc

# %%
def_func = lambda a: lambda x: x**3 - a*x

# %%
n = 2100
seed = 23497

a = 70

# %%
num_nn_train = [30]
num_nn_test = [15]
radius_nn_predict = [0.005]
radius_sub_nn_predict = [0.0005]

# %%
# %%time

for nn_train in num_nn_train:
    for nn_test in num_nn_test:
        for nn_predint in radius_nn_predict:
            for sub_nn_predict in radius_sub_nn_predict:

                start_time = datetime.now()

                tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                                          show_summary=False, show_loss_plot=False, show_rmse=True, 
                                          mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                                          num_nn_train=nn_train,
                                          num_nn_test=nn_test,
                                          radius_nn_predict=nn_predint,
                                          radius_sub_nn_predict=sub_nn_predict,
                                          zero_F_training=True)

                end_time = datetime.now()
                print('Duration:              {}'.format(end_time - start_time))
                print('num_nn_train:          {}'.format(nn_train))
                print('num_nn_test:           {}'.format(nn_test))
                print('radius_nn_predict:     {}'.format(nn_predint))
                print('radius_sub_nn_predict: {}'.format(sub_nn_predict))
                print()
                
                del tnnr_nn_test_64
                del start_time
                del end_time
                gc.collect()
# Out:
# Test RMSE: 0.01031414831124847
# Duration:              0:20:00.237936
# num_nn_train:          30
# num_nn_test:           15
# radius_nn_predict:     0.005
# radius_sub_nn_predict: 0.0005
#
# CPU times: user 1h 35min 39s, sys: 1h 42min 42s, total: 3h 18min 21s
# Wall time: 20min

# %%
gc.collect()
# Out:
# 2432

# %%
num_nn_train = [30]
num_nn_test = [15]
radius_nn_predict = [0.1]
radius_sub_nn_predict = [0.05]

# %%
# %%time

for nn_train in num_nn_train:
    for nn_test in num_nn_test:
        for nn_predint in radius_nn_predict:
            for sub_nn_predict in radius_sub_nn_predict:

                start_time = datetime.now()

                tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                                          show_summary=False, show_loss_plot=False, show_rmse=True, 
                                          mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                                          num_nn_train=nn_train,
                                          num_nn_test=nn_test,
                                          radius_nn_predict=nn_predint,
                                          radius_sub_nn_predict=sub_nn_predict,
                                          zero_F_training=True)

                end_time = datetime.now()
                print('Duration:              {}'.format(end_time - start_time))
                print('num_nn_train:          {}'.format(nn_train))
                print('num_nn_test:           {}'.format(nn_test))
                print('radius_nn_predict:     {}'.format(nn_predint))
                print('radius_sub_nn_predict: {}'.format(sub_nn_predict))
                print()
                
                del tnnr_nn_test_64
                del start_time
                del end_time
                gc.collect()
# Out:
# Test RMSE: 0.15169966629137668
# Duration:              0:13:25.031092
# num_nn_train:          30
# num_nn_test:           15
# radius_nn_predict:     0.1
# radius_sub_nn_predict: 0.05
#
# CPU times: user 42min 7s, sys: 40min 29s, total: 1h 22min 37s
# Wall time: 13min 25s

# %%
gc.collect()
# Out:
# 2432

# %%
num_nn_train = [13]
num_nn_test = [15]
radius_nn_predict = [0.1]
radius_sub_nn_predict = [0.05]

# %%
# %%time

for nn_train in num_nn_train:
    for nn_test in num_nn_test:
        for nn_predint in radius_nn_predict:
            for sub_nn_predict in radius_sub_nn_predict:

                start_time = datetime.now()

                tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                                          show_summary=False, show_loss_plot=False, show_rmse=True, 
                                          mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                                          num_nn_train=nn_train,
                                          num_nn_test=nn_test,
                                          radius_nn_predict=nn_predint,
                                          radius_sub_nn_predict=sub_nn_predict,
                                          zero_F_training=True)

                end_time = datetime.now()
                print('Duration:              {}'.format(end_time - start_time))
                print('num_nn_train:          {}'.format(nn_train))
                print('num_nn_test:           {}'.format(nn_test))
                print('radius_nn_predict:     {}'.format(nn_predint))
                print('radius_sub_nn_predict: {}'.format(sub_nn_predict))
                print()
                
                del tnnr_nn_test_64
                del start_time
                del end_time
                gc.collect()
# Out:
# Test RMSE: 0.1518736939635666
# Duration:              0:14:50.555926
# num_nn_train:          13
# num_nn_test:           15
# radius_nn_predict:     0.1
# radius_sub_nn_predict: 0.05
#
# CPU times: user 44min 15s, sys: 41min 20s, total: 1h 25min 36s
# Wall time: 14min 50s

# %%
gc.collect()
# Out:
# 2432

# %% [markdown]
# ------------

# %%
import sys
sys.path.append("..")

from TwinNeuralNetworkNearestNeighbors import TNNR_NN

import matplotlib.pyplot as plt

import numpy as np

from datetime import datetime

import gc

# %%
def_func = lambda a: lambda x: x**3 - a*x

# %%
n = 2100
seed = 23497

a = 70

# %% [markdown]
# ## layers: 128, 128, 1
# ## num_nn_train = 5
# ## num_nn_test = 10, 5, 1, 15, 20
# ## radius_nn_predict = 0.02
# ## radius_sub_nn_predict = 0.01

# %%
num_nn_train = [5]
num_nn_test = [10, 5, 1, 15, 20]
radius_nn_predict = [0.02]
radius_sub_nn_predict = [0.01]

# %%
# %%time

for nn_train in num_nn_train:
    for nn_test in num_nn_test:
        for nn_predint in radius_nn_predict:
            for sub_nn_predict in radius_sub_nn_predict:

                start_time = datetime.now()

                tnnr_nn_test_64 = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                                          show_summary=False, show_loss_plot=False, show_rmse=True, 
                                          mdl_wts_file='weights/tnnr_nn_test_64_n' + str(n) + '_inverse_a' + str(a),
                                          neurons=128,
                                          num_nn_train=nn_train,
                                          num_nn_test=nn_test,
                                          radius_nn_predict=nn_predint,
                                          radius_sub_nn_predict=sub_nn_predict,
                                          zero_F_training=True)

                end_time = datetime.now()
                print('Duration:              {}'.format(end_time - start_time))
                print('num_nn_train:          {}'.format(nn_train))
                print('num_nn_test:           {}'.format(nn_test))
                print('radius_nn_predict:     {}'.format(nn_predint))
                print('radius_sub_nn_predict: {}'.format(sub_nn_predict))
                print()
                
                del tnnr_nn_test_64
                del start_time
                del end_time
                gc.collect()
# Out:
# Test RMSE: 0.028127400539366503
# Duration:              0:09:41.144246
# num_nn_train:          5
# num_nn_test:           10
# radius_nn_predict:     0.02
# radius_sub_nn_predict: 0.01
#
# Test RMSE: 0.02883748313808436
# Duration:              0:05:51.962487
# num_nn_train:          5
# num_nn_test:           5
# radius_nn_predict:     0.02
# radius_sub_nn_predict: 0.01
#
# Test RMSE: 0.02878717372005931
# Duration:              0:02:54.582798
# num_nn_train:          5
# num_nn_test:           1
# radius_nn_predict:     0.02
# radius_sub_nn_predict: 0.01
#
# Test RMSE: 0.028043268782680413
# Duration:              0:13:18.874935
# num_nn_train:          5
# num_nn_test:           15
# radius_nn_predict:     0.02
# radius_sub_nn_predict: 0.01
#
# Test RMSE: 0.02771195139381227
# Duration:              0:16:54.167405
# num_nn_train:          5
# num_nn_test:           20
# radius_nn_predict:     0.02
# radius_sub_nn_predict: 0.01
#
# CPU times: user 3h 17min 35s, sys: 3h 27min 30s, total: 6h 45min 5s
# Wall time: 48min 41s
