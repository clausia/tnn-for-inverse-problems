# %%
import sys
sys.path.append("..")

from TwinNeuralNetworkNearestNeighbors import TNNR_NN

import matplotlib.pyplot as plt

import numpy as np

from datetime import datetime

import gc

# %%
def_func = lambda a: lambda x: x**3 - a*x

# %%
n = 2100
seed = 23497

a = 70

# %% [markdown]
# ## Simple noise

# %%
# %%time

tnnr_nn_test_64_fnorm = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                                show_summary=False, show_loss_plot=True, show_rmse=True, 
                                mdl_wts_file='weights/tnnr_nn_test_64_fnorm_n' + str(n) + '_inverse_a' + str(a),
                                num_nn_train=5,
                                num_nn_test=1,
                                radius_nn_predict=0.005,
                                radius_sub_nn_predict=0.0005,
                                noise_range_x=(-0.5, 0.5),
                                noise_range_y=(-1, 1))
# Out:
# Test RMSE (plain):                                6.882401270751803
# Test RMSE (back to y-space):                      40.54783418259807
# Test RMSE (min among clusters):                   6.861939808211379
# Test RMSE (transformed back):                     6.882401270751803
# Test RMSE (min among clusters, transformed back): 6.861939808211379
# CPU times: user 10min 37s, sys: 7min 25s, total: 18min 2s
# Wall time: 4min 28s

# %%
gc.collect()
# Out:
# 2630

# %%
# %%time

tnnr_nn_test_64_fzero = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                                show_summary=False, show_loss_plot=True, show_rmse=True, 
                                mdl_wts_file='weights/tnnr_nn_test_64_fzero_n' + str(n) + '_inverse_a' + str(a),
                                num_nn_train=5,
                                num_nn_test=1,
                                radius_nn_predict=0.005,
                                radius_sub_nn_predict=0.0005,
                                zero_F_training=True,
                                noise_range_x=(-0.5, 0.5),
                                noise_range_y=(-1, 1))
# Out:
# Test RMSE (plain):                                6.8824205933878995
# Test RMSE (back to y-space):                      40.6117942630555
# Test RMSE (min among clusters):                   6.8617040436494
# Test RMSE (transformed back):                     6.8824205933878995
# Test RMSE (min among clusters, transformed back): 6.8617040436494
# CPU times: user 10min 37s, sys: 7min 25s, total: 18min 2s
# Wall time: 4min 30s

# %%
gc.collect()
# Out:
# 23332

# %%
plt.plot(tnnr_nn_test_64_fnorm.train_history.history['loss'], label='Train (normal F)')
plt.plot(tnnr_nn_test_64_fnorm.train_history.history['val_loss'], label='Val (normal F)')

plt.plot(tnnr_nn_test_64_fzero.train_history.history['loss'], label='Train (F = 0)')
plt.plot(tnnr_nn_test_64_fzero.train_history.history['val_loss'], label='Val (F = 0)')

plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')

# %%
plt.scatter(tnnr_nn_test_64_fnorm.cn_transformer.inverse_transform_x(tnnr_nn_test_64_fnorm.x_train_single), 
            tnnr_nn_test_64_fnorm.cn_transformer.inverse_transform_y(tnnr_nn_test_64_fnorm.y_train_single),
            label='Train data set', s=50, c='#99ffff')
plt.scatter(tnnr_nn_test_64_fnorm.x_pred_test,
            tnnr_nn_test_64_fnorm.y_pred_test,
            label='TNNR NN, Normal F, $2\\times 64$ neurons', s=20)
plt.scatter(tnnr_nn_test_64_fnorm.x_pred_test,
            tnnr_nn_test_64_fnorm.y_pred_test,
            label='TNNR NN, F = 0, $2\\times 64$ neurons', s=1)

plt.title('Function: $x^3 - 70x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend(loc=6)

# %%
gc.collect()
# Out:
# 1962

# %%
# %%time

tnnr_nn_test_64_fnorm = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                                show_summary=False, show_loss_plot=True, show_rmse=True, 
                                mdl_wts_file='weights/tnnr_nn_test_64_fnorm_n' + str(n) + '_inverse_a' + str(a),
                                num_nn_train=5,
                                num_nn_test=1,
                                radius_nn_predict=0.005,
                                radius_sub_nn_predict=0.01,
                                noise_range_x=(-0.5, 0.5),
                                noise_range_y=(-1, 1))
# Out:
# Test RMSE (plain):                                6.8822850502198385
# Test RMSE (back to y-space):                      40.54118588376632
# Test RMSE (min among clusters):                   6.8822850502198385
# Test RMSE (transformed back):                     6.8822850502198385
# Test RMSE (min among clusters, transformed back): 6.8822850502198385
# CPU times: user 5min 29s, sys: 2min 1s, total: 7min 31s
# Wall time: 3min 37s

# %%
gc.collect()
# Out:
# 1578

# %%
# %%time

tnnr_nn_test_64_fzero = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                                show_summary=False, show_loss_plot=True, show_rmse=True, 
                                mdl_wts_file='weights/tnnr_nn_test_64_fzero_n' + str(n) + '_inverse_a' + str(a),
                                num_nn_train=5,
                                num_nn_test=1,
                                radius_nn_predict=0.005,
                                radius_sub_nn_predict=0.01,
                                zero_F_training=True,
                                noise_range_x=(-0.5, 0.5),
                                noise_range_y=(-1, 1))
# Out:
# Test RMSE (plain):                                6.882310556962521
# Test RMSE (back to y-space):                      40.60078051357038
# Test RMSE (min among clusters):                   6.882310556962521
# Test RMSE (transformed back):                     6.882310556962521
# Test RMSE (min among clusters, transformed back): 6.882310556962521
# CPU times: user 5min 21s, sys: 2min 3s, total: 7min 25s
# Wall time: 3min 30s

# %%
gc.collect()
# Out:
# 3131

# %%
plt.plot(tnnr_nn_test_64_fnorm.train_history.history['loss'], label='Train (normal F)')
plt.plot(tnnr_nn_test_64_fnorm.train_history.history['val_loss'], label='Val (normal F)')

plt.plot(tnnr_nn_test_64_fzero.train_history.history['loss'], label='Train (F = 0)')
plt.plot(tnnr_nn_test_64_fzero.train_history.history['val_loss'], label='Val (F = 0)')

plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')

# %%
plt.scatter(tnnr_nn_test_64_fnorm.cn_transformer.inverse_transform_x(tnnr_nn_test_64_fnorm.x_train_single), 
            tnnr_nn_test_64_fnorm.cn_transformer.inverse_transform_y(tnnr_nn_test_64_fnorm.y_train_single),
            label='Train data set', s=50, c='#99ffff')
plt.scatter(tnnr_nn_test_64_fnorm.x_pred_test,
            tnnr_nn_test_64_fnorm.y_pred_test,
            label='TNNR NN, Normal F, $2\\times 64$ neurons', s=20)
plt.scatter(tnnr_nn_test_64_fnorm.x_pred_test,
            tnnr_nn_test_64_fnorm.y_pred_test,
            label='TNNR NN, F = 0, $2\\times 64$ neurons', s=1)

plt.title('Function: $x^3 - 70x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend(loc=6)

# %%
gc.collect()
# Out:
# 1943

# %%
# %%time

tnnr_nn_test_64_fnorm = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                                show_summary=False, show_loss_plot=True, show_rmse=True, 
                                mdl_wts_file='weights/tnnr_nn_test_64_fnorm_n' + str(n) + '_inverse_a' + str(a),
                                num_nn_train=5,
                                num_nn_test=2,
                                radius_nn_predict=0.005,
                                radius_sub_nn_predict=0.0005,
                                noise_range_x=(-0.5, 0.5),
                                noise_range_y=(-1, 1))
# Out:
# Test RMSE (plain):                                6.955149615744601
# Test RMSE (back to y-space):                      40.054541583052874
# Test RMSE (min among clusters):                   5.77528309172854
# Test RMSE (transformed back):                     6.9551496157446
# Test RMSE (min among clusters, transformed back): 5.77528309172854
# CPU times: user 18min 3s, sys: 14min 9s, total: 32min 12s
# Wall time: 5min 41s

# %%
gc.collect()
# Out:
# 4685

# %%
# %%time

tnnr_nn_test_64_fzero = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                                show_summary=False, show_loss_plot=True, show_rmse=True, 
                                mdl_wts_file='weights/tnnr_nn_test_64_fzero_n' + str(n) + '_inverse_a' + str(a),
                                num_nn_train=5,
                                num_nn_test=2,
                                radius_nn_predict=0.005,
                                radius_sub_nn_predict=0.0005,
                                zero_F_training=True,
                                noise_range_x=(-0.5, 0.5),
                                noise_range_y=(-1, 1))
# Out:
# Test RMSE (plain):                                6.955171553750882
# Test RMSE (back to y-space):                      40.108367416063686
# Test RMSE (min among clusters):                   5.775139517322832
# Test RMSE (transformed back):                     6.955171553750882
# Test RMSE (min among clusters, transformed back): 5.775139517322832
# CPU times: user 17min 20s, sys: 14min 21s, total: 31min 41s
# Wall time: 5min 46s

# %%
40.054541583052874 - 40.108367416063686
# Out:
# -0.05382583301081212

# %%
gc.collect()
# Out:
# 86269

# %%
plt.plot(tnnr_nn_test_64_fnorm.train_history.history['loss'], label='Train (normal F)')
plt.plot(tnnr_nn_test_64_fnorm.train_history.history['val_loss'], label='Val (normal F)')

plt.plot(tnnr_nn_test_64_fzero.train_history.history['loss'], label='Train (F = 0)')
plt.plot(tnnr_nn_test_64_fzero.train_history.history['val_loss'], label='Val (F = 0)')

plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')

# %%
plt.scatter(tnnr_nn_test_64_fnorm.cn_transformer.inverse_transform_x(tnnr_nn_test_64_fnorm.x_train_single), 
            tnnr_nn_test_64_fnorm.cn_transformer.inverse_transform_y(tnnr_nn_test_64_fnorm.y_train_single),
            label='Train data set', s=50, c='#99ffff')
plt.scatter(tnnr_nn_test_64_fnorm.x_pred_test,
            tnnr_nn_test_64_fnorm.y_pred_test,
            label='TNNR NN, Normal F, $2\\times 64$ neurons', s=20)
plt.scatter(tnnr_nn_test_64_fnorm.x_pred_test,
            tnnr_nn_test_64_fnorm.y_pred_test,
            label='TNNR NN, F = 0, $2\\times 64$ neurons', s=1)

plt.title('Function: $x^3 - 70x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend(loc=6)

# %%
gc.collect()
# Out:
# 1943

# %%
# %%time

tnnr_nn_test_64_fnorm = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                                show_summary=False, show_loss_plot=True, show_rmse=True, 
                                mdl_wts_file='weights/tnnr_nn_test_64_fnorm_n' + str(n) + '_inverse_a' + str(a),
                                num_nn_train=5,
                                num_nn_test=2,
                                radius_nn_predict=0.005,
                                radius_sub_nn_predict=0.01,
                                noise_range_x=(-0.5, 0.5),
                                noise_range_y=(-1, 1))
# Out:
# Test RMSE (plain):                                6.955057226735219
# Test RMSE (back to y-space):                      40.061227476508996
# Test RMSE (min among clusters):                   5.794416824987955
# Test RMSE (transformed back):                     6.955057226735219
# Test RMSE (min among clusters, transformed back): 5.794416824987955
# CPU times: user 6min 44s, sys: 3min 12s, total: 9min 57s
# Wall time: 3min 43s

# %%
gc.collect()
# Out:
# 71505

# %%
# %%time

tnnr_nn_test_64_fzero = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                                show_summary=False, show_loss_plot=True, show_rmse=True, 
                                mdl_wts_file='weights/tnnr_nn_test_64_fzero_n' + str(n) + '_inverse_a' + str(a),
                                num_nn_train=5,
                                num_nn_test=2,
                                radius_nn_predict=0.005,
                                radius_sub_nn_predict=0.01,
                                zero_F_training=True,
                                noise_range_x=(-0.5, 0.5),
                                noise_range_y=(-1, 1))
# Out:
# Test RMSE (plain):                                6.955060150671324
# Test RMSE (back to y-space):                      40.1139772185137
# Test RMSE (min among clusters):                   5.794466778779877
# Test RMSE (transformed back):                     6.955060150671323
# Test RMSE (min among clusters, transformed back): 5.794466778779877
# CPU times: user 6min 46s, sys: 3min 18s, total: 10min 5s
# Wall time: 3min 50s

# %%
gc.collect()
# Out:
# 72283

# %%
plt.plot(tnnr_nn_test_64_fnorm.train_history.history['loss'], label='Train (normal F)')
plt.plot(tnnr_nn_test_64_fnorm.train_history.history['val_loss'], label='Val (normal F)')

plt.plot(tnnr_nn_test_64_fzero.train_history.history['loss'], label='Train (F = 0)')
plt.plot(tnnr_nn_test_64_fzero.train_history.history['val_loss'], label='Val (F = 0)')

plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')

# %%
plt.scatter(tnnr_nn_test_64_fnorm.cn_transformer.inverse_transform_x(tnnr_nn_test_64_fnorm.x_train_single), 
            tnnr_nn_test_64_fnorm.cn_transformer.inverse_transform_y(tnnr_nn_test_64_fnorm.y_train_single),
            label='Train data set', s=50, c='#99ffff')
plt.scatter(tnnr_nn_test_64_fnorm.x_pred_test,
            tnnr_nn_test_64_fnorm.y_pred_test,
            label='TNNR NN, Normal F, $2\\times 64$ neurons', s=20)
plt.scatter(tnnr_nn_test_64_fnorm.x_pred_test,
            tnnr_nn_test_64_fnorm.y_pred_test,
            label='TNNR NN, F = 0, $2\\times 64$ neurons', s=1)

plt.title('Function: $x^3 - 70x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend(loc=6)

# %%
gc.collect()
# Out:
# 1943

# %%
# %%time

tnnr_nn_test_64_fnorm = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                                show_summary=False, show_loss_plot=True, show_rmse=True, 
                                mdl_wts_file='weights/tnnr_nn_test_64_fnorm_n' + str(n) + '_inverse_a' + str(a),
                                num_nn_train=5,
                                num_nn_test=3,
                                radius_nn_predict=0.005,
                                radius_sub_nn_predict=0.0005,
                                noise_range_x=(-0.5, 0.5),
                                noise_range_y=(-1, 1))
# Out:
# Test RMSE (plain):                                6.944845624510695
# Test RMSE (back to y-space):                      39.43669537291139
# Test RMSE (min among clusters):                   5.180057419316331
# Test RMSE (transformed back):                     6.944845624510694
# Test RMSE (min among clusters, transformed back): 5.180057419316331
# CPU times: user 24min 6s, sys: 21min 22s, total: 45min 28s
# Wall time: 7min 3s

# %%
gc.collect()
# Out:
# 8569

# %%
# %%time

tnnr_nn_test_64_fzero = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                                show_summary=False, show_loss_plot=True, show_rmse=True, 
                                mdl_wts_file='weights/tnnr_nn_test_64_fzero_n' + str(n) + '_inverse_a' + str(a),
                                num_nn_train=5,
                                num_nn_test=3,
                                radius_nn_predict=0.005,
                                radius_sub_nn_predict=0.0005,
                                zero_F_training=True,
                                noise_range_x=(-0.5, 0.5),
                                noise_range_y=(-1, 1))
# Out:
# Test RMSE (plain):                                6.944837462464925
# Test RMSE (back to y-space):                      39.473443066448816
# Test RMSE (min among clusters):                   5.179954181967231
# Test RMSE (transformed back):                     6.944837462464925
# Test RMSE (min among clusters, transformed back): 5.179954181967231
# CPU times: user 24min 29s, sys: 21min 13s, total: 45min 42s
# Wall time: 7min 3s

# %%
39.473443066448816 - 39.43669537291139
# Out:
# 0.03674769353742846

# %%
gc.collect()
# Out:
# 122011

# %%
plt.plot(tnnr_nn_test_64_fnorm.train_history.history['loss'], label='Train (normal F)')
plt.plot(tnnr_nn_test_64_fnorm.train_history.history['val_loss'], label='Val (normal F)')

plt.plot(tnnr_nn_test_64_fzero.train_history.history['loss'], label='Train (F = 0)')
plt.plot(tnnr_nn_test_64_fzero.train_history.history['val_loss'], label='Val (F = 0)')

plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')

# %%
plt.scatter(tnnr_nn_test_64_fnorm.cn_transformer.inverse_transform_x(tnnr_nn_test_64_fnorm.x_train_single), 
            tnnr_nn_test_64_fnorm.cn_transformer.inverse_transform_y(tnnr_nn_test_64_fnorm.y_train_single),
            label='Train data set', s=50, c='#99ffff')
plt.scatter(tnnr_nn_test_64_fnorm.x_pred_test,
            tnnr_nn_test_64_fnorm.y_pred_test,
            label='TNNR NN, Normal F, $2\\times 64$ neurons', s=20)
plt.scatter(tnnr_nn_test_64_fnorm.x_pred_test,
            tnnr_nn_test_64_fnorm.y_pred_test,
            label='TNNR NN, F = 0, $2\\times 64$ neurons', s=1)

plt.title('Function: $x^3 - 70x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend(loc=6)

# %%
gc.collect()
# Out:
# 1901

# %% [markdown]
# ## Gaussian noise

# %%
# %%time

tnnr_nn_test_64_fnorm = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                                show_summary=False, show_loss_plot=True, show_rmse=True, 
                                mdl_wts_file='weights/tnnr_nn_test_64_fnorm_n' + str(n) + '_inverse_a' + str(a),
                                num_nn_train=5,
                                num_nn_test=1,
                                radius_nn_predict=0.005,
                                radius_sub_nn_predict=0.0005,
                                noise_normal_x=(0, 0.5),
                                noise_normal_y=(0, 5))
# Out:
# Test RMSE (plain):                                6.600714765089633
# Test RMSE (back to y-space):                      64.56678054015141
# Test RMSE (min among clusters):                   6.575780815041038
# Test RMSE (transformed back):                     6.600714765089633
# Test RMSE (min among clusters, transformed back): 6.575780815041038
# CPU times: user 10min 2s, sys: 8min 1s, total: 18min 4s
# Wall time: 3min 52s

# %%
gc.collect()
# Out:
# 51304

# %%
# %%time

tnnr_nn_test_64_fzero = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                                show_summary=False, show_loss_plot=True, show_rmse=True, 
                                mdl_wts_file='weights/tnnr_nn_test_64_fzero_n' + str(n) + '_inverse_a' + str(a),
                                num_nn_train=5,
                                num_nn_test=1,
                                radius_nn_predict=0.005,
                                radius_sub_nn_predict=0.0005,
                                zero_F_training=True,
                                noise_normal_x=(0, 0.5),
                                noise_normal_y=(0, 5))
# Out:
# Test RMSE (plain):                                6.600735459788734
# Test RMSE (back to y-space):                      64.62829607059405
# Test RMSE (min among clusters):                   6.5755448121699835
# Test RMSE (transformed back):                     6.600735459788734
# Test RMSE (min among clusters, transformed back): 6.5755448121699835
# CPU times: user 10min 22s, sys: 7min 46s, total: 18min 9s
# Wall time: 3min 38s

# %%
gc.collect()
# Out:
# 45853

# %%
plt.plot(tnnr_nn_test_64_fnorm.train_history.history['loss'], label='Train (normal F)')
plt.plot(tnnr_nn_test_64_fnorm.train_history.history['val_loss'], label='Val (normal F)')

plt.plot(tnnr_nn_test_64_fzero.train_history.history['loss'], label='Train (F = 0)')
plt.plot(tnnr_nn_test_64_fzero.train_history.history['val_loss'], label='Val (F = 0)')

plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')

# %%
plt.scatter(tnnr_nn_test_64_fnorm.cn_transformer.inverse_transform_x(tnnr_nn_test_64_fnorm.x_train_single), 
            tnnr_nn_test_64_fnorm.cn_transformer.inverse_transform_y(tnnr_nn_test_64_fnorm.y_train_single),
            label='Train data set', s=50, c='#99ffff')
plt.scatter(tnnr_nn_test_64_fnorm.x_pred_test,
            tnnr_nn_test_64_fnorm.y_pred_test,
            label='TNNR NN, Normal F, $2\\times 64$ neurons', s=20)
plt.scatter(tnnr_nn_test_64_fnorm.x_pred_test,
            tnnr_nn_test_64_fnorm.y_pred_test,
            label='TNNR NN, F = 0, $2\\times 64$ neurons', s=1)

plt.title('Function: $x^3 - 70x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend(loc=6)

# %%
gc.collect()
# Out:
# 1059

# %%
# %%time

tnnr_nn_test_64_fnorm = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                                show_summary=False, show_loss_plot=True, show_rmse=True, 
                                mdl_wts_file='weights/tnnr_nn_test_64_fnorm_n' + str(n) + '_inverse_a' + str(a),
                                num_nn_train=5,
                                num_nn_test=1,
                                radius_nn_predict=0.005,
                                radius_sub_nn_predict=0.01,
                                noise_normal_x=(0, 0.5),
                                noise_normal_y=(0, 5))
# Out:
# Test RMSE (plain):                                6.600377472781865
# Test RMSE (back to y-space):                      64.57146425091398
# Test RMSE (min among clusters):                   6.600377472781865
# Test RMSE (transformed back):                     6.600377472781864
# Test RMSE (min among clusters, transformed back): 6.600377472781864
# CPU times: user 4min 11s, sys: 1min 50s, total: 6min 1s
# Wall time: 2min 38s

# %%
gc.collect()
# Out:
# 86137

# %%
# %%time

tnnr_nn_test_64_fzero = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                                show_summary=False, show_loss_plot=True, show_rmse=True, 
                                mdl_wts_file='weights/tnnr_nn_test_64_fzero_n' + str(n) + '_inverse_a' + str(a),
                                num_nn_train=5,
                                num_nn_test=1,
                                radius_nn_predict=0.005,
                                radius_sub_nn_predict=0.01,
                                zero_F_training=True,
                                noise_normal_x=(0, 0.5),
                                noise_normal_y=(0, 5))
# Out:
# Test RMSE (plain):                                6.600400617546674
# Test RMSE (back to y-space):                      64.62353123867635
# Test RMSE (min among clusters):                   6.600400617546674
# Test RMSE (transformed back):                     6.600400617546674
# Test RMSE (min among clusters, transformed back): 6.600400617546674
# CPU times: user 4min 3s, sys: 1min 52s, total: 5min 56s
# Wall time: 2min 34s

# %%
gc.collect()
# Out:
# 86435

# %%
plt.plot(tnnr_nn_test_64_fnorm.train_history.history['loss'], label='Train (normal F)')
plt.plot(tnnr_nn_test_64_fnorm.train_history.history['val_loss'], label='Val (normal F)')

plt.plot(tnnr_nn_test_64_fzero.train_history.history['loss'], label='Train (F = 0)')
plt.plot(tnnr_nn_test_64_fzero.train_history.history['val_loss'], label='Val (F = 0)')

plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')

# %%
plt.scatter(tnnr_nn_test_64_fnorm.cn_transformer.inverse_transform_x(tnnr_nn_test_64_fnorm.x_train_single), 
            tnnr_nn_test_64_fnorm.cn_transformer.inverse_transform_y(tnnr_nn_test_64_fnorm.y_train_single),
            label='Train data set', s=50, c='#99ffff')
plt.scatter(tnnr_nn_test_64_fnorm.x_pred_test,
            tnnr_nn_test_64_fnorm.y_pred_test,
            label='TNNR NN, Normal F, $2\\times 64$ neurons', s=20)
plt.scatter(tnnr_nn_test_64_fnorm.x_pred_test,
            tnnr_nn_test_64_fnorm.y_pred_test,
            label='TNNR NN, F = 0, $2\\times 64$ neurons', s=1)

plt.title('Function: $x^3 - 70x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend(loc=6)

# %%
gc.collect()
# Out:
# 1058

# %%
# %%time

tnnr_nn_test_64_fnorm = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                                show_summary=False, show_loss_plot=True, show_rmse=True, 
                                mdl_wts_file='weights/tnnr_nn_test_64_fnorm_n' + str(n) + '_inverse_a' + str(a),
                                num_nn_train=5,
                                num_nn_test=2,
                                radius_nn_predict=0.005,
                                radius_sub_nn_predict=0.0005,
                                noise_normal_x=(0, 0.5),
                                noise_normal_y=(0, 5))
# Out:
# Test RMSE (plain):                                6.708692023414273
# Test RMSE (back to y-space):                      63.469020015639764
# Test RMSE (min among clusters):                   5.52291759845944
# Test RMSE (transformed back):                     6.708692023414273
# Test RMSE (min among clusters, transformed back): 5.52291759845944
# CPU times: user 16min 17s, sys: 15min 22s, total: 31min 39s
# Wall time: 5min 8s

# %%
gc.collect()
# Out:
# 100255

# %%
# %%time

tnnr_nn_test_64_fzero = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                                show_summary=False, show_loss_plot=True, show_rmse=True, 
                                mdl_wts_file='weights/tnnr_nn_test_64_fzero_n' + str(n) + '_inverse_a' + str(a),
                                num_nn_train=5,
                                num_nn_test=2,
                                radius_nn_predict=0.005,
                                radius_sub_nn_predict=0.0005,
                                zero_F_training=True,
                                noise_normal_x=(0, 0.5),
                                noise_normal_y=(0, 5))
# Out:
# Test RMSE (plain):                                6.7086408814322755
# Test RMSE (back to y-space):                      63.51263048499639
# Test RMSE (min among clusters):                   5.522703753015516
# Test RMSE (transformed back):                     6.708640881432275
# Test RMSE (min among clusters, transformed back): 5.522703753015516
# CPU times: user 16min 18s, sys: 15min 11s, total: 31min 30s
# Wall time: 4min 59s

# %%
    gc.collect()
# Out:
# 84697

# %%
plt.plot(tnnr_nn_test_64_fnorm.train_history.history['loss'], label='Train (normal F)')
plt.plot(tnnr_nn_test_64_fnorm.train_history.history['val_loss'], label='Val (normal F)')

plt.plot(tnnr_nn_test_64_fzero.train_history.history['loss'], label='Train (F = 0)')
plt.plot(tnnr_nn_test_64_fzero.train_history.history['val_loss'], label='Val (F = 0)')

plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')

# %%
plt.scatter(tnnr_nn_test_64_fnorm.cn_transformer.inverse_transform_x(tnnr_nn_test_64_fnorm.x_train_single), 
            tnnr_nn_test_64_fnorm.cn_transformer.inverse_transform_y(tnnr_nn_test_64_fnorm.y_train_single),
            label='Train data set', s=50, c='#99ffff')
plt.scatter(tnnr_nn_test_64_fnorm.x_pred_test,
            tnnr_nn_test_64_fnorm.y_pred_test,
            label='TNNR NN, Normal F, $2\\times 64$ neurons', s=20)
plt.scatter(tnnr_nn_test_64_fnorm.x_pred_test,
            tnnr_nn_test_64_fnorm.y_pred_test,
            label='TNNR NN, F = 0, $2\\times 64$ neurons', s=1)

plt.title('Function: $x^3 - 70x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend(loc=6)

# %%
gc.collect()
# Out:
# 1058

# %%
# %%time

tnnr_nn_test_64_fnorm = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                                show_summary=False, show_loss_plot=True, show_rmse=True, 
                                mdl_wts_file='weights/tnnr_nn_test_64_fnorm_n' + str(n) + '_inverse_a' + str(a),
                                num_nn_train=5,
                                num_nn_test=2,
                                radius_nn_predict=0.005,
                                radius_sub_nn_predict=0.01,
                                noise_normal_x=(0, 0.5),
                                noise_normal_y=(0, 5))
# Out:
# Test RMSE (plain):                                6.708326937505256
# Test RMSE (back to y-space):                      63.49914228727918
# Test RMSE (min among clusters):                   5.545499041575649
# Test RMSE (transformed back):                     6.708326937505256
# Test RMSE (min among clusters, transformed back): 5.545499041575649
# CPU times: user 5min 13s, sys: 3min 9s, total: 8min 23s
# Wall time: 2min 54s

# %%
gc.collect()
# Out:
# 52858

# %%
# %%time

tnnr_nn_test_64_fzero = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                                show_summary=False, show_loss_plot=True, show_rmse=True, 
                                mdl_wts_file='weights/tnnr_nn_test_64_fzero_n' + str(n) + '_inverse_a' + str(a),
                                num_nn_train=5,
                                num_nn_test=2,
                                radius_nn_predict=0.005,
                                radius_sub_nn_predict=0.01,
                                zero_F_training=True,
                                noise_normal_x=(0, 0.5),
                                noise_normal_y=(0, 5))
# Out:
# Test RMSE (plain):                                6.708309623029871
# Test RMSE (back to y-space):                      63.54172365069253
# Test RMSE (min among clusters):                   5.545540491288222
# Test RMSE (transformed back):                     6.708309623029871
# Test RMSE (min among clusters, transformed back): 5.545540491288222
# CPU times: user 4min 59s, sys: 3min 6s, total: 8min 6s
# Wall time: 2min 43s

# %%
gc.collect()
# Out:
# 48178

# %%
plt.plot(tnnr_nn_test_64_fnorm.train_history.history['loss'], label='Train (normal F)')
plt.plot(tnnr_nn_test_64_fnorm.train_history.history['val_loss'], label='Val (normal F)')

plt.plot(tnnr_nn_test_64_fzero.train_history.history['loss'], label='Train (F = 0)')
plt.plot(tnnr_nn_test_64_fzero.train_history.history['val_loss'], label='Val (F = 0)')

plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')

# %%
plt.scatter(tnnr_nn_test_64_fnorm.cn_transformer.inverse_transform_x(tnnr_nn_test_64_fnorm.x_train_single), 
            tnnr_nn_test_64_fnorm.cn_transformer.inverse_transform_y(tnnr_nn_test_64_fnorm.y_train_single),
            label='Train data set', s=50, c='#99ffff')
plt.scatter(tnnr_nn_test_64_fnorm.x_pred_test,
            tnnr_nn_test_64_fnorm.y_pred_test,
            label='TNNR NN, Normal F, $2\\times 64$ neurons', s=20)
plt.scatter(tnnr_nn_test_64_fnorm.x_pred_test,
            tnnr_nn_test_64_fnorm.y_pred_test,
            label='TNNR NN, F = 0, $2\\times 64$ neurons', s=1)

plt.title('Function: $x^3 - 70x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend(loc=6)

# %%
gc.collect()
# Out:
# 1058

# %%
gc.collect()
# Out:
# 0

# %%
# %%time

tnnr_nn_test_64_fnorm = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                                show_summary=False, show_loss_plot=True, show_rmse=True, 
                                mdl_wts_file='weights/tnnr_nn_test_64_fnorm_n' + str(n) + '_inverse_a' + str(a),
                                num_nn_train=5,
                                num_nn_test=3,
                                radius_nn_predict=0.005,
                                radius_sub_nn_predict=0.0005,
                                noise_normal_x=(0, 0.5),
                                noise_normal_y=(0, 5))
# Out:
# Test RMSE (plain):                                6.834886870540609
# Test RMSE (back to y-space):                      65.40124693180873
# Test RMSE (min among clusters):                   4.962597786761483
# Test RMSE (transformed back):                     6.834886870540609
# Test RMSE (min among clusters, transformed back): 4.962597786761483
# CPU times: user 24min 38s, sys: 22min 36s, total: 47min 14s
# Wall time: 6min 23s

# %%
gc.collect()
# Out:
# 45088

# %%
# %%time

tnnr_nn_test_64_fzero = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                                show_summary=False, show_loss_plot=True, show_rmse=True, 
                                mdl_wts_file='weights/tnnr_nn_test_64_fzero_n' + str(n) + '_inverse_a' + str(a),
                                num_nn_train=5,
                                num_nn_test=3,
                                radius_nn_predict=0.005,
                                radius_sub_nn_predict=0.0005,
                                zero_F_training=True,
                                noise_normal_x=(0, 0.5),
                                noise_normal_y=(0, 5))
# Out:
# Test RMSE (plain):                                6.834873997849637
# Test RMSE (back to y-space):                      65.4471118456947
# Test RMSE (min among clusters):                   4.962476975844226
# Test RMSE (transformed back):                     6.834873997849637
# Test RMSE (min among clusters, transformed back): 4.962476975844226
# CPU times: user 15min 3s, sys: 17min 39s, total: 32min 42s
# Wall time: 6min 35s

# %%
65.40124693180873 - 65.4471118456947
# Out:
# -0.04586491388597835

# %%
gc.collect()
# Out:
# 24874

# %%
plt.plot(tnnr_nn_test_64_fnorm.train_history.history['loss'], label='Train (normal F)')
plt.plot(tnnr_nn_test_64_fnorm.train_history.history['val_loss'], label='Val (normal F)')

plt.plot(tnnr_nn_test_64_fzero.train_history.history['loss'], label='Train (F = 0)')
plt.plot(tnnr_nn_test_64_fzero.train_history.history['val_loss'], label='Val (F = 0)')

plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')

# %%
plt.scatter(tnnr_nn_test_64_fnorm.cn_transformer.inverse_transform_x(tnnr_nn_test_64_fnorm.x_train_single), 
            tnnr_nn_test_64_fnorm.cn_transformer.inverse_transform_y(tnnr_nn_test_64_fnorm.y_train_single),
            label='Train data set', s=50, c='#99ffff')
plt.scatter(tnnr_nn_test_64_fnorm.x_pred_test,
            tnnr_nn_test_64_fnorm.y_pred_test,
            label='TNNR NN, Normal F, $2\\times 64$ neurons', s=20)
plt.scatter(tnnr_nn_test_64_fnorm.x_pred_test,
            tnnr_nn_test_64_fnorm.y_pred_test,
            label='TNNR NN, F = 0, $2\\times 64$ neurons', s=1)

plt.title('Function: $x^3 - 70x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend(loc=6)

# %%
gc.collect()
# Out:
# 959

# %%
gc.collect()
# Out:
# 0

# %% [markdown]
# --------------

# %% [markdown]
# ---------

# %%
a = -70

# %%
# %%time

tnnr_nn_test_64_fnorm = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                                show_summary=False, show_loss_plot=True, show_rmse=True, 
                                mdl_wts_file='weights/tnnr_nn_test_64_fnorm_n' + str(n) + '_inverse_a' + str(a),
                                num_nn_train=13,
                                num_nn_test=15,
                                radius_nn_predict=0.005,
                                radius_sub_nn_predict=0.0005,
                                noise_range_x=(-0.5, 0.5),
                                noise_range_y=(-1, 1))
# Out:
# Test RMSE (plain):              0.020377208087160717
# Test RMSE (back to y-space):    2.1281749113650124
# Test RMSE (min among clusters): 0.002752153181655515
# CPU times: user 1h 41min 47s, sys: 1h 41min 30s, total: 3h 23min 18s
# Wall time: 24min 19s

# %%
gc.collect()
# Out:
# 18670

# %%
# %%time

tnnr_nn_test_64_fzero = TNNR_NN(def_func(a), n=n, seed=seed, inverse_problem=True, test_pct=0.2, val_pct=0.2,
                                show_summary=False, show_loss_plot=True, show_rmse=True, 
                                mdl_wts_file='weights/tnnr_nn_test_64_fzero_n' + str(n) + '_inverse_a' + str(a),
                                num_nn_train=13,
                                num_nn_test=15,
                                radius_nn_predict=0.005,
                                radius_sub_nn_predict=0.0005,
                                zero_F_training=True,
                                noise_range_x=(-0.5, 0.5),
                                noise_range_y=(-1, 1))
# Out:
# Test RMSE (plain):              0.078955452127092
# Test RMSE (back to y-space):    16.101112303328367
# Test RMSE (min among clusters): 0.011866236629622754
# CPU times: user 1h 34min 37s, sys: 1h 43min 13s, total: 3h 17min 50s
# Wall time: 21min 58s

# %%
gc.collect()
# Out:
# 26440

# %%
plt.plot(tnnr_nn_test_64_fnorm.train_history.history['loss'], label='Train (normal F)')
plt.plot(tnnr_nn_test_64_fnorm.train_history.history['val_loss'], label='Val (normal F)')

plt.plot(tnnr_nn_test_64_fzero.train_history.history['loss'], label='Train (F = 0)')
plt.plot(tnnr_nn_test_64_fzero.train_history.history['val_loss'], label='Val (F = 0)')

plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')

# %%
plt.scatter(tnnr_nn_test_64_fnorm.cn_transformer.inverse_transform_x(tnnr_nn_test_64_fnorm.x_train_single), 
            tnnr_nn_test_64_fnorm.cn_transformer.inverse_transform_y(tnnr_nn_test_64_fnorm.y_train_single),
            label='Train data set', s=50, c='#99ffff')
plt.scatter(tnnr_nn_test_64_fnorm.x_pred_test,
            tnnr_nn_test_64_fnorm.y_pred_test,
            label='TNNR NN, Normal F, $2\\times 64$ neurons', s=20)
plt.scatter(tnnr_nn_test_64_fnorm.x_pred_test,
            tnnr_nn_test_64_fnorm.y_pred_test,
            label='TNNR NN, F = 0, $2\\times 64$ neurons', s=1)

plt.title('Function: $x^3 + 70x$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend(loc=6)

# %%
gc.collect()
# Out:
# 1433

# %%
gc.collect()
# Out:
# 3895

# %%
gc.collect()
# Out:
# 2686
